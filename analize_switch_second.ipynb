# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import pearsonr

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LassoCV, RidgeCV, ElasticNetCV, LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
import matplotlib.pyplot as plt
from matplotlib import cm
import textwrap
import re

plt.rcParams["font.family"] = "Hiragino Sans"
plt.rcParams["axes.unicode_minus"] = False

pd.set_option("display.max_rows", 200)
pd.set_option("display.max_columns", 200)

# %%
# 目的
# ・ハードの売上げに影響の強い（貢献度が高い）と考えられるゲームタイトルの抽出
# ・そのタイトルのハード販売への影響の程度を測る
# ・その影響がタイトルローンチからどの程度継続したか測る（タイトルのハード販売に対する影響度の減衰の程度を測る）

# 利用データ
# 公開されている決算資料。四半期ごとのミリオンセラータイトルと、ハードウェアの販売量（地域別・世界合計）

# 前提と手法
# タイトル数に対して販売データ数（四半期データ数）が少ないので、多重共線性の影響が残る。
# タイトル網羅的な重回帰分析を意図しているわけではないので、説明性を損なわない回帰分析を中心にする。
# 多重共線性に対処する過程で、残すべきタイトルを落としてしまう可能性がある。

# %%
df = pd.read_csv("completed_data/merged_data_switch.csv", index_col=0)

df.dropna(subset="FY", inplace=True) # データのある行だけを残す(タイトルの販売量があるときだけ、FYに値が入っているから)
q_dummies = pd.get_dummies(df["Q"].astype(int), prefix="Q", dtype=int, drop_first=True)
df = pd.concat([df, q_dummies], axis=1)
df.head()
# Out:
#                FYQ      FY    Q  あつまれ どうぶつの森  マリオカート8 デラックス  スーパーマリオ 3Dコレクション  \
# 2017-03-31  2017Q4  2017.0  4.0          NaN            NaN               NaN
# 2017-06-30  2018Q1  2018.0  1.0          NaN          354.0               NaN
# 2017-09-30  2018Q2  2018.0  2.0          NaN          442.0               NaN
# 2017-12-31  2018Q3  2018.0  3.0          NaN          733.0               NaN
# 2018-03-31  2018Q4  2018.0  4.0          NaN          922.0               NaN
#
#             リングフィット アドベンチャー  ゼルダの伝説 ブレス オブ ザ ワイルド  大乱闘スマッシュブラザーズ SPECIAL  \
# 2017-03-31              NaN                 276.0                    NaN
# 2017-06-30              NaN                 116.0                    NaN
# 2017-09-30              NaN                 193.0                    NaN
# 2017-12-31              NaN                 394.0                    NaN
# 2018-03-31              NaN                 572.0                    NaN
#
#             スーパーマリオパーティ  New スーパーマリオブラザーズU デラックス  ペーパーマリオ オリガミキング  \
# 2017-03-31          NaN                      NaN              NaN
# 2017-06-30          NaN                      NaN              NaN
# 2017-09-30          NaN                      NaN              NaN
# 2017-12-31          NaN                      NaN              NaN
# 2018-03-31          NaN                      NaN              NaN
#
#             ポケットモンスター ソード・シールド  ゼルダ無双 厄災の黙示録  スーパーマリオ オデッセイ  ルイージマンション3  \
# 2017-03-31                 NaN           NaN            NaN         NaN
# 2017-06-30                 NaN           NaN            NaN         NaN
# 2017-09-30                 NaN           NaN            NaN         NaN
# 2017-12-31                 NaN           NaN          907.0         NaN
# 2018-03-31                 NaN           NaN         1041.0         NaN
#
#             世界のアソビ大全51  ピクミン3 デラックス  Splatoon2  Xenoblade Definitive Edition  \
# 2017-03-31         NaN          NaN        NaN                           NaN
# 2017-06-30         NaN          NaN        NaN                           NaN
# 2017-09-30         NaN          NaN      361.0                           NaN
# 2017-12-31         NaN          NaN      491.0                           NaN
# 2018-03-31         NaN          NaN      602.0                           NaN
#
#             スーパーマリオメーカー2  マリオカート ライブ ホームサーキット  \
# 2017-03-31           NaN                  NaN
# 2017-06-30           NaN                  NaN
# 2017-09-30           NaN                  NaN
# 2017-12-31           NaN                  NaN
# 2018-03-31           NaN                  NaN
#
#             ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ  ポケットモンスター スカーレット・バイオレット  \
# 2017-03-31                                       NaN                      NaN
# 2017-06-30                                       NaN                      NaN
# 2017-09-30                                       NaN                      NaN
# 2017-12-31                                       NaN                      NaN
# 2018-03-31                                       NaN                      NaN
#
#             Splatoon3  Nintendo Switch Sports  星のカービィ ディスカバリー  \
# 2017-03-31        NaN                     NaN             NaN
# 2017-06-30        NaN                     NaN             NaN
# 2017-09-30        NaN                     NaN             NaN
# 2017-12-31        NaN                     NaN             NaN
# 2018-03-31        NaN                     NaN             NaN
#
#             マリオパーティ スーパースターズ  マリオストライカーズ バトルリーグ  Pokmon LEGENDS アルセウス  \
# 2017-03-31               NaN                NaN                   NaN
# 2017-06-30               NaN                NaN                   NaN
# 2017-09-30               NaN                NaN                   NaN
# 2017-12-31               NaN                NaN                   NaN
# 2018-03-31               NaN                NaN                   NaN
#
#             スーパーマリオ 3Dワールド + フューリーワールド  ゼノブレイド3  ファイアーエムブレム エンゲージ  \
# 2017-03-31                         NaN      NaN               NaN
# 2017-06-30                         NaN      NaN               NaN
# 2017-09-30                         NaN      NaN               NaN
# 2017-12-31                         NaN      NaN               NaN
# 2018-03-31                         NaN      NaN               NaN
#
#             星のカービィ Wii デラックス  メトロイドプライム リマスタード  ベヨネッタ3  \
# 2017-03-31               NaN               NaN     NaN
# 2017-06-30               NaN               NaN     NaN
# 2017-09-30               NaN               NaN     NaN
# 2017-12-31               NaN               NaN     NaN
# 2018-03-31               NaN               NaN     NaN
#
#             ポケットモンスター ブリリアントダイヤモンド・シャイニングパール  ゼルダの伝説 スカイウォードソード HD  \
# 2017-03-31                               NaN                   NaN
# 2017-06-30                               NaN                   NaN
# 2017-09-30                               NaN                   NaN
# 2017-12-31                               NaN                   NaN
# 2018-03-31                               NaN                   NaN
#
#             メトロイド ドレッド  New ポケモンスナップ  マリオゴルフ スーパーラッシュ  ミートピア  \
# 2017-03-31         NaN           NaN              NaN    NaN
# 2017-06-30         NaN           NaN              NaN    NaN
# 2017-09-30         NaN           NaN              NaN    NaN
# 2017-12-31         NaN           NaN              NaN    NaN
# 2018-03-31         NaN           NaN              NaN    NaN
#
#             やわらかあたま塾 いっしょにあたまのストレッチ  おすそわける メイド イン ワリオ  \
# 2017-03-31                      NaN                NaN
# 2017-06-30                      NaN                NaN
# 2017-09-30                      NaN                NaN
# 2017-12-31                      NaN                NaN
# 2018-03-31                      NaN                NaN
#
#             ナビつき！ つくってわかる はじめてゲームプログラミング   ARMS  1-2-Switch  ゼノブレイド2  \
# 2017-03-31                           NaN    NaN         NaN      NaN
# 2017-06-30                           NaN  118.0         NaN      NaN
# 2017-09-30                           NaN  135.0         NaN      NaN
# 2017-12-31                           NaN  161.0         NaN    106.0
# 2018-03-31                           NaN  185.0       134.0    131.0
#
#             星のカービィ スターアライズ  ポッ拳 ポッケン トーナメント DX  ゼルダの伝説 ティアーズ オブ ザ キングダム  \
# 2017-03-31             NaN                 NaN                      NaN
# 2017-06-30             NaN                 NaN                      NaN
# 2017-09-30             NaN                 NaN                      NaN
# 2017-12-31             NaN                 NaN                      NaN
# 2018-03-31           126.0               116.0                      NaN
#
#             Pikmin 4  ゼルダの伝説 夢をみる島  ファイアーエムブレム 風花雪月  ASTRAL CHAIN  \
# 2017-03-31       NaN           NaN              NaN           NaN
# 2017-06-30       NaN           NaN              NaN           NaN
# 2017-09-30       NaN           NaN              NaN           NaN
# 2017-12-31       NaN           NaN              NaN           NaN
# 2018-03-31       NaN           NaN              NaN           NaN
#
#             MARVEL ULTIMATE ALLIANCE 3: The Black Order  ゼルダの伝説 知恵のかりもの  \
# 2017-03-31                                          NaN             NaN
# 2017-06-30                                          NaN             NaN
# 2017-09-30                                          NaN             NaN
# 2017-12-31                                          NaN             NaN
# 2018-03-31                                          NaN             NaN
#
#             ペーパーマリオRPG  ルイージマンション2 HD  スーパー マリオパーティ ジャンボリー  \
# 2017-03-31         NaN            NaN                  NaN
# 2017-06-30         NaN            NaN                  NaN
# 2017-09-30         NaN            NaN                  NaN
# 2017-12-31         NaN            NaN                  NaN
# 2018-03-31         NaN            NaN                  NaN
#
#             Super Mario Bros. Wonder  マリオ&ルイージRPG ブラザーシップ!  マリオテニス エース  \
# 2017-03-31                       NaN                   NaN         NaN
# 2017-06-30                       NaN                   NaN         NaN
# 2017-09-30                       NaN                   NaN         NaN
# 2017-12-31                       NaN                   NaN         NaN
# 2018-03-31                       NaN                   NaN         NaN
#
#             ドンキーコング トロピカルフリーズ  スーパーマリオRPG  プリンセスピーチ Showtime!  マリオvs.ドンキーコング  \
# 2017-03-31                NaN         NaN                 NaN            NaN
# 2017-06-30                NaN         NaN                 NaN            NaN
# 2017-09-30                NaN         NaN                 NaN            NaN
# 2017-12-31                NaN         NaN                 NaN            NaN
# 2018-03-31                NaN         NaN                 NaN            NaN
#
#             ドンキーコング リターンズ HD  進め! キノピオ隊長  OCTOPATH TRAVELER  ヨッシークラフトワールド  \
# 2017-03-31               NaN         NaN                NaN           NaN
# 2017-06-30               NaN         NaN                NaN           NaN
# 2017-09-30               NaN         NaN                NaN           NaN
# 2017-12-31               NaN         NaN                NaN           NaN
# 2018-03-31               NaN         NaN                NaN           NaN
#
#             Nintendo Labo Toy-Con 01: Variety Kit  ルイージマンション３  \
# 2017-03-31                                    NaN         NaN
# 2017-06-30                                    NaN         NaN
# 2017-09-30                                    NaN         NaN
# 2017-12-31                                    NaN         NaN
# 2018-03-31                                    NaN         NaN
#
#             おすそわける　メイド イン ワリオ  ポケモン不思議のダンジョン 救助隊DX  あつまれ どうぶつの森_quarter  \
# 2017-03-31                NaN                  NaN                  NaN
ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter  \
# 2017-03-31                                               NaN
# 2017-06-30                                               NaN
# 2017-09-30                                               NaN
# 2017-12-31                                               NaN
# 2018-03-31                                               NaN
#
#             ポケットモンスター スカーレット・バイオレット_quarter  Splatoon3_quarter  \
# 2017-03-31                              NaN                NaN
# 2017-06-30                              NaN                NaN
# 2017-09-30                              NaN                NaN
# 2017-12-31                              NaN                NaN
# 2018-03-31                              NaN                NaN
#
#             Nintendo Switch Sports_quarter  星のカービィ ディスカバリー_quarter  \
# 2017-03-31                             NaN                     NaN
# 2017-06-30                             NaN                     NaN
# 2017-09-30                             NaN                     NaN
# 2017-12-31                             NaN                     NaN
# 2018-03-31                             NaN                     NaN
#
#             マリオパーティ スーパースターズ_quarter  マリオストライカーズ バトルリーグ_quarter  \
# 2017-03-31                       NaN                        NaN
# 2017-06-30                       NaN                        NaN
# 2017-09-30                       NaN                        NaN
# 2017-12-31                       NaN                        NaN
# 2018-03-31                       NaN                        NaN
#
#             Pokmon LEGENDS アルセウス_quarter  スーパーマリオ 3Dワールド + フューリーワールド_quarter  \
# 2017-03-31                           NaN                                 NaN
# 2017-06-30                           NaN                                 NaN
# 2017-09-30                           NaN                                 NaN
# 2017-12-31                           NaN                                 NaN
# 2018-03-31                           NaN                                 NaN
#
#             ゼノブレイド3_quarter  ファイアーエムブレム エンゲージ_quarter  \
# 2017-03-31              NaN                       NaN
# 2017-06-30              NaN                       NaN
# 2017-09-30              NaN                       NaN
# 2017-12-31              NaN                       NaN
# 2018-03-31              NaN                       NaN
#
#             星のカービィ Wii デラックス_quarter  メトロイドプライム リマスタード_quarter  \
# 2017-03-31                       NaN                       NaN
# 2017-06-30                       NaN                       NaN
# 2017-09-30                       NaN                       NaN
# 2017-12-31                       NaN                       NaN
# 2018-03-31                       NaN                       NaN
#
#             ベヨネッタ3_quarter  ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter  \
# 2017-03-31             NaN                                       NaN
# 2017-06-30             NaN                                       NaN
# 2017-09-30             NaN                                       NaN
# 2017-12-31             NaN                                       NaN
# 2018-03-31             NaN                                       NaN
#
#             ゼルダの伝説 スカイウォードソード HD_quarter  メトロイド ドレッド_quarter  \
# 2017-03-31                           NaN                 NaN
# 2017-06-30                           NaN                 NaN
# 2017-09-30                           NaN                 NaN
# 2017-12-31                           NaN                 NaN
# 2018-03-31                           NaN                 NaN
#
#             New ポケモンスナップ_quarter  マリオゴルフ スーパーラッシュ_quarter  ミートピア_quarter  \
# 2017-03-31                   NaN                      NaN            NaN
# 2017-06-30                   NaN                      NaN            NaN
# 2017-09-30                   NaN                      NaN            NaN
# 2017-12-31                   NaN                      NaN            NaN
# 2018-03-31                   NaN                      NaN            NaN
#
#             やわらかあたま塾 いっしょにあたまのストレッチ_quarter  おすそわける メイド イン ワリオ_quarter  \
# 2017-03-31                              NaN                        NaN
# 2017-06-30                              NaN                        NaN
# 2017-09-30                              NaN                        NaN
# 2017-12-31                              NaN                        NaN
# 2018-03-31                              NaN                        NaN
#
#             ナビつき！ つくってわかる はじめてゲームプログラミング_quarter  ARMS_quarter  \
# 2017-03-31                                   NaN           NaN
# 2017-06-30                                   NaN         118.0
# 2017-09-30                                   NaN          17.0
# 2017-12-31                                   NaN          26.0
# 2018-03-31                                   NaN          24.0
#
#             1-2-Switch_quarter  ゼノブレイド2_quarter  星のカービィ スターアライズ_quarter  \
# 2017-03-31                 NaN              NaN                     NaN
# 2017-06-30                 NaN              NaN                     NaN
# 2017-09-30                 NaN              NaN                     NaN
# 2017-12-31                 NaN            106.0                     NaN
# 2018-03-31               134.0             25.0                   126.0
#
#             ポッ拳 ポッケン トーナメント DX_quarter  ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter  \
# 2017-03-31                         NaN                              NaN
# 2017-06-30                         NaN                              NaN
# 2017-09-30                         NaN                              NaN
# 2017-12-31                         NaN                              NaN
# 2018-03-31                       116.0                              NaN
#
#             Pikmin 4_quarter  ゼルダの伝説 夢をみる島_quarter  ファイアーエムブレム 風花雪月_quarter  \
# 2017-03-31               NaN                   NaN                      NaN
# 2017-06-30               NaN                   NaN                      NaN
# 2017-09-30               NaN                   NaN                      NaN
# 2017-12-31               NaN                   NaN                      NaN
# 2018-03-31               NaN                   NaN                      NaN
#
#             ASTRAL CHAIN_quarter  \
# 2017-03-31                   NaN
# 2017-06-30                   NaN
# 2017-09-30                   NaN
# 2017-12-31                   NaN
# 2018-03-31                   NaN
#
#             MARVEL ULTIMATE ALLIANCE 3: The Black Order_quarter  \
# 2017-03-31                                                NaN
# 2017-06-30                                                NaN
# 2017-09-30                                                NaN
# 2017-12-31                                                NaN
# 2018-03-31                                                NaN
#
#             ゼルダの伝説 知恵のかりもの_quarter  ペーパーマリオRPG_quarter  ルイージマンション2 HD_quarter  \
# 2017-03-31                     NaN                 NaN                    NaN
# 2017-06-30                     NaN                 NaN                    NaN
# 2017-09-30                     NaN                 NaN                    NaN
# 2017-12-31                     NaN                 NaN                    NaN
# 2018-03-31                     NaN                 NaN                    NaN
#
#             スーパー マリオパーティ ジャンボリー_quarter  Super Mario Bros. Wonder_quarter  \
# 2017-03-31                          NaN                               NaN
# 2017-06-30                          NaN                               NaN
# 2017-09-30                          NaN                               NaN
# 2017-12-31                          NaN                               NaN
# 2018-03-31                          NaN                               NaN
#
#             マリオ&ルイージRPG ブラザーシップ!_quarter  マリオテニス エース_quarter  \
# 2017-03-31                           NaN                 NaN
# 2017-06-30                           NaN                 NaN
# 2017-09-30                           NaN                 NaN
# 2017-12-31                           NaN                 NaN
# 2018-03-31                           NaN                 NaN
#
#             ドンキーコング トロピカルフリーズ_quarter  スーパーマリオRPG_quarter  \
# 2017-03-31                        NaN                 NaN
# 2017-06-30                        NaN                 NaN
# 2017-09-30                        NaN                 NaN
# 2017-12-31                        NaN                 NaN
# 2018-03-31                        NaN                 NaN
#
#             プリンセスピーチ Showtime!_quarter  マリオvs.ドンキーコング_quarter  \
# 2017-03-31                         NaN                    NaN
# 2017-06-30                         NaN                    NaN
# 2017-09-30                         NaN                    NaN
# 2017-12-31                         NaN                    NaN
# 2018-03-31                         NaN                    NaN
#
#             ドンキーコング リターンズ HD_quarter  進め! キノピオ隊長_quarter  \
# 2017-03-31                       NaN                 NaN
# 2017-06-30                       NaN                 NaN
# 2017-09-30                       NaN                 NaN
# 2017-12-31                       NaN                 NaN
# 2018-03-31                       NaN                 NaN
#
#             OCTOPATH TRAVELER_quarter  ヨッシークラフトワールド_quarter  \
# 2017-03-31                        NaN                   NaN
# 2017-06-30                        NaN                   NaN
# 2017-09-30                        NaN                   NaN
# 2017-12-31                        NaN                   NaN
# 2018-03-31                        NaN                   NaN
#
#             Nintendo Labo Toy-Con 01: Variety Kit_quarter  ルイージマンション３_quarter  \
# 2017-03-31                                            NaN                 NaN
# 2017-06-30                                            NaN                 NaN
# 2017-09-30                                            NaN                 NaN
# 2017-12-31                                            NaN                 NaN
# 2018-03-31                                            NaN                 NaN
#
#             おすそわける　メイド イン ワリオ_quarter  ポケモン不思議のダンジョン 救助隊DX_quarter  \
# 2017-03-31                        NaN                          NaN
# 2017-06-30                        NaN                          NaN
# 2017-09-30                        NaN                          NaN
# 2017-12-31                        NaN                          NaN
# 2018-03-31                        NaN                          NaN
#
#             Switch_jp_sales  Switch_us_sales  Switch_eur_sales  \
# 2017-03-31             60.0            120.0               0.0
# 2017-06-30             52.0             75.0               0.0
# 2017-09-30             83.0            117.0               0.0
# 2017-12-31            177.0            282.0               0.0
# 2018-03-31             66.0            120.0               0.0
#
#             Switch_others_sales  hard_total_sales  Q_2  Q_3  Q_4
# 2017-03-31                 94.0             274.0    0    0    1
# 2017-06-30                 69.0             196.0    0    0    0
# 2017-09-30                 93.0             293.0    1    0    0
# 2017-12-31                264.0             723.0    0    1    0
# 2018-03-31                107.0             293.0    0    0    1

# %%
df.describe()
# Out:
#                 FY          Q  あつまれ どうぶつの森  マリオカート8 デラックス  スーパーマリオ 3Dコレクション  \
# count    33.000000  33.000000    18.000000      31.000000          3.000000
# mean   2021.363636   2.545455   622.277778     519.612903        751.333333
# std       2.421495   1.148121   637.356287     290.980489        202.435998
# min    2017.000000   1.000000   109.000000     113.000000        521.000000
# 25%    2019.000000   2.000000   211.500000     240.500000        676.500000
# 50%    2021.000000   3.000000   305.000000     538.000000        832.000000
# 75%    2023.000000   4.000000   947.500000     771.500000        866.500000
# max    2025.000000   4.000000  2085.000000    1062.000000        901.000000
#
#        リングフィット アドベンチャー  ゼルダの伝説 ブレス オブ ザ ワイルド  大乱闘スマッシュブラザーズ SPECIAL  \
# count        12.000000             24.000000              20.000000
# mean        296.500000            287.125000             380.700000
# std         199.511449            132.493909             335.386517
# min         113.000000            116.000000             115.000000
# 25%         126.000000            180.750000             189.000000
# 50%         245.000000            259.500000             274.500000
# 75%         356.000000            396.500000             409.000000
# max         738.000000            572.000000            1381.000000
#
#        スーパーマリオパーティ  New スーパーマリオブラザーズU デラックス  ペーパーマリオ オリガミキング  \
# count    15.000000                15.000000         3.000000
# mean    280.533333               226.800000       299.666667
# std     165.734670                87.449741        15.695010
# min     101.000000               103.000000       282.000000
# 25%     144.000000               158.500000       293.500000
# 50%     259.000000               211.000000       305.000000
# 75%     371.000000               304.000000       308.500000
# max     640.000000               384.000000       312.000000
#
#        ポケットモンスター ソード・シールド  ゼルダ無双 厄災の黙示録  スーパーマリオ オデッセイ  ルイージマンション3  \
# count            8.000000      2.000000      20.000000    7.000000
# mean           616.375000    295.500000     295.650000  244.428571
# std            656.338096     16.263456     246.771208  152.231027
# min            154.000000    284.000000     109.000000  102.000000
# 25%            251.250000    289.750000     161.000000  141.000000
# 50%            308.000000    295.500000     219.500000  183.000000
# 75%            681.250000    301.250000     306.500000  303.500000
# max           1737.000000    307.000000    1041.000000  537.000000
#
#        世界のアソビ大全51  ピクミン3 デラックス   Splatoon2  Xenoblade Definitive Edition  \
# count    5.000000     2.000000   12.000000                      4.000000
# mean   193.600000   199.000000  246.083333                    143.000000
# std     93.366482     7.071068  160.375955                      8.869423
# min    103.000000   194.000000  109.000000                    132.000000
# 25%    108.000000   196.500000  135.500000                    138.000000
# 50%    181.000000   199.000000  192.500000                    144.000000
# 75%    262.000000   201.500000  292.000000                    149.000000
# max    314.000000   204.000000  602.000000                    152.000000
#
#        スーパーマリオメーカー2  マリオカート ライブ ホームサーキット  \
# count      6.000000             2.000000
# mean     332.833333           117.500000
# std      173.783102            13.435029
# min      143.000000           108.000000
# 25%      185.750000           112.750000
# 50%      317.500000           117.500000
# 75%      476.250000           122.250000
# max      548.000000           127.000000
#
#        ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ  ポケットモンスター スカーレット・バイオレット  \
# count                                   8.00000                 7.000000
# mean                                  346.75000               746.428571
# std                                   423.12266               951.436258
# min                                   103.00000               113.000000
# 25%                                   111.00000               166.500000
# 50%                                   128.00000               226.000000
# 75%                                   350.50000              1171.500000
# max                                  1063.00000              2210.000000
#
#          Splatoon3  Nintendo Switch Sports  星のカービィ ディスカバリー  マリオパーティ スーパースターズ  \
# count     5.000000                10.00000        6.000000          9.000000
# mean    620.600000               438.10000      258.000000        294.666667
# std     471.829736               290.75016      101.105885        199.889970
# min     104.000000               117.00000      106.000000        110.000000
# 25%     129.000000               269.25000      206.250000        127.000000
# 50%     790.000000               333.50000      263.000000        250.000000
# 75%    1013.000000               582.25000      326.500000        329.000000
# max    1067.000000               960.00000      381.000000        688.000000
#
#        マリオストライカーズ バトルリーグ  Pokmon LEGENDS アルセウス  スーパーマリオ 3Dワールド + フューリーワールド  \
# count           4.000000              4.000000                   10.000000
# mean          227.250000            452.500000                  240.700000
# std            29.010056            542.407289                  141.896715
# min           191.000000            128.000000                  109.000000
# 25%           210.500000            181.250000                  149.000000
# 50%           232.000000            209.000000                  190.500000
# 75%           248.750000            480.250000                  297.000000
# max           254.000000           1264.000000                  559.000000
#
#           ゼノブレイド3  ファイアーエムブレム エンゲージ  星のカービィ Wii デラックス  メトロイドプライム リマスタード  \
# count    3.000000               1.0               1.0               1.0
# mean   179.666667             161.0             146.0             109.0
# std      7.094599               NaN               NaN               NaN
# min    172.000000             161.0             146.0             109.0
# 25%    176.500000             161.0             146.0             109.0
# 50%    181.000000             161.0             146.0             109.0
# 75%    183.500000             161.0             146.0             109.0
# max    186.000000             161.0             146.0             109.0
#
#           ベヨネッタ3  ポケットモンスター ブリリアントダイヤモンド・シャイニングパール  ゼルダの伝説 スカイウォードソード HD  \
# count    2.00000                          2.000000              3.000000
# mean   105.50000                       1431.000000            378.666667
# std      2.12132                         48.083261             16.441817
# min    104.00000                       1397.000000            360.000000
# 25%    104.75000                       1414.000000            372.500000
# 50%    105.50000                       1431.000000            385.000000
# 75%    106.25000                       1448.000000            388.000000
# max    107.00000                       1465.000000            391.000000
#
#        メトロイド ドレッド  New ポケモンスナップ  マリオゴルフ スーパーラッシュ       ミートピア  \
# count    2.000000       4.00000         4.000000    4.000000
# mean   282.000000     225.50000       197.250000  143.000000
# std     11.313708      15.32971        45.690079   29.337121
# min    274.000000     207.00000       134.000000  104.000000
# 25%    278.000000     216.00000       179.000000  128.750000
# 50%    282.000000     227.50000       210.000000  150.000000
# 75%    286.000000     237.00000       228.250000  164.250000
# max    290.000000     240.00000       235.000000  168.000000
#
#        やわらかあたま塾 いっしょにあたまのストレッチ  おすそわける メイド イン ワリオ  \
# count                  2.00000                1.0
# mean                 143.50000              127.0
# std                   21.92031                NaN
# min                  128.00000              127.0
# 25%                  135.75000              127.0
# 50%                  143.50000              127.0
# 75%                  151.25000              127.0
# max                  159.00000              127.0
#
#        ナビつき！ つくってわかる はじめてゲームプログラミング        ARMS  1-2-Switch    ゼノブレイド2  \
# count                      2.000000    4.000000         1.0    2.00000
# mean                     103.500000  149.750000       134.0  118.50000
# std                        3.535534   29.409466         NaN   17.67767
# min                      101.000000  118.000000       134.0  106.00000
# 25%                      102.250000  130.750000       134.0  112.25000
# 50%                      103.500000  148.000000       134.0  118.50000
# 75%                      104.750000  167.000000       134.0  124.75000
# max                      106.000000  185.000000       134.0  131.00000
#
#        星のカービィ スターアライズ  ポッ拳 ポッケン トーナメント DX  ゼルダの伝説 ティアーズ オブ ザ キングダム  \
# count        3.000000                 1.0                 5.000000
# mean       124.000000               116.0              1600.400000
# std          7.211103                 NaN               835.964892
# min        116.000000               116.0               112.000000
# 25%        121.000000               116.0              1851.000000
# 50%        126.000000               116.0              1950.000000
# 75%        128.000000               116.0              2028.000000
# max        130.000000               116.0              2061.000000
#
#          Pikmin 4  ゼルダの伝説 夢をみる島  ファイアーエムブレム 風花雪月  ASTRAL CHAIN  \
# count    3.000000      4.000000              3.0      2.000000
# mean   314.000000    320.250000            258.0    105.500000
# std     46.508064    149.949714             29.0      3.535534
# min    261.000000    111.000000            229.0    103.000000
# 25%    297.000000    262.500000            243.5    104.250000
# 50%    333.000000    366.000000            258.0    105.500000
# 75%    340.500000    423.750000            272.5    106.750000
# max    348.000000    438.000000            287.0    108.000000
#
#        MARVEL ULTIMATE ALLIANCE 3: The Black Order  ゼルダの伝説 知恵のかりもの  \
# count                                     2.000000        3.000000
# mean                                    105.000000      352.666667
# std                                       4.242641       82.476259
# min                                     102.000000      258.000000
# 25%                                     103.500000      324.500000
# 50%                                     105.000000      391.000000
# 75%                                     106.500000      400.000000
# max                                     108.000000      409.000000
#
#        ペーパーマリオRPG  ルイージマンション2 HD  スーパー マリオパーティ ジャンボリー  \
# count    4.000000       4.000000             2.000000
# mean   196.500000     161.000000           682.500000
# std     15.264338      30.930029            92.630988
# min    176.000000     119.000000           617.000000
# 25%    189.500000     147.500000           649.750000
# 50%    200.000000     168.500000           682.500000
# 75%    207.000000     182.000000           715.250000
# max    210.000000     188.000000           748.000000
#
#        Super Mario Bros. Wonder  マリオ&ルイージRPG ブラザーシップ!  マリオテニス エース  \
# count                  4.000000              2.000000    4.000000
# mean                 751.750000            190.500000  217.750000
# std                  601.855118              9.192388   56.993421
# min                  207.000000            184.000000  138.000000
# 25%                  246.750000            187.250000  196.500000
# 50%                  728.000000            190.500000  234.500000
# 75%                 1233.000000            193.750000  255.750000
# max                 1344.000000            197.000000  264.000000
#
#        ドンキーコング トロピカルフリーズ  スーパーマリオRPG  プリンセスピーチ Showtime!  マリオvs.ドンキーコング  \
# count           4.000000    2.000000                 1.0            1.0
# mean          185.000000  322.500000               122.0          112.0
# std            38.635045   12.020815                 NaN            NaN
# min           140.000000  314.000000               122.0          112.0
# 25%           160.250000  318.250000               122.0          112.0
# 50%           187.500000  322.500000               122.0          112.0
# 75%           212.250000  326.750000               122.0          112.0
# max           225.000000  331.000000               122.0          112.0
#
#        ドンキーコング リターンズ HD  進め! キノピオ隊長  OCTOPATH TRAVELER  ヨッシークラフトワールド  \
# count               1.0    2.000000           2.000000           1.0
# mean              127.0  111.500000         112.500000         111.0
# std                 NaN    9.192388           6.363961           NaN
# min               127.0  105.000000         108.000000         111.0
# 25%               127.0  108.250000         110.250000         111.0
# 50%               127.0  111.500000         112.500000         111.0
# 75%               127.0  114.750000         114.750000         111.0
# max               127.0  118.000000         117.000000         111.0
#
#        Nintendo Labo Toy-Con 01: Variety Kit  ルイージマンション３  おすそわける　メイド イン ワリオ  \
# count                                2.00000    4.000000                1.0
# mean                               107.50000  261.000000              124.0
# std                                  2.12132  248.499497                NaN
# min                                106.00000  115.000000              124.0
# 25%                                106.75000  137.500000              124.0
# 50%                                107.50000  148.000000              124.0
# 75%                                108.25000  271.500000              124.0
# max                                109.00000  633.000000              124.0
#
#        ポケモン不思議のダンジョン 救助隊DX  あつまれ どうぶつの森_quarter  マリオカート8 デラックス_quarter  \
# count                  1.0            18.000000              31.000000
# mean                 126.0           265.722222             219.967742
# std                    NaN           332.686534             105.268699
# min                  126.0            39.000000              85.000000
# 25%                  126.0            99.750000             151.500000
# 50%                  126.0           133.500000             181.000000
# 75%                  126.0           246.000000             299.000000
# max                  126.0          1177.000000             462.000000
#
#        スーパーマリオ 3Dコレクション_quarter  リングフィット アドベンチャー_quarter  \
# count                  3.000000                12.000000
# mean                 300.333333               128.166667
# std                  226.188712                74.693109
# min                   69.000000                16.000000
# 25%                  190.000000                85.250000
# 50%                  311.000000               116.000000
# 75%                  416.000000               155.750000
# max                  521.000000               284.000000
#
#        ゼルダの伝説 ブレス オブ ザ ワイルド_quarter  大乱闘スマッシュブラザーズ SPECIAL_quarter  \
# count                     24.000000                      20.000000
# mean                     132.666667                     181.250000
# std                       56.030013                     246.249098
# min                       24.000000                      36.000000
# 25%                      101.500000                      98.000000
# 50%                      121.500000                     128.500000
# 75%                      176.500000                     173.500000
# max                      276.000000                    1208.000000
#
#        スーパーマリオパーティ_quarter  New スーパーマリオブラザーズU デラックス_quarter  \
# count            15.000000                        15.000000
# mean            137.733333                       116.266667
# std             119.373045                        73.237838
# min              32.000000                        25.000000
# 25%              94.000000                        64.000000
# 50%             110.000000                       125.000000
# 75%             160.000000                       136.500000
# max             530.000000                       331.000000
#
#        ペーパーマリオ オリガミキング_quarter  ポケットモンスター ソード・シールド_quarter  \
# count                 3.000000                    8.000000
# mean                104.000000                  303.500000
# std                 154.359969                  527.943991
# min                   7.000000                   38.000000
# 25%                  15.000000                  113.250000
# 50%                  23.000000                  132.000000
# 75%                 152.500000                  156.750000
# max                 282.000000                 1606.000000
#
#        ゼルダ無双 厄災の黙示録_quarter  スーパーマリオ オデッセイ_quarter  ルイージマンション3_quarter  \
# count               2.00000              20.000000            7.000000
# mean              153.50000             146.450000          189.714286
# std               184.55487             186.180579          174.602133
# min                23.00000              24.000000           38.000000
# 25%                88.25000              67.500000           73.500000
# 50%               153.50000             110.500000          142.000000
# 75%               218.75000             158.250000          232.000000
# max               284.00000             907.000000          537.000000
#
#        世界のアソビ大全51_quarter  ピクミン3 デラックス_quarter  Splatoon2_quarter  \
# count             5.00000             2.000000          12.000000
# mean             84.40000           102.000000         110.916667
# std              22.38973           130.107648          87.474109
# min              52.00000            10.000000          31.000000
# 25%              78.00000            56.000000          59.000000
# 50%              81.00000           102.000000         109.500000
# 75%             103.00000           148.000000         117.250000
# max             108.00000           194.000000         361.000000
#
#        Xenoblade Definitive Edition_quarter  スーパーマリオメーカー2_quarter  \
# count                              4.000000              6.000000
# mean                              38.000000            119.166667
# std                               62.695029             79.300483
# min                                4.000000             24.000000
# 25%                                7.000000             60.750000
# 50%                                8.000000            127.000000
# 75%                               39.000000            149.000000
# max                              132.000000            242.000000
#
#        マリオカート ライブ ホームサーキット_quarter  \
# count                     2.000000
# mean                     63.500000
# std                      62.932504
# min                      19.000000
# 25%                      41.250000
# 50%                      63.500000
# 75%                      85.750000
# max                     108.000000
#
#        ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter  \
# count                                          8.000000
# mean                                         181.625000
# std                                          332.972731
# min                                           20.000000
# 25%                                           26.250000
# 50%                                           83.000000
# 75%                                          107.000000
# max                                         1000.000000
#
#        ポケットモンスター スカーレット・バイオレット_quarter  Splatoon3_quarter  \
# count                         7.000000           5.000000
# mean                        382.714286         239.200000
# std                         741.204136         317.057881
# min                          41.000000          25.000000
# 25%                          84.500000          54.000000
# 50%                         113.000000         104.000000
# 75%                         147.500000         223.000000
# max                        2061.000000         790.000000
#
#        Nintendo Switch Sports_quarter  星のカービィ ディスカバリー_quarter  \
# count                       10.000000                6.000000
# mean                       162.700000              125.333333
# std                        125.332491               85.364317
# min                         53.000000               34.000000
# 25%                        103.500000               76.250000
# 50%                        128.500000               96.000000
# 75%                        162.500000              167.500000
# max                        484.000000              265.000000
#
#        マリオパーティ スーパースターズ_quarter  マリオストライカーズ バトルリーグ_quarter  \
# count                  9.000000                   4.000000
# mean                 155.444444                  63.500000
# std                  147.957858                  85.590108
# min                   58.000000                   7.000000
# 25%                   87.000000                  21.250000
# 50%                  119.000000                  28.000000
# 75%                  131.000000                  70.250000
# max                  543.000000                 191.000000
#
#        Pokmon LEGENDS アルセウス_quarter  スーパーマリオ 3Dワールド + フューリーワールド_quarter  \
# count                      4.000000                           10.000000
# mean                     370.750000                          134.800000
# std                      597.131686                          153.783253
# min                       20.000000                           31.000000
# 25%                       58.250000                           58.250000
# 50%                       99.500000                           93.000000
# 75%                      412.000000                          134.250000
# max                     1264.000000                          559.000000
#
#        ゼノブレイド3_quarter  ファイアーエムブレム エンゲージ_quarter  星のカービィ Wii デラックス_quarter  \
# count         3.000000                       1.0                       1.0
# mean         62.000000                     161.0                     146.0
# std          95.283787                       NaN                       NaN
# min           5.000000                     161.0                     146.0
# 25%           7.000000                     161.0                     146.0
# 50%           9.000000                     161.0                     146.0
# 75%          90.500000                     161.0                     146.0
# max         172.000000                     161.0                     146.0
#
#        メトロイドプライム リマスタード_quarter  ベヨネッタ3_quarter  \
# count                       1.0        2.000000
# mean                      109.0       53.500000
# std                         NaN       71.417785
# min                       109.0        3.000000
# 25%                       109.0       28.250000
# 50%                       109.0       53.500000
# 75%                       109.0       78.750000
# max                       109.0      104.000000
#
#        ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter  ゼルダの伝説 スカイウォードソード HD_quarter  \
# count                                  2.000000                      3.000000
# mean                                 732.500000                    130.333333
# std                                  939.744912                    199.123915
# min                                   68.000000                      6.000000
# 25%                                  400.250000                     15.500000
# 50%                                  732.500000                     25.000000
# 75%                                 1064.750000                    192.500000
# max                                 1397.000000                    360.000000
#
#        メトロイド ドレッド_quarter  New ポケモンスナップ_quarter  マリオゴルフ スーパーラッシュ_quarter  \
# count             2.00000               4.00000                 4.000000
# mean            145.00000              60.00000                58.750000
# std             182.43355              98.14615                54.328476
# min              16.00000               4.00000                 9.000000
# 25%              80.50000              10.00000                26.250000
# 50%             145.00000              14.50000                46.000000
# 75%             209.50000              64.50000                78.500000
# max             274.00000             207.00000               134.000000
#
#        ミートピア_quarter  やわらかあたま塾 いっしょにあたまのストレッチ_quarter  \
# count       4.000000                         2.000000
# mean       42.000000                        79.500000
# std        43.011626                        68.589358
# min         5.000000                        31.000000
# 25%        20.750000                        55.250000
# 50%        29.500000                        79.500000
# 75%        50.750000                       103.750000
# max       104.000000                       128.000000
#
#        おすそわける メイド イン ワリオ_quarter  ナビつき！ つくってわかる はじめてゲームプログラミング_quarter  \
# count                        1.0                              2.000000
# mean                       127.0                             53.000000
# std                          NaN                             67.882251
# min                        127.0                              5.000000
# 25%                        127.0                             29.000000
# 50%                        127.0                             53.000000
# 75%                        127.0                             77.000000
# max                        127.0                            101.000000
#
#        ARMS_quarter  1-2-Switch_quarter  ゼノブレイド2_quarter  \
# count      4.000000                 1.0         2.000000
# mean      46.250000               134.0        65.500000
# std       47.988714                 NaN        57.275649
# min       17.000000               134.0        25.000000
# 25%       22.250000               134.0        45.250000
# 50%       25.000000               134.0        65.500000
# 75%       49.000000               134.0        85.750000
# max      118.000000               134.0       106.000000
#
#        星のカービィ スターアライズ_quarter  ポッ拳 ポッケン トーナメント DX_quarter  \
# count                3.000000                         1.0
# mean                85.333333                       116.0
# std                 61.978491                         NaN
# min                 14.000000                       116.0
# 25%                 65.000000                       116.0
# 50%                116.000000                       116.0
# 75%                121.000000                       116.0
# max                126.000000                       116.0
#
#        ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter  Pikmin 4_quarter  \
# count                         5.000000          3.000000
# mean                        434.600000        116.000000
# std                         792.359325        128.767232
# min                          33.000000         15.000000
# 25%                          78.000000         43.500000
# 50%                          99.000000         72.000000
# 75%                         112.000000        166.500000
# max                        1851.000000        261.000000
#
#        ゼルダの伝説 夢をみる島_quarter  ファイアーエムブレム 風花雪月_quarter  ASTRAL CHAIN_quarter  \
# count              4.000000                 3.000000              2.000000
# mean             137.250000                95.666667             54.000000
# std              124.548183               115.470054             69.296465
# min               19.000000                29.000000              5.000000
# 25%               84.250000                29.000000             29.500000
# 50%              108.500000                29.000000             54.000000
# 75%              161.500000               129.000000             78.500000
# max              313.000000               229.000000            103.000000
#
#        MARVEL ULTIMATE ALLIANCE 3: The Black Order_quarter  \
# count                                           2.000000
# mean                                           54.000000
# std                                            67.882251
# min                                             6.000000
# 25%                                            30.000000
# 50%                                            54.000000
# 75%                                            78.000000
# max                                           102.000000
#
#        ゼルダの伝説 知恵のかりもの_quarter  ペーパーマリオRPG_quarter  ルイージマンション2 HD_quarter  \
# count                3.000000            4.000000               4.000000
# mean               136.333333           52.500000              47.000000
# std                120.034717           82.532822              49.537864
# min                 18.000000            4.000000               8.000000
# 25%                 75.500000           10.000000              19.250000
# 50%                133.000000           15.000000              30.500000
# 75%                195.500000           57.500000              58.250000
# max                258.000000          176.000000             119.000000
#
#        スーパー マリオパーティ ジャンボリー_quarter  Super Mario Bros. Wonder_quarter  \
# count                     2.000000                          4.000000
# mean                    374.000000                        401.000000
# std                     343.653896                        533.783352
# min                     131.000000                         53.000000
# 25%                     252.500000                        124.250000
# 50%                     374.000000                        177.500000
# 75%                     495.500000                        454.250000
# max                     617.000000                       1196.000000
#
#        マリオ&ルイージRPG ブラザーシップ!_quarter  マリオテニス エース_quarter  \
# count                       2.00000            4.000000
# mean                       98.50000           66.000000
# std                       120.91526           55.359432
# min                        13.00000           11.000000
# 25%                        55.75000           30.500000
# 50%                        98.50000           57.500000
# 75%                       141.25000           93.000000
# max                       184.00000          138.000000
#
#        ドンキーコング トロピカルフリーズ_quarter  スーパーマリオRPG_quarter  \
# count                   4.000000            2.000000
# mean                   56.250000          165.500000
# std                    56.694356          210.010714
# min                    17.000000           17.000000
# 25%                    24.500000           91.250000
# 50%                    34.000000          165.500000
# 75%                    65.750000          239.750000
# max                   140.000000          314.000000
#
#        プリンセスピーチ Showtime!_quarter  マリオvs.ドンキーコング_quarter  \
# count                         1.0                    1.0
# mean                        122.0                  112.0
# std                           NaN                    NaN
# min                         122.0                  112.0
# 25%                         122.0                  112.0
# 50%                         122.0                  112.0
# 75%                         122.0                  112.0
# max                         122.0                  112.0
#
#        ドンキーコング リターンズ HD_quarter  進め! キノピオ隊長_quarter  \
# count                       1.0            2.000000
# mean                      127.0           59.000000
# std                         NaN           65.053824
# min                       127.0           13.000000
# 25%                       127.0           36.000000
# 50%                       127.0           59.000000
# 75%                       127.0           82.000000
# max                       127.0          105.000000
#
#        OCTOPATH TRAVELER_quarter  ヨッシークラフトワールド_quarter  \
# count                   2.000000                   1.0
# mean                   58.500000                 111.0
# std                    70.003571                   NaN
# min                     9.000000                 111.0
# 25%                    33.750000                 111.0
# 50%                    58.500000                 111.0
# 75%                    83.250000                 111.0
# max                   108.000000                 111.0
#
#        Nintendo Labo Toy-Con 01: Variety Kit_quarter  ルイージマンション３_quarter  \
# count                                       2.000000            4.000000
# mean                                       54.500000          261.000000
# std                                        72.831998          248.499497
# min                                         3.000000          115.000000
# 25%                                        28.750000          137.500000
# 50%                                        54.500000          148.000000
# 75%                                        80.250000          271.500000
# max                                       106.000000          633.000000
#
#        おすそわける　メイド イン ワリオ_quarter  ポケモン不思議のダンジョン 救助隊DX_quarter  \
# count                        1.0                          1.0
# mean                       124.0                        126.0
# std                          NaN                          NaN
# min                        124.0                        126.0
# 25%                        124.0                        126.0
# 50%                        124.0                        126.0
# 75%                        124.0                        126.0
# max                        124.0                        126.0
#
#        Switch_jp_sales  Switch_us_sales  Switch_eur_sales  \
# count        33.000000        33.000000         33.000000
# mean        112.757576       176.727273         75.030303
# std          62.438985       107.844295         91.279271
# min          38.000000        48.000000          0.000000
# 25%          66.000000       108.000000          0.000000
# 50%          98.000000       134.000000         58.000000
# 75%         124.000000       210.000000        108.000000
# max         271.000000       459.000000        338.000000
#
#        Switch_others_sales  hard_total_sales        Q_2        Q_3        Q_4
# count            33.000000         33.000000  33.000000  33.000000  33.000000
# mean             89.303030        453.818182   0.242424   0.242424   0.272727
# std              75.931501        274.365456   0.435194   0.435194   0.452267
# min              19.000000        125.000000   0.000000   0.000000   0.000000
# 25%              48.000000        274.000000   0.000000   0.000000   0.000000
# 50%              65.000000        343.000000   0.000000   0.000000   0.000000
# 75%             107.000000        567.000000   0.000000   0.000000   1.000000
# max             340.000000       1156.000000   1.000000   1.000000   1.000000

# %%
# 四半期のみの販売量の説明変数にするために、selected_dfを作成
titles_with_quarter = [col for col in df.columns if "_quarter" in col]
# selected_cols = ["Q_2", "Q_3", "Q_4"] + titles_with_quarter + ["Wii_jp_sales", "Wii_us_sales", "Wii_others_sales" , "hard_total_sales"]
selected_cols = ["Q_2", "Q_3", "Q_4"] + titles_with_quarter + ["hard_total_sales"]
selected_df = df[selected_cols]
selected_df_with_na = selected_df # 欠損処理しないdfを後の分析のために残しておく
selected_df = selected_df.fillna(0)
# selected_df.info()
selected_df.head()
# Out:
#             Q_2  Q_3  Q_4  あつまれ どうぶつの森_quarter  マリオカート8 デラックス_quarter  \
# 2017-03-31    0    0    1                  0.0                    0.0
# 2017-06-30    0    0    0                  0.0                  354.0
# 2017-09-30    1    0    0                  0.0                   88.0
# 2017-12-31    0    1    0                  0.0                  291.0
# 2018-03-31    0    0    1                  0.0                  189.0
#
#             スーパーマリオ 3Dコレクション_quarter  リングフィット アドベンチャー_quarter  \
# 2017-03-31                       0.0                      0.0
# 2017-06-30                       0.0                      0.0
# 2017-06-30                        0.0                          0.0
# 2017-09-30                        0.0                          0.0
# 2017-12-31                        0.0                          0.0
# 2018-03-31                        0.0                          0.0
#
#             hard_total_sales
# 2017-03-31             274.0
# 2017-06-30             196.0
# 2017-09-30             293.0
# 2017-12-31             723.0
# 2018-03-31             293.0

# %%
def summarize_title_stats(df, title_cols):
    """
    記述統計を見やすく表示する（相関係数、p値付き）
    """
    stats = {}
    for col in title_cols:
        series = df[col].dropna()
        n = series.count()

        # 相関係数とp値の計算（データ数が3以上のときのみ）
        if n > 2:
            corr_val, p_val = pearsonr(df["hard_total_sales"].loc[series.index], series)
            corr_val = round(corr_val, 3)
            p_val = round(p_val, 4)
        else:
            corr_val = None
            p_val = None

        mean_val = series.mean()
        if mean_val != 0:
            cv_val = round(series.std() / mean_val, 3)
        else:
            cv_val = None

        stats[col] = {
            "データ数": n,
            "平均": round(mean_val, 3),
            "中央値": series.median() if n > 0 else None,
            "標準偏差": round(series.std(), 3) if n > 0 else None,
            "最小値": series.min() if n > 0 else None,
            "最大値": series.max() if n > 0 else None,
            "変動係数(CV)": cv_val,
            "相関係数(hard_total_sales)": corr_val,
            "p値(hard_total_sales)": p_val,
            "データ数(再掲)": n,
            "総販売量": series.sum() if n > 0 else None
        }

    summary_df = pd.DataFrame(stats).T
    return summary_df

# %%
summary_df = summarize_title_stats(selected_df_with_na, titles_with_quarter)
display(summary_df.sort_values("データ数", ascending=False))
# Out:
#                                                     データ数       平均    中央値  \
# マリオカート8 デラックス_quarter                               31.0  219.968  181.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                        24.0  132.667  121.5
# スーパーマリオ オデッセイ_quarter                               20.0  146.450  110.5
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                       20.0  181.250  128.5
# あつまれ どうぶつの森_quarter                                 18.0  265.722  133.5
# New スーパーマリオブラザーズU デラックス_quarter                     15.0  116.267  125.0
# スーパーマリオパーティ_quarter                                 15.0  137.733  110.0
# Splatoon2_quarter                                   12.0  110.917  109.5
# リングフィット アドベンチャー_quarter                             12.0  128.167  116.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                  10.0  134.800   93.0
# Nintendo Switch Sports_quarter                      10.0  162.700  128.5
# マリオパーティ スーパースターズ_quarter                             9.0  155.444  119.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter     8.0  181.625   83.0
# ポケットモンスター ソード・シールド_quarter                           8.0  303.500  132.0
# ルイージマンション3_quarter                                   7.0  189.714  142.0
# ポケットモンスター スカーレット・バイオレット_quarter                      7.0  382.714  113.0
# スーパーマリオメーカー2_quarter                                 6.0  119.167  127.0
# 星のカービィ ディスカバリー_quarter                               6.0  125.333   96.0
# 世界のアソビ大全51_quarter                                   5.0   84.400   81.0
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                      5.0  434.600   99.0
# Splatoon3_quarter                                    5.0  239.200  104.0
# ミートピア_quarter                                        4.0   42.000   29.5
# ARMS_quarter                                         4.0   46.250   25.0
# ゼルダの伝説 夢をみる島_quarter                                 4.0  137.250  108.5
# ドンキーコング トロピカルフリーズ_quarter                            4.0   56.250   34.0
# ペーパーマリオRPG_quarter                                   4.0   52.500   15.0
# ルイージマンション2 HD_quarter                                4.0   47.000   30.5
# ルイージマンション３_quarter                                   4.0  261.000  148.0
# Super Mario Bros. Wonder_quarter                     4.0  401.000  177.5
# マリオテニス エース_quarter                                   4.0   66.000   57.5
# マリオゴルフ スーパーラッシュ_quarter                              4.0   58.750   46.0
# New ポケモンスナップ_quarter                                 4.0   60.000   14.5
# Xenoblade Definitive Edition_quarter                 4.0   38.000    8.0
# マリオストライカーズ バトルリーグ_quarter                            4.0   63.500   28.0
# Pokmon LEGENDS アルセウス_quarter                         4.0  370.750   99.5
# ゼノブレイド3_quarter                                      3.0   62.000    9.0
# 星のカービィ スターアライズ_quarter                               3.0   85.333  116.0
# ゼルダの伝説 スカイウォードソード HD_quarter                         3.0  130.333   25.0
# スーパーマリオ 3Dコレクション_quarter                             3.0  300.333  311.0
# ファイアーエムブレム 風花雪月_quarter                              3.0   95.667   29.0
# Pikmin 4_quarter                                     3.0  116.000   72.0
# ペーパーマリオ オリガミキング_quarter                              3.0  104.000   23.0
# ゼルダの伝説 知恵のかりもの_quarter                               3.0  136.333  133.0
# スーパー マリオパーティ ジャンボリー_quarter                          2.0  374.000  374.0
# ベヨネッタ3_quarter                                       2.0   53.500   53.5
# ピクミン3 デラックス_quarter                                  2.0  102.000  102.0
# マリオ&ルイージRPG ブラザーシップ!_quarter                         2.0   98.500   98.5
# ゼルダ無双 厄災の黙示録_quarter                                 2.0  153.500  153.5
# スーパーマリオRPG_quarter                                   2.0  165.500  165.5
# 進め! キノピオ隊長_quarter                                   2.0   59.000   59.0
# OCTOPATH TRAVELER_quarter                            2.0   58.500   58.5
# Nintendo Labo Toy-Con 01: Variety Kit_quarter        2.0   54.500   54.5
# マリオカート ライブ ホームサーキット_quarter                          2.0   63.500   63.5
# MARVEL ULTIMATE ALLIANCE 3: The Black Order_qua...   2.0   54.000   54.0
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter             2.0  732.500  732.5
# ゼノブレイド2_quarter                                      2.0   65.500   65.5
# メトロイド ドレッド_quarter                                   2.0  145.000  145.0
# ナビつき！ つくってわかる はじめてゲームプログラミング_quarter                 2.0   53.000   53.0
# やわらかあたま塾 いっしょにあたまのストレッチ_quarter                      2.0   79.500   79.5
# ASTRAL CHAIN_quarter                                 2.0   54.000   54.0
# ファイアーエムブレム エンゲージ_quarter                             1.0  161.000  161.0
# おすそわける　メイド イン ワリオ_quarter                            1.0  124.000  124.0
# メトロイドプライム リマスタード_quarter                             1.0  109.000  109.0
# ヨッシークラフトワールド_quarter                                 1.0  111.000  111.0
# 星のカービィ Wii デラックス_quarter                             1.0  146.000  146.0
# マリオvs.ドンキーコング_quarter                                1.0  112.000  112.0
# ドンキーコング リターンズ HD_quarter                             1.0  127.000  127.0
# プリンセスピーチ Showtime!_quarter                           1.0  122.000  122.0
# おすそわける メイド イン ワリオ_quarter                            1.0  127.000  127.0
# 1-2-Switch_quarter                                   1.0  134.000  134.0
# ポッ拳 ポッケン トーナメント DX_quarter                           1.0  116.000  116.0
# ポケモン不思議のダンジョン 救助隊DX_quarter                          1.0  126.000  126.0
#
#                                                        標準偏差    最小値     最大値  \
# マリオカート8 デラックス_quarter                               105.269   85.0   462.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter
# ゼルダの伝説 スカイウォードソード HD_quarter                           1.528
# スーパーマリオ 3Dコレクション_quarter                               0.753
# ファイアーエムブレム 風花雪月_quarter                                1.207
# Pikmin 4_quarter                                       1.110
# ペーパーマリオ オリガミキング_quarter                                1.484
# ゼルダの伝説 知恵のかりもの_quarter                                 0.880
# スーパー マリオパーティ ジャンボリー_quarter                            0.919
# ベヨネッタ3_quarter                                         1.335
# ピクミン3 デラックス_quarter                                    1.276
# マリオ&ルイージRPG ブラザーシップ!_quarter                           1.228
# ゼルダ無双 厄災の黙示録_quarter                                   1.202
# スーパーマリオRPG_quarter                                     1.269
# 進め! キノピオ隊長_quarter                                     1.103
# OCTOPATH TRAVELER_quarter                              1.197
# Nintendo Labo Toy-Con 01: Variety Kit_quarter          1.336
# マリオカート ライブ ホームサーキット_quarter                            0.991
# MARVEL ULTIMATE ALLIANCE 3: The Black Order_qua...     1.257
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter               1.283
# ゼノブレイド2_quarter                                        0.874
# メトロイド ドレッド_quarter                                     1.258
# ナビつき！ つくってわかる はじめてゲームプログラミング_quarter                   1.281
# やわらかあたま塾 いっしょにあたまのストレッチ_quarter                        0.863
# ASTRAL CHAIN_quarter                                   1.283
# ファイアーエムブレム エンゲージ_quarter                                 NaN
# おすそわける　メイド イン ワリオ_quarter                                NaN
# メトロイドプライム リマスタード_quarter                                 NaN
# ヨッシークラフトワールド_quarter                                     NaN
# 星のカービィ Wii デラックス_quarter                                 NaN
# マリオvs.ドンキーコング_quarter                                    NaN
# ドンキーコング リターンズ HD_quarter                                 NaN
# プリンセスピーチ Showtime!_quarter                               NaN
# おすそわける メイド イン ワリオ_quarter                                NaN
# 1-2-Switch_quarter                                       NaN
# ポッ拳 ポッケン トーナメント DX_quarter                               NaN
# ポケモン不思議のダンジョン 救助隊DX_quarter                              NaN
#
#                                                     相関係数(hard_total_sales)  \
# マリオカート8 デラックス_quarter                                                0.831
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                                         0.210
# スーパーマリオ オデッセイ_quarter                                                0.280
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                                        0.387
# あつまれ どうぶつの森_quarter                                                  0.203
# New スーパーマリオブラザーズU デラックス_quarter                                      0.108
# スーパーマリオパーティ_quarter                                                  0.464
# Splatoon2_quarter                                                   -0.213
# リングフィット アドベンチャー_quarter                                              0.799
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                                   0.116
# Nintendo Switch Sports_quarter                                       0.348
# マリオパーティ スーパースターズ_quarter                                             0.728
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter                     0.368
# ポケットモンスター ソード・シールド_quarter                                           0.335
# ルイージマンション3_quarter                                                   0.618
# ポケットモンスター スカーレット・バイオレット_quarter                                      0.712
# スーパーマリオメーカー2_quarter                                                -0.079
# 星のカービィ ディスカバリー_quarter                                              -0.022
# 世界のアソビ大全51_quarter                                                  -0.127
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                                      0.127
# Splatoon3_quarter                                                   -0.075
# ミートピア_quarter                                                       -0.193
# ARMS_quarter                                                        -0.462
# ゼルダの伝説 夢をみる島_quarter                                                -0.024
# ドンキーコング トロピカルフリーズ_quarter                                           -0.299
# ペーパーマリオRPG_quarter                                                  -0.231
# ルイージマンション2 HD_quarter                                               -0.163
# ルイージマンション３_quarter                                                  -0.802
# Super Mario Bros. Wonder_quarter                                     0.863
# マリオテニス エース_quarter                                                  -0.406
# マリオゴルフ スーパーラッシュ_quarter                                             -0.282
# New ポケモンスナップ_quarter                                                -0.227
# Xenoblade Definitive Edition_quarter                                -0.317
# マリオストライカーズ バトルリーグ_quarter                                           -0.208
# Pokmon LEGENDS アルセウス_quarter                                        -0.150
# ゼノブレイド3_quarter                                                     -0.453
# 星のカービィ スターアライズ_quarter                                               0.481
# ゼルダの伝説 スカイウォードソード HD_quarter                                        -0.491
# スーパーマリオ 3Dコレクション_quarter                                             0.345
# ファイアーエムブレム 風花雪月_quarter                                             -0.333
# Pikmin 4_quarter                                                    -0.110
# ペーパーマリオ オリガミキング_quarter                                             -0.160
# ゼルダの伝説 知恵のかりもの_quarter                                               0.357
# スーパー マリオパーティ ジャンボリー_quarter                                            NaN
# ベヨネッタ3_quarter                                                         NaN
# ピクミン3 デラックス_quarter                                                    NaN
# マリオ&ルイージRPG ブラザーシップ!_quarter                                           NaN
# ゼルダ無双 厄災の黙示録_quarter                                                   NaN
# スーパーマリオRPG_quarter                                                     NaN
# 進め! キノピオ隊長_quarter                                                     NaN
# OCTOPATH TRAVELER_quarter                                              NaN
# Nintendo Labo Toy-Con 01: Variety Kit_quarter                          NaN
# マリオカート ライブ ホームサーキット_quarter                                            NaN
# MARVEL ULTIMATE ALLIANCE 3: The Black Order_qua...                     NaN
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter                               NaN
# ゼノブレイド2_quarter                                                        NaN
# メトロイド ドレッド_quarter                                                     NaN
# ナビつき！ つくってわかる はじめてゲームプログラミング_quarter                                   NaN
# やわらかあたま塾 いっしょにあたまのストレッチ_quarter                                        NaN
# ASTRAL CHAIN_quarter                                                   NaN
# ファイアーエムブレム エンゲージ_quarter                                               NaN
# おすそわける　メイド イン ワリオ_quarter                                              NaN
# メトロイドプライム リマスタード_quarter                                               NaN
# ヨッシークラフトワールド_quarter                                                   NaN
# 星のカービィ Wii デラックス_quarter                                               NaN
# マリオvs.ドンキーコング_quarter                                                  NaN
# ドンキーコング リターンズ HD_quarter                                               NaN
# プリンセスピーチ Showtime!_quarter                                             NaN
# おすそわける メイド イン ワリオ_quarter                                              NaN
# 1-2-Switch_quarter                                                     NaN
# ポッ拳 ポッケン トーナメント DX_quarter                                             NaN
# ポケモン不思議のダンジョン 救助隊DX_quarter                                            NaN
#
#                                                     p値(hard_total_sales)  \
# マリオカート8 デラックス_quarter                                             0.0000
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                                      0.3248
# スーパーマリオ オデッセイ_quarter                                             0.2319
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                                     0.0916
# あつまれ どうぶつの森_quarter                                               0.4201
# New スーパーマリオブラザーズU デラックス_quarter                                   0.7022
# スーパーマリオパーティ_quarter                                               0.0812
# Splatoon2_quarter                                                 0.5068
# リングフィット アドベンチャー_quarter                                           0.0018
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                                0.7499
# Nintendo Switch Sports_quarter                                    0.3247
# マリオパーティ スーパースターズ_quarter                                          0.0263
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter                  0.3702
# ポケットモンスター ソード・シールド_quarter                                        0.4179
# ルイージマンション3_quarter                                                0.1393
# ポケットモンスター スカーレット・バイオレット_quarter                                   0.0726
# スーパーマリオメーカー2_quarter                                              0.8813
# 星のカービィ ディスカバリー_quarter                                            0.9669
# 世界のアソビ大全51_quarter                                                0.8383
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                                   0.8382
# Splatoon3_quarter                                                 0.9040
# ミートピア_quarter                                                     0.8069
# ARMS_quarter                                                      0.5382
# ゼルダの伝説 夢をみる島_quarter                                              0.9758
# ドンキーコング トロピカルフリーズ_quarter                                         0.7013
# ペーパーマリオRPG_quarter                                                0.7693
# ルイージマンション2 HD_quarter                                             0.8369
# ルイージマンション３_quarter                                                0.1975
# Super Mario Bros. Wonder_quarter                                  0.1368
# マリオテニス エース_quarter                                                0.5935
# マリオゴルフ スーパーラッシュ_quarter                                           0.7179
# New ポケモンスナップ_quarter                                              0.7730
# Xenoblade Definitive Edition_quarter                              0.6830
# マリオストライカーズ バトルリーグ_quarter                                         0.7923
# Pokmon LEGENDS アルセウス_quarter                                      0.8504
# ゼノブレイド3_quarter                                                   0.7007
# 星のカービィ スターアライズ_quarter                                            0.6804
# ゼルダの伝説 スカイウォードソード HD_quarter                                      0.6731
# スーパーマリオ 3Dコレクション_quarter                                          0.7758
# ファイアーエムブレム 風花雪月_quarter                                           0.7837
# Pikmin 4_quarter                                                  0.9298
# ペーパーマリオ オリガミキング_quarter                                           0.8979
# ゼルダの伝説 知恵のかりもの_quarter                                            0.7677
# スーパー マリオパーティ ジャンボリー_quarter                                          NaN
# ベヨネッタ3_quarter                                                       NaN
# ピクミン3 デラックス_quarter                                                  NaN
# マリオ&ルイージRPG ブラザーシップ!_quarter                                         NaN
# ゼルダ無双 厄災の黙示録_quarter                                                 NaN
# スーパーマリオRPG_quarter                                                   NaN
# 進め! キノピオ隊長_quarter                                                   NaN
# OCTOPATH TRAVELER_quarter                                            NaN
# Nintendo Labo Toy-Con 01: Variety Kit_quarter                        NaN
# マリオカート ライブ ホームサーキット_quarter                                          NaN
# MARVEL ULTIMATE ALLIANCE 3: The Black Order_qua...                   NaN
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter                             NaN
# ゼノブレイド2_quarter                                                      NaN
# メトロイド ドレッド_quarter                                                   NaN
# ナビつき！ つくってわかる はじめてゲームプログラミング_quarter                                 NaN
# やわらかあたま塾 いっしょにあたまのストレッチ_quarter                                      NaN
# ASTRAL CHAIN_quarter                                                 NaN
# ファイアーエムブレム エンゲージ_quarter                                             NaN
# おすそわける　メイド イン ワリオ_quarter                                            NaN
# メトロイドプライム リマスタード_quarter                                             NaN
# ヨッシークラフトワールド_quarter                                                 NaN
# 星のカービィ Wii デラックス_quarter                                             NaN
# マリオvs.ドンキーコング_quarter                                                NaN
# ドンキーコング リターンズ HD_quarter                                             NaN
# プリンセスピーチ Showtime!_quarter                                           NaN
# おすそわける メイド イン ワリオ_quarter                                            NaN
# 1-2-Switch_quarter                                                   NaN
# ポッ拳 ポッケン トーナメント DX_quarter                                           NaN
# ポケモン不思議のダンジョン 救助隊DX_quarter                                          NaN
#
#                                                     データ数(再掲)    総販売量
# マリオカート8 デラックス_quarter                                   31.0  6819.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter                 2.0  1465.0
# ゼノブレイド2_quarter                                          2.0   131.0
# メトロイド ドレッド_quarter                                       2.0   290.0
# ナビつき！ つくってわかる はじめてゲームプログラミング_quarter                     2.0   106.0
# やわらかあたま塾 いっしょにあたまのストレッチ_quarter                          2.0   159.0
# ASTRAL CHAIN_quarter                                     2.0   108.0
# ファイアーエムブレム エンゲージ_quarter                                 1.0   161.0
# おすそわける　メイド イン ワリオ_quarter                                1.0   124.0
# メトロイドプライム リマスタード_quarter                                 1.0   109.0
# ヨッシークラフトワールド_quarter                                     1.0   111.0
# 星のカービィ Wii デラックス_quarter                                 1.0   146.0
# マリオvs.ドンキーコング_quarter                                    1.0   112.0
# ドンキーコング リターンズ HD_quarter                                 1.0   127.0
# プリンセスピーチ Showtime!_quarter                               1.0   122.0
# おすそわける メイド イン ワリオ_quarter                                1.0   127.0
# 1-2-Switch_quarter                                       1.0   134.0
# ポッ拳 ポッケン トーナメント DX_quarter                               1.0   116.0
# ポケモン不思議のダンジョン 救助隊DX_quarter                              1.0   126.0

# %%
# 分析の信頼度を上げるためにデータ数が一定以上あること、販売量が大きいものでフィルタする。
# 　"データ数" >= 4 のタイトルを残す（とりあえず1年分）

# 例外になりそうなもの（データ数が少なくても販売量が大きいタイトル）
# データ数 3 販売量 901 スーパーマリオ 3Dコレクション
# データ数 2 販売量 1465 スーパーマリオ ポケットモンスター ブリリアントダイヤモンド・シャイニングパール

# %%
# データ数でフィルタ
def get_titles_filtered_by_count(summary_df, min_count=4):
    """
    min_count以上のデータ数で記述統計をフィルタして表示
    return: フィルタ後に残ったタイトルのリスト
    """
    filtered_titles_by_count = summary_df[summary_df["データ数"] >= min_count].index.tolist()
    # display(selected_titles)  # 一覧表示
    display(summary_df.loc[filtered_titles_by_count].sort_values("データ数", ascending=False))
    return filtered_titles_by_count

filtered_titles_by_count = get_titles_filtered_by_count(summary_df, min_count=4)
display(filtered_titles_by_count)
# Out:
#                                                   データ数       平均    中央値  \
# マリオカート8 デラックス_quarter                             31.0  219.968  181.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                      24.0  132.667  121.5
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                     20.0  181.250  128.5
# スーパーマリオ オデッセイ_quarter                             20.0  146.450  110.5
# あつまれ どうぶつの森_quarter                               18.0  265.722  133.5
# スーパーマリオパーティ_quarter                               15.0  137.733  110.0
# New スーパーマリオブラザーズU デラックス_quarter                   15.0  116.267  125.0
# Splatoon2_quarter                                 12.0  110.917  109.5
# リングフィット アドベンチャー_quarter                           12.0  128.167  116.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                10.0  134.800   93.0
# Nintendo Switch Sports_quarter                    10.0  162.700  128.5
# マリオパーティ スーパースターズ_quarter                           9.0  155.444  119.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter   8.0  181.625   83.0
# ポケットモンスター ソード・シールド_quarter                         8.0  303.500  132.0
# ポケットモンスター スカーレット・バイオレット_quarter                    7.0  382.714  113.0
# ルイージマンション3_quarter                                 7.0  189.714  142.0
# スーパーマリオメーカー2_quarter                               6.0  119.167  127.0
# 星のカービィ ディスカバリー_quarter                             6.0  125.333   96.0
# 世界のアソビ大全51_quarter                                 5.0   84.400   81.0
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                    5.0  434.600   99.0
# Splatoon3_quarter                                  5.0  239.200  104.0
# ドンキーコング トロピカルフリーズ_quarter                          4.0   56.250   34.0
# マリオテニス エース_quarter                                 4.0   66.000   57.5
# Super Mario Bros. Wonder_quarter                   4.0  401.000  177.5
# ルイージマンション2 HD_quarter                              4.0   47.000   30.5
# ペーパーマリオRPG_quarter                                 4.0   52.500   15.0
# ゼルダの伝説 夢をみる島_quarter                               4.0  137.250  108.5
# New ポケモンスナップ_quarter                               4.0   60.000   14.5
# ARMS_quarter                                       4.0   46.250   25.0
# ミートピア_quarter                                      4.0   42.000   29.5
# マリオゴルフ スーパーラッシュ_quarter                            4.0   58.750   46.0
# Xenoblade Definitive Edition_quarter               4.0   38.000    8.0
# Pokmon LEGENDS アルセウス_quarter                       4.0  370.750   99.5
# マリオストライカーズ バトルリーグ_quarter                          4.0   63.500   28.0
# ルイージマンション３_quarter                                 4.0  261.000  148.0
#
#                                                      標準偏差    最小値     最大値  \
# マリオカート8 デラックス_quarter                             105.269   85.0   462.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                       56.030   24.0   276.0
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                     246.249   36.0  1208.0
# スーパーマリオ オデッセイ_quarter                             186.181   24.0   907.0
# あつまれ どうぶつの森_quarter                               332.687   39.0  1177.0
# スーパーマリオパーティ_quarter                               119.373   32.0   530.0
# New スーパーマリオブラザーズU デラックス_quarter                    73.238   25.0   331.0
# Splatoon2_quarter                                  87.474   31.0   361.0
# リングフィット アドベンチャー_quarter                            74.693   16.0   284.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                153.783   31.0   559.0
# Nintendo Switch Sports_quarter                    125.332   53.0   484.0
# マリオパーティ スーパースターズ_quarter                          147.958   58.0   543.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter  332.973   20.0  1000.0
# ポケットモンスター ソード・シールド_quarter                        527.944   38.0  1606.0
# ポケットモンスター スカーレット・バイオレット_quarter                   741.204   41.0  2061.0
# ルイージマンション3_quarter                                174.602   38.0   537.0
# スーパーマリオメーカー2_quarter                               79.300   24.0   242.0
# 星のカービィ ディスカバリー_quarter                             85.364   34.0   265.0
# 世界のアソビ大全51_quarter                                 22.390   52.0   108.0
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                   792.359   33.0  1851.0
# Splatoon3_quarter                                 317.058   25.0   790.0
# ドンキーコング トロピカルフリーズ_quarter                          56.694   17.0   140.0
# マリオテニス エース_quarter                                 55.359   11.0   138.0
# Super Mario Bros. Wonder_quarter                  533.783   53.0  1196.0
# ルイージマンション2 HD_quarter                              49.538    8.0   119.0
# ペーパーマリオRPG_quarter                                 82.533    4.0   176.0
# ゼルダの伝説 夢をみる島_quarter                              124.548   19.0   313.0
# New ポケモンスナップ_quarter                               98.146    4.0   207.0
# ARMS_quarter                                       47.989   17.0   118.0
# ミートピア_quarter                                      43.012    5.0   104.0
# マリオゴルフ スーパーラッシュ_quarter                            54.328    9.0   134.0
# Xenoblade Definitive Edition_quarter               62.695    4.0   132.0
# Pokmon LEGENDS アルセウス_quarter                      597.132   20.0  1264.0
# マリオストライカーズ バトルリーグ_quarter                          85.590    7.0   191.0
# ルイージマンション３_quarter                                248.499  115.0   633.0
#
#                                                   変動係数(CV)  \
# マリオカート8 デラックス_quarter                                0.479
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                         0.422
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                        1.359
# スーパーマリオ オデッセイ_quarter                                1.271
# あつまれ どうぶつの森_quarter                                  1.252
# スーパーマリオパーティ_quarter                                  0.867
# New スーパーマリオブラザーズU デラックス_quarter                      0.630
# Splatoon2_quarter                                    0.789
# リングフィット アドベンチャー_quarter                              0.583
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                   1.141
# Nintendo Switch Sports_quarter                       0.770
# マリオパーティ スーパースターズ_quarter                             0.952
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter     1.833
# ポケットモンスター ソード・シールド_quarter                           1.740
# ポケットモンスター スカーレット・バイオレット_quarter                      1.937
# ルイージマンション3_quarter                                   0.920
# スーパーマリオメーカー2_quarter                                 0.665
# 星のカービィ ディスカバリー_quarter                               0.681
# 世界のアソビ大全51_quarter                                   0.265
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                      1.823
# Splatoon3_quarter                                    1.325
# ドンキーコング トロピカルフリーズ_quarter                            1.008
# マリオテニス エース_quarter                                   0.839
# Super Mario Bros. Wonder_quarter                     1.331
# ルイージマンション2 HD_quarter                                1.054
# ペーパーマリオRPG_quarter                                   1.572
# ゼルダの伝説 夢をみる島_quarter                                 0.907
# New ポケモンスナップ_quarter                                 1.636
# ARMS_quarter                                         1.038
# ミートピア_quarter                                        1.024
# マリオゴルフ スーパーラッシュ_quarter                              0.925
# Xenoblade Definitive Edition_quarter                 1.650
# Pokmon LEGENDS アルセウス_quarter                         1.611
# マリオストライカーズ バトルリーグ_quarter                            1.348
# ルイージマンション３_quarter                                   0.952
#
#                                                   相関係数(hard_total_sales)  \
# マリオカート8 デラックス_quarter                                              0.831
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                                       0.210
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                                      0.387
# スーパーマリオ オデッセイ_quarter                                              0.280
# あつまれ どうぶつの森_quarter                                                0.203
# スーパーマリオパーティ_quarter                                                0.464
# New スーパーマリオブラザーズU デラックス_quarter                                    0.108
# Splatoon2_quarter                                                 -0.213
# リングフィット アドベンチャー_quarter                                            0.799
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                                 0.116
# Nintendo Switch Sports_quarter                                     0.348
# マリオパーティ スーパースターズ_quarter                                           0.728
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter                   0.368
# ポケットモンスター ソード・シールド_quarter                                         0.335
# ポケットモンスター スカーレット・バイオレット_quarter                                    0.712
# ルイージマンション3_quarter                                                 0.618
# スーパーマリオメーカー2_quarter                                              -0.079
# 星のカービィ ディスカバリー_quarter                                            -0.022
# 世界のアソビ大全51_quarter                                                -0.127
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                                    0.127
# Splatoon3_quarter                                                 -0.075
# ドンキーコング トロピカルフリーズ_quarter                                         -0.299
# マリオテニス エース_quarter                                                -0.406
# Super Mario Bros. Wonder_quarter                                   0.863
# ルイージマンション2 HD_quarter                                             -0.163
# ペーパーマリオRPG_quarter                                                -0.231
# ゼルダの伝説 夢をみる島_quarter                                              -0.024
# New ポケモンスナップ_quarter                                              -0.227
# ARMS_quarter                                                      -0.462
# ミートピア_quarter                                                     -0.193
# マリオゴルフ スーパーラッシュ_quarter                                           -0.282
# Xenoblade Definitive Edition_quarter                              -0.317
# Pokmon LEGENDS アルセウス_quarter                                      -0.150
# マリオストライカーズ バトルリーグ_quarter                                         -0.208
# ルイージマンション３_quarter                                                -0.802
#
#                                                   p値(hard_total_sales)  \
# マリオカート8 デラックス_quarter                                           0.0000
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                                    0.3248
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                                   0.0916
# スーパーマリオ オデッセイ_quarter                                           0.2319
# あつまれ どうぶつの森_quarter                                             0.4201
# スーパーマリオパーティ_quarter                                             0.0812
# New スーパーマリオブラザーズU デラックス_quarter                                 0.7022
# Splatoon2_quarter                                               0.5068
# リングフィット アドベンチャー_quarter                                         0.0018
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                              0.7499
# Nintendo Switch Sports_quarter                                  0.3247
# マリオパーティ スーパースターズ_quarter                                        0.0263
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter                0.3702
# ポケットモンスター ソード・シールド_quarter                                      0.4179
# ポケットモンスター スカーレット・バイオレット_quarter                                 0.0726
# ルイージマンション3_quarter                                              0.1393
# スーパーマリオメーカー2_quarter                                            0.8813
# 星のカービィ ディスカバリー_quarter                                          0.9669
# 世界のアソビ大全51_quarter                                              0.8383
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                                 0.8382
# Splatoon3_quarter                                               0.9040
# ドンキーコング トロピカルフリーズ_quarter                                       0.7013
# マリオテニス エース_quarter                                              0.5935
# Super Mario Bros. Wonder_quarter                                0.1368
# ルイージマンション2 HD_quarter                                           0.8369
# ペーパーマリオRPG_quarter                                              0.7693
# ゼルダの伝説 夢をみる島_quarter                                            0.9758
# New ポケモンスナップ_quarter                                            0.7730
# ARMS_quarter                                                    0.5382
# ミートピア_quarter                                                   0.8069
# マリオゴルフ スーパーラッシュ_quarter                                         0.7179
# Xenoblade Definitive Edition_quarter                            0.6830
# Pokmon LEGENDS アルセウス_quarter                                    0.8504
# マリオストライカーズ バトルリーグ_quarter                                       0.7923
# ルイージマンション３_quarter                                              0.1975
#
#                                                   データ数(再掲)    総販売量
# マリオカート8 デラックス_quarter                                 31.0  6819.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                          24.0  3184.0
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                         20.0  3625.0
# スーパーマリオ オデッセイ_quarter                                 20.0  2929.0
# あつまれ どうぶつの森_quarter                                   18.0  4783.0
# スーパーマリオパーティ_quarter                                   15.0  2066.0
# New スーパーマリオブラザーズU デラックス_quarter                       15.0  1744.0
# Splatoon2_quarter                                     12.0  1331.0
# リングフィット アドベンチャー_quarter                               12.0  1538.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                    10.0  1348.0
# Nintendo Switch Sports_quarter                        10.0  1627.0
# マリオパーティ スーパースターズ_quarter                               9.0  1399.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter       8.0  1453.0
# ポケットモンスター ソード・シールド_quarter                             8.0  2428.0
# ポケットモンスター スカーレット・バイオレット_quarter                        7.0  2679.0
# ルイージマンション3_quarter                                     7.0  1328.0
# スーパーマリオメーカー2_quarter                                   6.0   715.0
# 星のカービィ ディスカバリー_quarter                                 6.0   752.0
# 世界のアソビ大全51_quarter                                     5.0   422.0
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                        5.0  2173.0
# Splatoon3_quarter                                      5.0  1196.0
# ドンキーコング トロピカルフリーズ_quarter                              4.0   225.0
# マリオテニス エース_quarter                                     4.0   264.0
# Super Mario Bros. Wonder_quarter                       4.0  1604.0
# ルイージマンション2 HD_quarter                                  4.0   188.0
# ペーパーマリオRPG_quarter                                     4.0   210.0
# ゼルダの伝説 夢をみる島_quarter                                   4.0   549.0
# New ポケモンスナップ_quarter                                   4.0   240.0
# ARMS_quarter                                           4.0   185.0
# ミートピア_quarter                                          4.0   168.0
# マリオゴルフ スーパーラッシュ_quarter                                4.0   235.0
# Xenoblade Definitive Edition_quarter                   4.0   152.0
# Pokmon LEGENDS アルセウス_quarter                           4.0  1483.0
# マリオストライカーズ バトルリーグ_quarter                              4.0   254.0
# ルイージマンション３_quarter                                     4.0  1044.0
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ルイージマンション3_quarter',
#  '世界のアソビ大全51_quarter',
#  'Splatoon2_quarter',
#  'Xenoblade Definitive Edition_quarter',
#  'スーパーマリオメーカー2_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'Splatoon3_quarter',
#  'Nintendo Switch Sports_quarter',
#  '星のカービィ ディスカバリー_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'マリオストライカーズ バトルリーグ_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'New ポケモンスナップ_quarter',
#  'マリオゴルフ スーパーラッシュ_quarter',
#  'ミートピア_quarter',
#  'ARMS_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'ゼルダの伝説 夢をみる島_quarter',
#  'ペーパーマリオRPG_quarter',
#  'ルイージマンション2 HD_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'マリオテニス エース_quarter',
#  'ドンキーコング トロピカルフリーズ_quarter',
#  'ルイージマンション３_quarter']

# %%
def simple_OLS(df, y_col: str, X_cols: list):
    y = df[y_col]
    X = df[X_cols]
    X = sm.add_constant(X)
    model = sm.OLS(y, X)
    res = model.fit()
    print(res.summary())

# %%
# 全てのタイトルを説明変数にしてOLS
y_col = "hard_total_sales"
X_cols= [c for c in selected_cols if c != "hard_total_sales"]
simple_OLS(selected_df, y_col, X_cols)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       hard_total_sales   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sat, 08 Nov 2025   Prob (F-statistic):                nan
# Time:                        07:04:38   Log-Likelihood:                 886.50
# No. Observations:                  33   AIC:                            -1707.
# Df Residuals:                       0   BIC:                            -1658.
# Df Model:                          32
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# const                                                   0.0361        inf          0        nan         nan         nan
# Q_2                                                    -0.0374        inf         -0        nan         nan         nan
# Q_3                                                     0.0144        inf          0        nan         nan         nan
# Q_4                                                     0.0256        inf          0        nan         nan         nan
# あつまれ どうぶつの森_quarter                                     0.2702        inf          0        nan         nan         nan
# マリオカート8 デラックス_quarter                                   0.1977        inf          0        nan         nan         nan
# スーパーマリオ 3Dコレクション_quarter                                0.3535        inf          0        nan         nan         nan
# リングフィット アドベンチャー_quarter                                 0.7030        inf          0        nan         nan         nan
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                            0.9925        inf          0        nan         nan         nan
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                           0.2215        inf          0        nan         nan         nan
# スーパーマリオパーティ_quarter                                     0.1533        inf          0        nan         nan         nan
# New スーパーマリオブラザーズU デラックス_quarter                        -0.0831        inf         -0        nan         nan         nan
# ペーパーマリオ オリガミキング_quarter                                 0.0570        inf          0        nan         nan         nan
# ポケットモンスター ソード・シールド_quarter                              0.0725        inf          0        nan         nan         nan
# ゼルダ無双 厄災の黙示録_quarter                                    0.2804        inf          0        nan         nan         nan
# スーパーマリオ オデッセイ_quarter                                   0.2884        inf          0        nan         nan         nan
# ルイージマンション3_quarter                                      0.2024        inf          0        nan         nan         nan
# 世界のアソビ大全51_quarter                                      0.0940        inf          0        nan         nan         nan
# ピクミン3 デラックス_quarter                                     0.1944        inf          0        nan         nan         nan
# Splatoon2_quarter                                       0.5474        inf          0        nan         nan         nan
# Xenoblade Definitive Edition_quarter                    0.0401        inf          0        nan         nan         nan
# スーパーマリオメーカー2_quarter                                    0.6663        inf          0        nan         nan         nan
# マリオカート ライブ ホームサーキット_quarter                             0.1016        inf          0        nan         nan         nan
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter        0.2585        inf          0        nan         nan         nan
# ポケットモンスター スカーレット・バイオレット_quarter                         0.1268        inf          0        nan         nan         nan
# Splatoon3_quarter                                       0.0290        inf          0        nan         nan         nan
# Nintendo Switch Sports_quarter                          0.5455        inf          0        nan         nan         nan
# 星のカービィ ディスカバリー_quarter                                  0.0856        inf          0        nan         nan         nan
# マリオパーティ スーパースターズ_quarter                               -0.0493        inf         -0        nan         nan         nan
# マリオストライカーズ バトルリーグ_quarter                               0.1758        inf          0        nan         nan         nan
# Pokmon LEGENDS アルセウス_quarter                            0.0196        inf          0        nan         nan         nan
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                      0.0898        inf          0        nan         nan         nan
# ゼノブレイド3_quarter                                        -0.0033        inf         -0        nan         nan         nan
# ファイアーエムブレム エンゲージ_quarter                                0.1133        inf          0        nan         nan         nan
# 星のカービィ Wii デラックス_quarter                                0.1027        inf          0        nan         nan         nan
# メトロイドプライム リマスタード_quarter                                0.0767        inf          0        nan         nan         nan
# ベヨネッタ3_quarter                                          0.0078        inf          0        nan         nan         nan
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter                0.3925        inf          0        nan         nan         nan
# ゼルダの伝説 スカイウォードソード HD_quarter                           -0.2484        inf         -0        nan         nan         nan
# メトロイド ドレッド_quarter                                      0.0770        inf          0        nan         nan         nan
# New ポケモンスナップ_quarter                                    0.8455        inf          0        nan         nan         nan
# マリオゴルフ スーパーラッシュ_quarter                                 0.5162        inf          0        nan         nan         nan
# ミートピア_quarter                                           0.4106        inf          0        nan         nan         nan
# やわらかあたま塾 いっしょにあたまのストレッチ_quarter                         0.0361        inf          0        nan         nan         nan
# おすそわける メイド イン ワリオ_quarter                               0.0007        inf          0        nan         nan         nan
# ナビつき！ つくってわかる はじめてゲームプログラミング_quarter                    0.0284        inf          0        nan         nan         nan
# ARMS_quarter                                            0.0918        inf          0        nan         nan         nan
# 1-2-Switch_quarter                                     -0.1566        inf         -0        nan         nan         nan
# ゼノブレイド2_quarter                                         1.2341        inf          0        nan         nan         nan
# 星のカービィ スターアライズ_quarter                                 -0.1337        inf         -0        nan         nan         nan
# ポッ拳 ポッケン トーナメント DX_quarter                             -0.1356        inf         -0        nan         nan         nan
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                         0.1928        inf          0        nan         nan         nan
# Pikmin 4_quarter                                       -0.2141        inf         -0        nan         nan         nan
# ゼルダの伝説 夢をみる島_quarter                                    0.1659        inf          0        nan         nan         nan
# ファイアーエムブレム 風花雪月_quarter                                 0.1432        inf          0        nan         nan         nan
# ASTRAL CHAIN_quarter                                    0.0047        inf          0        nan         nan         nan
# MARVEL ULTIMATE ALLIANCE 3: The Black Order_quarter     0.0037        inf          0        nan         nan         nan
# ゼルダの伝説 知恵のかりもの_quarter                                  0.3173        inf          0        nan         nan         nan
# ペーパーマリオRPG_quarter                                      0.8054        inf          0        nan         nan         nan
# ルイージマンション2 HD_quarter                                   0.5732        inf          0        nan         nan         nan
# スーパー マリオパーティ ジャンボリー_quarter                             0.1440        inf          0        nan         nan         nan
# Super Mario Bros. Wonder_quarter                        0.3232        inf          0        nan         nan         nan
# マリオ&ルイージRPG ブラザーシップ!_quarter                            0.0721        inf          0        nan         nan         nan
# マリオテニス エース_quarter                                     -0.9421        inf         -0        nan         nan         nan
# ドンキーコング トロピカルフリーズ_quarter                               2.1045        inf          0        nan         nan         nan
# スーパーマリオRPG_quarter                                      0.0973        inf          0        nan         nan         nan
# プリンセスピーチ Showtime!_quarter                             -0.1255        inf         -0        nan         nan         nan
# マリオvs.ドンキーコング_quarter                                  -0.1152        inf         -0        nan         nan         nan
# ドンキーコング リターンズ HD_quarter                               -0.1419        inf         -0        nan         nan         nan
# 進め! キノピオ隊長_quarter                                      0.0122        inf          0        nan         nan         nan
# OCTOPATH TRAVELER_quarter                               0.0147        inf          0        nan         nan         nan
# ヨッシークラフトワールド_quarter                                   -0.0550        inf         -0        nan         nan         nan
# Nintendo Labo Toy-Con 01: Variety Kit_quarter           0.0173        inf          0        nan         nan         nan
# ルイージマンション３_quarter                                     -0.4796        inf         -0        nan         nan         nan
# おすそわける　メイド イン ワリオ_quarter                               0.0348        inf          0        nan         nan         nan
# ポケモン不思議のダンジョン 救助隊DX_quarter                            -0.1159        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                       24.889   Durbin-Watson:                   1.592
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.350
# Skew:                           1.636   Prob(JB):                     9.57e-13
# Kurtosis:                       8.436   Cond. No.                         75.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid

# %%
# 説明変数が多すぎて残差自由度が０になっているので、回帰モデルとして使えない

# %%
# データ数でフィルタ（>=4）したタイトルを説明変数にしてOLS
simple_OLS(selected_df, y_col, filtered_titles_by_count)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       hard_total_sales   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Sat, 08 Nov 2025   Prob (F-statistic):                nan
# Time:                        07:04:38   Log-Likelihood:                 859.00
# No. Observations:                  33   AIC:                            -1652.
# Df Residuals:                       0   BIC:                            -1603.
# Df Model:                          32
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# const                                                0.8439        inf          0        nan         nan         nan
# あつまれ どうぶつの森_quarter                                 -2.1820        inf         -0        nan         nan         nan
# マリオカート8 デラックス_quarter                               -0.3548        inf         -0        nan         nan         nan
# リングフィット アドベンチャー_quarter                             12.1869        inf          0        nan         nan         nan
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                         0.9897        inf          0        nan         nan         nan
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                        1.5394        inf          0        nan         nan         nan
# スーパーマリオパーティ_quarter                                 -2.3038        inf         -0        nan         nan         nan
# New スーパーマリオブラザーズU デラックス_quarter                      0.2510        inf          0        nan         nan         nan
# ポケットモンスター ソード・シールド_quarter                          -1.2982        inf         -0        nan         nan         nan
# スーパーマリオ オデッセイ_quarter                                0.5543        inf          0        nan         nan         nan
# ルイージマンション3_quarter                                   0.0399        inf          0        nan         nan         nan
# 世界のアソビ大全51_quarter                                 -16.9907        inf         -0        nan         nan         nan
# Splatoon2_quarter                                    0.6025        inf          0        nan         nan         nan
# Xenoblade Definitive Edition_quarter                22.6130        inf          0        nan         nan         nan
# スーパーマリオメーカー2_quarter                                 0.9369        inf          0        nan         nan         nan
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter     0.0762        inf          0        nan         nan         nan
# ポケットモンスター スカーレット・バイオレット_quarter                     -0.3893        inf         -0        nan         nan         nan
# Splatoon3_quarter                                    0.0186        inf          0        nan         nan         nan
# Nintendo Switch Sports_quarter                       2.2124        inf          0        nan         nan         nan
# 星のカービィ ディスカバリー_quarter                               1.4664        inf          0        nan         nan         nan
# マリオパーティ スーパースターズ_quarter                            -0.3425        inf         -0        nan         nan         nan
# マリオストライカーズ バトルリーグ_quarter                           -4.9833        inf         -0        nan         nan         nan
# Pokmon LEGENDS アルセウス_quarter                         1.1295        inf          0        nan         nan         nan
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                  -0.2500        inf         -0        nan         nan         nan
# New ポケモンスナップ_quarter                                 2.3694        inf          0        nan         nan         nan
# マリオゴルフ スーパーラッシュ_quarter                             -8.1621        inf         -0        nan         nan         nan
# ミートピア_quarter                                        0.0774        inf          0        nan         nan         nan
# ARMS_quarter                                         1.7452        inf          0        nan         nan         nan
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                      0.2422        inf          0        nan         nan         nan
# ゼルダの伝説 夢をみる島_quarter                                 0.3421        inf          0        nan         nan         nan
# ペーパーマリオRPG_quarter                                  -6.1619        inf         -0        nan         nan         nan
# ルイージマンション2 HD_quarter                               10.8710        inf          0        nan         nan         nan
# Super Mario Bros. Wonder_quarter                     0.3323        inf          0        nan         nan         nan
# マリオテニス エース_quarter                                  -0.7840        inf         -0        nan         nan         nan
# ドンキーコング トロピカルフリーズ_quarter                            2.3888        inf          0        nan         nan         nan
# ルイージマンション３_quarter                                   3.5324        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                        4.391   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.111   Jarque-Bera (JB):                3.631
# Skew:                           0.812   Prob(JB):                        0.163
# Kurtosis:                       2.980   Cond. No.                         914.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid

# %%
# 多重共線性の確認（VIF）
def compute_vif(df):
    X = df.fillna(0).copy()
    X = sm.add_constant(X, has_constant='add') # 定数項

    
    res = []
    for i in range(1, X.shape[1]):  # const列は除外
        vif_val = variance_inflation_factor(X.values, i)
        res.append({
            "feature": X.columns[i],
            "VIF": vif_val
        })

    res_df = pd.DataFrame(res)
    res_df = res_df.sort_values("VIF", ascending=False).reset_index(drop=True)
    return res_df

# %%
print("Variance Inflation Factor")
titlea_for_vif = [col for col in df.columns if "_quarter" in col]
compute_vif(df[titlea_for_vif])
# Out:
# Variance Inflation Factor
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                                               feature  VIF
# 0                                 あつまれ どうぶつの森_quarter  inf
# 1                               マリオカート8 デラックス_quarter  inf
# 2   MARVEL ULTIMATE ALLIANCE 3: The Black Order_qu...  inf
# 3                                ASTRAL CHAIN_quarter  inf
# 4                             ファイアーエムブレム 風花雪月_quarter  inf
# 5                                ゼルダの伝説 夢をみる島_quarter  inf
# 6                                    Pikmin 4_quarter  inf
# 7                     ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter  inf
# 8                          ポッ拳 ポッケン トーナメント DX_quarter  inf
# 9                              星のカービィ スターアライズ_quarter  inf
# 10                                    ゼノブレイド2_quarter  inf
# 11                                 1-2-Switch_quarter  inf
# 12                                       ARMS_quarter  inf
# 13               ナビつき！ つくってわかる はじめてゲームプログラミング_quarter  inf
# 14                          おすそわける メイド イン ワリオ_quarter  inf
# 15                    やわらかあたま塾 いっしょにあたまのストレッチ_quarter  inf
# 16                                      ミートピア_quarter  inf
# 17                             ゼルダの伝説 知恵のかりもの_quarter  inf
# 18                                 ペーパーマリオRPG_quarter  inf
# 19                              ルイージマンション2 HD_quarter  inf
# 20                           ドンキーコング リターンズ HD_quarter  inf
# 21                          おすそわける　メイド イン ワリオ_quarter  inf
# 22                                 ルイージマンション３_quarter  inf
# 23      Nintendo Labo Toy-Con 01: Variety Kit_quarter  inf
# 24                               ヨッシークラフトワールド_quarter  inf
# 25                          OCTOPATH TRAVELER_quarter  inf
# 26                                 進め! キノピオ隊長_quarter  inf
# 27                              マリオvs.ドンキーコング_quarter  inf
# 28                        スーパー マリオパーティ ジャンボリー_quarter  inf
# 29                         プリンセスピーチ Showtime!_quarter  inf
# 30                                 スーパーマリオRPG_quarter  inf
# 31                          ドンキーコング トロピカルフリーズ_quarter  inf
# 32                                 マリオテニス エース_quarter  inf
# 33                       マリオ&ルイージRPG ブラザーシップ!_quarter  inf
# 34                   Super Mario Bros. Wonder_quarter  inf
# 35                            マリオゴルフ スーパーラッシュ_quarter  inf
# 36                               New ポケモンスナップ_quarter  inf
# 37                                 メトロイド ドレッド_quarter  inf
# 38                         ポケットモンスター ソード・シールド_quarter  inf
# 39                                  Splatoon2_quarter  inf
# 40                                ピクミン3 デラックス_quarter  inf
# 41                                 世界のアソビ大全51_quarter  inf
# 42                                 ルイージマンション3_quarter  inf
# 43                              スーパーマリオ オデッセイ_quarter  inf
# 44                               ゼルダ無双 厄災の黙示録_quarter  inf
# 45                            ペーパーマリオ オリガミキング_quarter  inf
# 46                               スーパーマリオメーカー2_quarter  inf
# 47                    New スーパーマリオブラザーズU デラックス_quarter  inf
# 48                                スーパーマリオパーティ_quarter  inf
# 49                      大乱闘スマッシュブラザーズ SPECIAL_quarter  inf
# 50                       ゼルダの伝説 ブレス オブ ザ ワイルド_quarter  inf
# 51                            リングフィット アドベンチャー_quarter  inf
# 52                           スーパーマリオ 3Dコレクション_quarter  inf
# 53               Xenoblade Definitive Edition_quarter  inf
# 54                        マリオカート ライブ ホームサーキット_quarter  inf
# 55                       ゼルダの伝説 スカイウォードソード HD_quarter  inf
# 56                 スーパーマリオ 3Dワールド + フューリーワールド_quarter  inf
# 57           ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter  inf
# 58                                     ベヨネッタ3_quarter  inf
# 59                           メトロイドプライム リマスタード_quarter  inf
# 60                           星のカービィ Wii デラックス_quarter  inf
# 61                           ファイアーエムブレム エンゲージ_quarter  inf
# 62                                    ゼノブレイド3_quarter  inf
# 63                       Pokmon LEGENDS アルセウス_quarter  inf
# 64   ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter  inf
# 65                          マリオストライカーズ バトルリーグ_quarter  inf
# 66                           マリオパーティ スーパースターズ_quarter  inf
# 67                             星のカービィ ディスカバリー_quarter  inf
# 68                     Nintendo Switch Sports_quarter  inf
# 69                                  Splatoon3_quarter  inf
# 70                    ポケットモンスター スカーレット・バイオレット_quarter  inf
# 71                        ポケモン不思議のダンジョン 救助隊DX_quarter  inf

# %%
# 四半期のデータでは、ローンチ前や飽きられた後に販売量が落ち込んだデータが０になる。そのため、有効なデータの重なりが少なく、vifは無限大。
# vifを取っても、思った以上に参考にならない結果。

# %%
# OLS の結果 -> 
# 各タイトルのデータ数が少ない、かつタイトル数が多すぎる。自由度が小さくなって、過学習。
# 四半期ベースのデータので、データ数は増やせない。。。
# このままでは、四半期数に対してタイトル数が多いので、何をしても過学習になる。
# とりあえず、全タイトルを使って、Lasso回帰とRidge回帰とその併用(ElasticNet)をためしてみる。
# その後、データ数でフィルタリングしたタイトルのみで同じ処理をしてみる。

# %%
def _adjusted_r2(r2, n, p_eff):
    """
    調整R2の計算
    """
    denom = (n - p_eff - 1)  # 残差の自由度
    if denom <= 0:
        return np.nan
    return 1.0 - (1.0 - r2) * (n - 1) / denom

def fit_regularized(
    df, y_col, X_cols,
    kind="elasticnet",
    alphas=None,
    l1_ratios=None,
    random_state=0,
    n_splits=4,
    max_iter=1000000,
    nonzero_threshold=1e-12,  # 非ゼロ判定のしきい値
    scoring="r2", 
):
    """
    df:欠損処理済のdf
    kind: "lasso" or "ridge" or "elasticnet"
    return: 結果のdic
    """
    X = df[X_cols].to_numpy()
    y = df[y_col].to_numpy()
    n_samples, n_features = X.shape

    if alphas is None:
        alphas = np.logspace(-4, 2, 30)
    if kind == "elasticnet" and l1_ratios is None:
        l1_ratios = [0.2, 0.4, 0.5, 0.6, 0.8]

    if kind == "lasso":
        base = Lasso(max_iter=max_iter, random_state=random_state)
        param_grid = {"reg__alpha": alphas}
    elif kind == "ridge":
        base = Ridge(max_iter=max_iter, random_state=random_state)
        param_grid = {"reg__alpha": alphas}
    elif kind == "elasticnet":
        base = ElasticNet(max_iter=max_iter, random_state=random_state)
        param_grid = {"reg__alpha": alphas, "reg__l1_ratio": l1_ratios}
    else:
        raise ValueError('kind は "lasso" / "ridge" / "elasticnet" のいずれか')

    steps = [("scaler", StandardScaler()), ("reg", base)]   
    pipe = Pipeline(steps)
    tscv = TimeSeriesSplit(n_splits=n_splits)
    gscv = GridSearchCV(
        estimator=pipe,
        param_grid=param_grid,
        cv=tscv,
        scoring=scoring,
        refit=True
    )
    gscv.fit(X, y)

    best_pipe = gscv.best_estimator_
    reg = best_pipe.named_steps["reg"]
    
    y_hat = best_pipe.predict(X) # 予測（in-sample）
    r2 = r2_score(y, y_hat)
    coef = reg.coef_.copy()
    intercept = reg.intercept_

    is_nonzero = np.abs(coef) > nonzero_threshold
    nonzero_features = [f for f, keep in zip(X_cols, is_nonzero) if keep] # 残すべきタイトル
    n_nonzero = len(nonzero_features)
    p_eff = n_nonzero if kind in ("lasso", "elasticnet") else n_features
    adj_r2 = _adjusted_r2(r2, n_samples, p_eff)

    best_alpha = float(getattr(reg, "alpha", np.nan))
    best_l1 = None
    if kind == "elasticnet":
        best_l1 = float(getattr(reg, "l1_ratio", np.nan))
    elif kind == "lasso":
        best_l1 = 1.0  # LassoはL1=1固定

    # 係数を表示
    coef_table = (
        pd.DataFrame({"feature": X_cols, "coef": coef, "abs_coef": np.abs(coef)})
          .sort_values("abs_coef", ascending=False)
          .reset_index(drop=True)
          .drop(columns=["abs_coef"])
    )

    # 情報を表示
    # if kind in ("lasso", "elasticnet"):
    #     print(f"[{kind.upper()}-TS] Non-zero features ({n_nonzero}):")
    #     for f in nonzero_features:
    #         print(f"  - {f}")

    print(f"[{kind.upper()}-TS] n_samples={n_samples}, n_features={n_features}, nonzero={n_nonzero}/{p_eff}  "
          f"alpha={best_alpha:.6g}"
          + (f", l1_ratio={best_l1:.3f}" if best_l1 is not None and not np.isnan(best_l1) else ""))
    print(f"R2={r2:.4f}, Adjusted R2={adj_r2:.4f}, Intercept={intercept:.4f}")

    return {
        "pipeline": best_pipe, 
        "cv": gscv,
        "model": reg,
        "best_alpha": best_alpha,
        "best_l1_ratio": best_l1,
        "r2": r2,
        "adj_r2": adj_r2,
        "nonzero": n_nonzero,
        "nonzero_features": nonzero_features,
        "coef_table": coef_table,
        "y_pred_in_sample": y_hat,
    }

def fit_Lasso(df, y_col: str, X_cols: list, alphas=None, random_state=0, n_splits=4, max_iter=10000, nonzero_threshold=1e-12):
    return fit_regularized(
        df, y_col, X_cols,
        kind="lasso", alphas=alphas,
        random_state=random_state, n_splits=n_splits, max_iter=max_iter, nonzero_threshold=nonzero_threshold
    )

def fit_Ridge(df, y_col: str, X_cols: list, alphas=None, n_splits=4, max_iter=10000, nonzero_threshold=1e-12):
    return fit_regularized(
        df, y_col, X_cols,
        kind="ridge", alphas=alphas,
        n_splits=n_splits, max_iter=max_iter, nonzero_threshold=nonzero_threshold
    )

def fit_ElasticNet(df, y_col: str, X_cols: list, alphas=None, l1_ratios=None, random_state=0, n_splits=4, max_iter=100000, nonzero_threshold=1e-12):
    return fit_regularized(
        df, y_col, X_cols,
        kind="elasticnet", alphas=alphas, l1_ratios=l1_ratios,
        random_state=random_state, n_splits=n_splits, max_iter=max_iter, nonzero_threshold=nonzero_threshold
    )


def compare_all(df, y_col: str, X_cols: list, random_state=0, n_splits=4, max_iter=100000, nonzero_threshold=1e-12):
    """
    3手法を同一条件の時系列CVで学習し、R²/調整後R²/非ゼロ数を比較。
    ここでのR²は in-sample。汎化性能は res["cv"].cv_results_ を確認。
    return: 結果をまとめたpd.DataFrame
    """
    out = {}
    out["lasso"] = fit_Lasso(df, y_col, X_cols, random_state=random_state, n_splits=n_splits, max_iter=max_iter, nonzero_threshold=nonzero_threshold)
    out["ridge"] = fit_Ridge(df, y_col, X_cols, n_splits=n_splits, max_iter=max_iter, nonzero_threshold=nonzero_threshold)
    out["elasticnet"] = fit_ElasticNet(df, y_col, X_cols, random_state=random_state, n_splits=n_splits, max_iter=max_iter, nonzero_threshold=nonzero_threshold)
    
    def cv_stats(res):
        """GridSearchCVの結果からCV R²の平均と標準偏差を取り出す"""
        mean_cv_r2 = res["cv"].cv_results_["mean_test_score"].max()   # ベストパラメータの平均CV R2
        std_cv_r2  = res["cv"].cv_results_["std_test_score"][res["cv"].cv_results_["mean_test_score"].argmax()] # ベストパラメータのCV R2の標準偏差
        return mean_cv_r2, std_cv_r2

    lasso_cv_mean, lasso_cv_std = cv_stats(out["lasso"])
    ridge_cv_mean, ridge_cv_std = cv_stats(out["ridge"])
    enet_cv_mean, enet_cv_std   = cv_stats(out["elasticnet"])

    summary = pd.DataFrame([
    {
        "model": "Lasso",
        "R2": out["lasso"]["r2"],
        "AdjR2": out["lasso"]["adj_r2"],
        "CV_R2_mean": lasso_cv_mean,
        "CV_R2_std": lasso_cv_std,
        "nonzero": out["lasso"]["nonzero"],
        # "nonzero_titles": ", ".join(out["lasso"]["nonzero_features"])
    },
    {
        "model": "Ridge",
        "R2": out["ridge"]["r2"],
        "AdjR2": out["ridge"]["adj_r2"],
        "CV_R2_mean": ridge_cv_mean,
        "CV_R2_std": ridge_cv_std,
        "nonzero": out["ridge"]["nonzero"],
        # "nonzero_titles": ", ".join(out["ridge"]["nonzero_features"])
    },
    {
        "model": "ElasticNet",
        "R2": out["elasticnet"]["r2"],
        "AdjR2": out["elasticnet"]["adj_r2"],
        "CV_R2_mean": enet_cv_mean,
        "CV_R2_std": enet_cv_std,
        "nonzero": out["elasticnet"]["nonzero"],
        # "nonzero_titles": ", ".join(out["elasticnet"]["nonzero_features"])
    }
])
    print("/// Lasso_nonzero_titles ///")
    display(out["lasso"]["nonzero_features"])
    print("/// Ridge_nonzero_titles ///")
    display(out["ridge"]["nonzero_features"])
    print("/// ElasticNet_nonzero_titles ///")
    display(out["elasticnet"]["nonzero_features"])


    print("\n== compare_all内で実行した結果  R2 AdjR2 は in sample ==")
    return summary

# %%
# 試しにLasso, Ridge, elasticnetで単純に全データで比較
compare_with_nonfilterd = compare_all(selected_df, y_col, X_cols=[c for c in X_cols if c not in ['Q_2', 'Q_3', 'Q_4']], max_iter=100000, nonzero_threshold=1e-12)
display(compare_with_nonfilterd)
print("== こここまで 全データでcompare_all ==")
# Out:
# [LASSO-TS] n_samples=33, n_features=72, nonzero=68/68  alpha=0.000417532, l1_ratio=1.000
# R2=1.0000, Adjusted R2=nan, Intercept=453.8182
# [RIDGE-TS] n_samples=33, n_features=72, nonzero=72/72  alpha=14.8735
# R2=0.9848, Adjusted R2=nan, Intercept=453.8182
# [ELASTICNET-TS] n_samples=33, n_features=72, nonzero=72/72  alpha=0.000161026, l1_ratio=0.600
# R2=1.0000, Adjusted R2=nan, Intercept=453.8182
# /// Lasso_nonzero_titles ///
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'スーパーマリオ 3Dコレクション_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ペーパーマリオ オリガミキング_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'ゼルダ無双 厄災の黙示録_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ルイージマンション3_quarter',
#  '世界のアソビ大全51_quarter',
#  'ピクミン3 デラックス_quarter',
#  'Splatoon2_quarter',
#  'Xenoblade Definitive Edition_quarter',
#  'スーパーマリオメーカー2_quarter',
#  'マリオカート ライブ ホームサーキット_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'Splatoon3_quarter',
#  'Nintendo Switch Sports_quarter',
#  '星のカービィ ディスカバリー_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'マリオストライカーズ バトルリーグ_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'ゼノブレイド3_quarter',
#  'ファイアーエムブレム エンゲージ_quarter',
#  'ベヨネッタ3_quarter',
#  'ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter',
#  'ゼルダの伝説 スカイウォードソード HD_quarter',
#  'メトロイド ドレッド_quarter',
#  'New ポケモンスナップ_quarter',
#  'マリオゴルフ スーパーラッシュ_quarter',
#  'やわらかあたま塾 いっしょにあたまのストレッチ_quarter',
#  'おすそわける メイド イン ワリオ_quarter',
#  'ナビつき！ つくってわかる はじめてゲームプログラミング_quarter',
#  'ARMS_quarter',
#  '1-2-Switch_quarter',
#  'ゼノブレイド2_quarter',
#  '星のカービィ スターアライズ_quarter',
#  'ポッ拳 ポッケン トーナメント DX_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'Pikmin 4_quarter',
#  'ゼルダの伝説 夢をみる島_quarter',
#  'ファイアーエムブレム 風花雪月_quarter',
#  'ASTRAL CHAIN_quarter',
#  'MARVEL ULTIMATE ALLIANCE 3: The Black Order_quarter',
#  'ゼルダの伝説 知恵のかりもの_quarter',
#  'ペーパーマリオRPG_quarter',
#  'ルイージマンション2 HD_quarter',
#  'スーパー マリオパーティ ジャンボリー_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'マリオ&ルイージRPG ブラザーシップ!_quarter',
#  'マリオテニス エース_quarter',
#  'ドンキーコング トロピカルフリーズ_quarter',
#  'スーパーマリオRPG_quarter',
#  'プリンセスピーチ Showtime!_quarter',
#  'ドンキーコング リターンズ HD_quarter',
#  '進め! キノピオ隊長_quarter',
#  'OCTOPATH TRAVELER_quarter',
#  'ヨッシークラフトワールド_quarter',
#  'Nintendo Labo Toy-Con 01: Variety Kit_quarter',
#  'ルイージマンション３_quarter',
#  'おすそわける\u3000メイド イン ワリオ_quarter',
#  'ポケモン不思議のダンジョン 救助隊DX_quarter']
# /// Ridge_nonzero_titles ///
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'スーパーマリオ 3Dコレクション_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ペーパーマリオ オリガミキング_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'ゼルダ無双 厄災の黙示録_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ルイージマンション3_quarter',
#  '世界のアソビ大全51_quarter',
#  'ピクミン3 デラックス_quarter',
#  'Splatoon2_quarter',
#  'Xenoblade Definitive Edition_quarter',
#  'スーパーマリオメーカー2_quarter',
#  'マリオカート ライブ ホームサーキット_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'Splatoon3_quarter',
#  'Nintendo Switch Sports_quarter',
#  '星のカービィ ディスカバリー_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'マリオストライカーズ バトルリーグ_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'ゼノブレイド3_quarter',
#  'ファイアーエムブレム エンゲージ_quarter',
#  '星のカービィ Wii デラックス_quarter',
#  'メトロイドプライム リマスタード_quarter',
#  'ベヨネッタ3_quarter',
#  'ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter',
#  'ゼルダの伝説 スカイウォードソード HD_quarter',
#  'メトロイド ドレッド_quarter',
#  'New ポケモンスナップ_quarter',
#  'マリオゴルフ スーパーラッシュ_quarter',
#  'ミートピア_quarter',
#  'やわらかあたま塾 いっしょにあたまのストレッチ_quarter',
#  'おすそわける メイド イン ワリオ_quarter',
#  'ナビつき！ つくってわかる はじめてゲームプログラミング_quarter',
#  'ARMS_quarter',
#  '1-2-Switch_quarter',
#  'ゼノブレイド2_quarter',
#  '星のカービィ スターアライズ_quarter',
#  'ポッ拳 ポッケン トーナメント DX_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'Pikmin 4_quarter',
#  'ゼルダの伝説 夢をみる島_quarter',
#  'ファイアーエムブレム 風花雪月_quarter',
#  'ASTRAL CHAIN_quarter',
#  'MARVEL ULTIMATE ALLIANCE 3: The Black Order_quarter',
#  'ゼルダの伝説 知恵のかりもの_quarter',
#  'ペーパーマリオRPG_quarter',
#  'ルイージマンション2 HD_quarter',
#  'スーパー マリオパーティ ジャンボリー_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'マリオ&ルイージRPG ブラザーシップ!_quarter',
#  'マリオテニス エース_quarter',
#  'ドンキーコング トロピカルフリーズ_quarter',
#  'スーパーマリオRPG_quarter',
#  'プリンセスピーチ Showtime!_quarter',
#  'マリオvs.ドンキーコング_quarter',
#  'ドンキーコング リターンズ HD_quarter',
#  '進め! キノピオ隊長_quarter',
#  'OCTOPATH TRAVELER_quarter',
#  'ヨッシークラフトワールド_quarter',
#  'Nintendo Labo Toy-Con 01: Variety Kit_quarter',
#  'ルイージマンション３_quarter',
#  'おすそわける\u3000メイド イン ワリオ_quarter',
#  'ポケモン不思議のダンジョン 救助隊DX_quarter']
# /// ElasticNet_nonzero_titles ///
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'スーパーマリオ 3Dコレクション_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ペーパーマリオ オリガミキング_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'ゼルダ無双 厄災の黙示録_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ルイージマンション3_quarter',
#  '世界のアソビ大全51_quarter',
#  'ピクミン3 デラックス_quarter',
#  'Splatoon2_quarter',
#  'Xenoblade Definitive Edition_quarter',
#  'スーパーマリオメーカー2_quarter',
#  'マリオカート ライブ ホームサーキット_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'Splatoon3_quarter',
#  'Nintendo Switch Sports_quarter',
#  '星のカービィ ディスカバリー_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'マリオストライカーズ バトルリーグ_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'ゼノブレイド3_quarter',
#  'ファイアーエムブレム エンゲージ_quarter',
#  '星のカービィ Wii デラックス_quarter',
#  'メトロイドプライム リマスタード_quarter',
#  'ベヨネッタ3_quarter',
#  'ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter',
#  'ゼルダの伝説 スカイウォードソード HD_quarter',
#  'メトロイド ドレッド_quarter',
#  'New ポケモンスナップ_quarter',
#  'マリオゴルフ スーパーラッシュ_quarter',
#  'ミートピア_quarter',
#  'やわらかあたま塾 いっしょにあたまのストレッチ_quarter',
#  'おすそわける メイド イン ワリオ_quarter',
#  'ナビつき！ つくってわかる はじめてゲームプログラミング_quarter',
#  'ARMS_quarter',
#  '1-2-Switch_quarter',
#  'ゼノブレイド2_quarter',
#  '星のカービィ スターアライズ_quarter',
#  'ポッ拳 ポッケン トーナメント DX_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'Pikmin 4_quarter',
#  'ゼルダの伝説 夢をみる島_quarter',
#  'ファイアーエムブレム 風花雪月_quarter',
#  'ASTRAL CHAIN_quarter',
#  'MARVEL ULTIMATE ALLIANCE 3: The Black Order_quarter',
#  'ゼルダの伝説 知恵のかりもの_quarter',
#  'ペーパーマリオRPG_quarter',
#  'ルイージマンション2 HD_quarter',
#  'スーパー マリオパーティ ジャンボリー_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'マリオ&ルイージRPG ブラザーシップ!_quarter',
#  'マリオテニス エース_quarter',
#  'ドンキーコング トロピカルフリーズ_quarter',
#  'スーパーマリオRPG_quarter',
#  'プリンセスピーチ Showtime!_quarter',
#  'マリオvs.ドンキーコング_quarter',
#  'ドンキーコング リターンズ HD_quarter',
#  '進め! キノピオ隊長_quarter',
#  'OCTOPATH TRAVELER_quarter',
#  'ヨッシークラフトワールド_quarter',
#  'Nintendo Labo Toy-Con 01: Variety Kit_quarter',
#  'ルイージマンション３_quarter',
#  'おすそわける\u3000メイド イン ワリオ_quarter',
#  'ポケモン不思議のダンジョン 救助隊DX_quarter']
# == compare_all内で実行した結果  R2 AdjR2 は in sample ==
#         model        R2  AdjR2  CV_R2_mean  CV_R2_std  nonzero
# 0       Lasso  1.000000    NaN    0.522935   0.215023       68
# 1       Ridge  0.984758    NaN    0.157663   0.266306       72
# 2  ElasticNet  1.000000    NaN    0.523061   0.215037       72
# == こここまで 全データでcompare_all ==

# %%
# 結果 -> 
# OLSと同じく、タイトル数が四半期数に比べて多いので分析できない
# lassoでも過学習

# %%
# データ数4でフィルタしたタイトルでcompare_all
compare_filtered_by_count = compare_all(selected_df, y_col, filtered_titles_by_count, max_iter=100000, nonzero_threshold=1e-12)
display(compare_filtered_by_count)
print("== ここまで データ数4 でフィルタしてcompare_all ==")
# display(filtered_titles_by_count)
# Out:
# [LASSO-TS] n_samples=33, n_features=35, nonzero=7/7  alpha=23.9503, l1_ratio=1.000
# R2=0.8790, Adjusted R2=0.8451, Intercept=453.8182
# [RIDGE-TS] n_samples=33, n_features=35, nonzero=35/35  alpha=14.8735
# R2=0.9313, Adjusted R2=nan, Intercept=453.8182
# [ELASTICNET-TS] n_samples=33, n_features=35, nonzero=33/33  alpha=3.56225, l1_ratio=0.800
# R2=0.8826, Adjusted R2=nan, Intercept=453.8182
# /// Lasso_nonzero_titles ///
# ['マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'スーパーマリオパーティ_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ARMS_quarter']
# /// Ridge_nonzero_titles ///
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ルイージマンション3_quarter',
#  '世界のアソビ大全51_quarter',
#  'Splatoon2_quarter',
#  'Xenoblade Definitive Edition_quarter',
#  'スーパーマリオメーカー2_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'Splatoon3_quarter',
#  'Nintendo Switch Sports_quarter',
#  '星のカービィ ディスカバリー_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'マリオストライカーズ バトルリーグ_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'New ポケモンスナップ_quarter',
#  'マリオゴルフ スーパーラッシュ_quarter',
#  'ミートピア_quarter',
#  'ARMS_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'ゼルダの伝説 夢をみる島_quarter',
#  'ペーパーマリオRPG_quarter',
#  'ルイージマンション2 HD_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'マリオテニス エース_quarter',
#  'ドンキーコング トロピカルフリーズ_quarter',
#  'ルイージマンション３_quarter']
# /// ElasticNet_nonzero_titles ///
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ルイージマンション3_quarter',
#  '世界のアソビ大全51_quarter',
#  'Splatoon2_quarter',
#  'Xenoblade Definitive Edition_quarter',
#  'スーパーマリオメーカー2_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'Nintendo Switch Sports_quarter',
#  '星のカービィ ディスカバリー_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'マリオストライカーズ バトルリーグ_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'New ポケモンスナップ_quarter',
#  'マリオゴルフ スーパーラッシュ_quarter',
#  'ミートピア_quarter',
#  'ARMS_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'ゼルダの伝説 夢をみる島_quarter',
#  'ペーパーマリオRPG_quarter',
#  'ルイージマンション2 HD_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'マリオテニス エース_quarter',
#  'ドンキーコング トロピカルフリーズ_quarter',
#  'ルイージマンション３_quarter']
# == compare_all内で実行した結果  R2 AdjR2 は in sample ==
#         model        R2     AdjR2  CV_R2_mean  CV_R2_std  nonzero
# 0       Lasso  0.878968  0.845079    0.373799   0.526196        7
# 1       Ridge  0.931267       NaN    0.368516   0.239189       35
# 2  ElasticNet  0.882563       NaN    0.381214   0.236403       33
# == ここまで データ数4 でフィルタしてcompare_all ==

# %%
# lassoで特徴量が７まで減ってもCV_R2が上がらないのは、データ数（四半期数）が少なさが原因の可能性が高い
# CV_R2の分散が0.5と大きいのは、タイトル販売のデータに季節性のスパイクや多重共線性の影響が強く出ているからと考えられる
# ridgeとelasticnetは自由度不足（まだタイトル数が多い）

# ここからさらに諸条件でタイトルをフィルタ
# フィルタ条件
# ・販売量
# ・季節性調整後の相関
# ・データ数 > 8

# 同時に販売されている人気タイトルは多重共線性の原因になるが、同時期に同じように売れたタイトルはデータ上の差別化はできず、個別の影響度は測りにくい。
# フィルタしても、同じ時期に同じように良く売れたタイトルは残る。
# -> 特徴量がすべて「タイトルの販売量」という同じ性質である以上、多重共線性の問題は残る。

# %%
# 販売量でフィルタ
def culc_total_sales(df):
    """
    return: タイトルと販売量の総計のpd.DataFrame
    """
    title_cols = [title for title in df.columns if "_quarter" in title]
    total_sales_df = df[title_cols].sum()
    total_sales_df = total_sales_df.reset_index()
    total_sales_df.columns = ["title", "total_sales"]
    total_sales_df = total_sales_df.sort_values(by="total_sales", ascending=False).reset_index(drop=True)
    # display(total_sales_df)
    return total_sales_df

def get_titles_filtered_by_sales(total_sales_df, min_sales=1000):
    """
    min_sales以上のデータ数で記述統計をフィルタして表示
    return: フィルタ後に残ったタイトルのリスト
    """
    sample_size = len(total_sales_df)
    print(f"sample_size: {sample_size}")
    print(f"残すものは、販売量 >{min_sales}万本 でフィルタ")
    filtered_df_by_sales = total_sales_df[total_sales_df["total_sales"] > min_sales]["title"].tolist()
    # filtered_titles = filtered_df_by_sales["title"].tolist()
    return filtered_df_by_sales

# %%
# タイトルの販売量 > 1000万本でフィルタしたタイトルでcompare_all
total_sales_df = culc_total_sales(selected_df)
print(f"total_sales_df: {len(total_sales_df)}")
titles_filtered_by_sales = get_titles_filtered_by_sales(total_sales_df, min_sales=1000)
y_col = "hard_total_sales"
# X_cols_titles_filtered_by_sales = ["Q_2", "Q_3", "Q_4"] + titles_filtered_by_sales
compare_filtered_by_sales = compare_all(selected_df, y_col, titles_filtered_by_sales, max_iter=1000000, nonzero_threshold=1e-12)
display(compare_filtered_by_sales)
display(titles_filtered_by_sales)
# Out:
# total_sales_df: 72
# sample_size: 72
# 残すものは、販売量 >1000万本 でフィルタ
# [LASSO-TS] n_samples=33, n_features=22, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8093, Adjusted R2=0.7653, Intercept=453.8182
# [RIDGE-TS] n_samples=33, n_features=22, nonzero=22/22  alpha=9.23671
# R2=0.9251, Adjusted R2=0.7603, Intercept=453.8182
# [ELASTICNET-TS] n_samples=33, n_features=22, nonzero=22/22  alpha=1.37382, l1_ratio=0.600
# R2=0.8900, Adjusted R2=0.6481, Intercept=453.8182
# /// Lasso_nonzero_titles ///
# ['マリオカート8 デラックス_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'スーパーマリオパーティ_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter']
# /// Ridge_nonzero_titles ///
# ['マリオカート8 デラックス_quarter',
#  'あつまれ どうぶつの森_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'Nintendo Switch Sports_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'マリオパーティ スーパースターズ_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'Splatoon2_quarter',
#  'ルイージマンション3_quarter',
#  'Splatoon3_quarter',
#  'ルイージマンション３_quarter']
# /// ElasticNet_nonzero_titles ///
# ['マリオカート8 デラックス_quarter',
#  'あつまれ どうぶつの森_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'Nintendo Switch Sports_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'マリオパーティ スーパースターズ_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'Splatoon2_quarter',
#  'ルイージマンション3_quarter',
#  'Splatoon3_quarter',
#  'ルイージマンション３_quarter']
# == compare_all内で実行した結果  R2 AdjR2 は in sample ==
#         model        R2     AdjR2  CV_R2_mean  CV_R2_std  nonzero
# 0       Lasso  0.809327  0.765325    0.342725   0.489400        6
# 1       Ridge  0.925109  0.760349    0.363185   0.280902       22
# 2  ElasticNet  0.890028  0.648089    0.360152   0.301874       22
# ['マリオカート8 デラックス_quarter',
#  'あつまれ どうぶつの森_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'Nintendo Switch Sports_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'マリオパーティ スーパースターズ_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'Splatoon2_quarter',
#  'ルイージマンション3_quarter',
#  'Splatoon3_quarter',
#  'ルイージマンション３_quarter']

# %%
# 販売量>1000でフィルタした記述統計
display(summary_df[summary_df["総販売量"]>1000].sort_values("総販売量", ascending=False))
# Out:
#                                                   データ数       平均    中央値  \
# マリオカート8 デラックス_quarter                             31.0  219.968  181.0
# あつまれ どうぶつの森_quarter                               18.0  265.722  133.5
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                     20.0  181.250  128.5
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                      24.0  132.667  121.5
# スーパーマリオ オデッセイ_quarter                             20.0  146.450  110.5
# ポケットモンスター スカーレット・バイオレット_quarter                    7.0  382.714  113.0
# ポケットモンスター ソード・シールド_quarter                         8.0  303.500  132.0
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                    5.0  434.600   99.0
# スーパーマリオパーティ_quarter                               15.0  137.733  110.0
# New スーパーマリオブラザーズU デラックス_quarter                   15.0  116.267  125.0
# Nintendo Switch Sports_quarter                    10.0  162.700  128.5
# Super Mario Bros. Wonder_quarter                   4.0  401.000  177.5
# リングフィット アドベンチャー_quarter                           12.0  128.167  116.0
# Pokmon LEGENDS アルセウス_quarter                       4.0  370.750   99.5
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter           2.0  732.500  732.5
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter   8.0  181.625   83.0
# マリオパーティ スーパースターズ_quarter                           9.0  155.444  119.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                10.0  134.800   93.0
# Splatoon2_quarter                                 12.0  110.917  109.5
# ルイージマンション3_quarter                                 7.0  189.714  142.0
# Splatoon3_quarter                                  5.0  239.200  104.0
# ルイージマンション３_quarter                                 4.0  261.000  148.0
#
#                                                      標準偏差    最小値     最大値  \
# マリオカート8 デラックス_quarter                             105.269   85.0   462.0
# あつまれ どうぶつの森_quarter                               332.687   39.0  1177.0
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                     246.249   36.0  1208.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                       56.030   24.0   276.0
# スーパーマリオ オデッセイ_quarter                             186.181   24.0   907.0
# ポケットモンスター スカーレット・バイオレット_quarter                   741.204   41.0  2061.0
# ポケットモンスター ソード・シールド_quarter                        527.944   38.0  1606.0
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                   792.359   33.0  1851.0
# スーパーマリオパーティ_quarter                               119.373   32.0   530.0
# New スーパーマリオブラザーズU デラックス_quarter                    73.238   25.0   331.0
# Nintendo Switch Sports_quarter                    125.332   53.0   484.0
# Super Mario Bros. Wonder_quarter                  533.783   53.0  1196.0
# リングフィット アドベンチャー_quarter                            74.693   16.0   284.0
# Pokmon LEGENDS アルセウス_quarter                      597.132   20.0  1264.0
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter          939.745   68.0  1397.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter  332.973   20.0  1000.0
# マリオパーティ スーパースターズ_quarter                          147.958   58.0   543.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                153.783   31.0   559.0
# Splatoon2_quarter                                  87.474   31.0   361.0
# ルイージマンション3_quarter                                174.602   38.0   537.0
# Splatoon3_quarter                                 317.058   25.0   790.0
# ルイージマンション３_quarter                                248.499  115.0   633.0
#
#                                                   変動係数(CV)  \
# マリオカート8 デラックス_quarter                                0.479
# あつまれ どうぶつの森_quarter                                  1.252
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                        1.359
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                         0.422
# スーパーマリオ オデッセイ_quarter                                1.271
# ポケットモンスター スカーレット・バイオレット_quarter                      1.937
# ポケットモンスター ソード・シールド_quarter                           1.740
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                      1.823
# スーパーマリオパーティ_quarter                                  0.867
# New スーパーマリオブラザーズU デラックス_quarter                      0.630
# Nintendo Switch Sports_quarter                       0.770
# Super Mario Bros. Wonder_quarter                     1.331
# リングフィット アドベンチャー_quarter                              0.583
# Pokmon LEGENDS アルセウス_quarter                         1.611
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter             1.283
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter     1.833
# マリオパーティ スーパースターズ_quarter                             0.952
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                   1.141
# Splatoon2_quarter                                    0.789
# ルイージマンション3_quarter                                   0.920
# Splatoon3_quarter                                    1.325
# ルイージマンション３_quarter                                   0.952
#
#                                                   相関係数(hard_total_sales)  \
# マリオカート8 デラックス_quarter                                              0.831
# あつまれ どうぶつの森_quarter                                                0.203
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                                      0.387
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                                       0.210
# スーパーマリオ オデッセイ_quarter                                              0.280
# ポケットモンスター スカーレット・バイオレット_quarter                                    0.712
# ポケットモンスター ソード・シールド_quarter                                         0.335
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                                    0.127
# スーパーマリオパーティ_quarter                                                0.464
# New スーパーマリオブラザーズU デラックス_quarter                                    0.108
# Nintendo Switch Sports_quarter                                     0.348
# Super Mario Bros. Wonder_quarter                                   0.863
# リングフィット アドベンチャー_quarter                                            0.799
# Pokmon LEGENDS アルセウス_quarter                                      -0.150
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter                             NaN
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter                   0.368
# マリオパーティ スーパースターズ_quarter                                           0.728
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                                 0.116
# Splatoon2_quarter                                                 -0.213
# ルイージマンション3_quarter                                                 0.618
# Splatoon3_quarter                                                 -0.075
# ルイージマンション３_quarter                                                -0.802
#
#                                                   p値(hard_total_sales)  \
# マリオカート8 デラックス_quarter                                           0.0000
# あつまれ どうぶつの森_quarter                                             0.4201
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                                   0.0916
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                                    0.3248
# スーパーマリオ オデッセイ_quarter                                           0.2319
# ポケットモンスター スカーレット・バイオレット_quarter                                 0.0726
# ポケットモンスター ソード・シールド_quarter                                      0.4179
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                                 0.8382
# スーパーマリオパーティ_quarter                                             0.0812
# New スーパーマリオブラザーズU デラックス_quarter                                 0.7022
# Nintendo Switch Sports_quarter                                  0.3247
# Super Mario Bros. Wonder_quarter                                0.1368
# リングフィット アドベンチャー_quarter                                         0.0018
# Pokmon LEGENDS アルセウス_quarter                                    0.8504
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter                           NaN
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter                0.3702
# マリオパーティ スーパースターズ_quarter                                        0.0263
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                              0.7499
# Splatoon2_quarter                                               0.5068
# ルイージマンション3_quarter                                              0.1393
# Splatoon3_quarter                                               0.9040
# ルイージマンション３_quarter                                              0.1975
#
#                                                   データ数(再掲)    総販売量
# マリオカート8 デラックス_quarter                                 31.0  6819.0
# あつまれ どうぶつの森_quarter                                   18.0  4783.0
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                         20.0  3625.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                          24.0  3184.0
# スーパーマリオ オデッセイ_quarter                                 20.0  2929.0
# ポケットモンスター スカーレット・バイオレット_quarter                        7.0  2679.0
# ポケットモンスター ソード・シールド_quarter                             8.0  2428.0
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                        5.0  2173.0
# スーパーマリオパーティ_quarter                                   15.0  2066.0
# New スーパーマリオブラザーズU デラックス_quarter                       15.0  1744.0
# Nintendo Switch Sports_quarter                        10.0  1627.0
# Super Mario Bros. Wonder_quarter                       4.0  1604.0
# リングフィット アドベンチャー_quarter                               12.0  1538.0
# Pokmon LEGENDS アルセウス_quarter                           4.0  1483.0
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter               2.0  1465.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter       8.0  1453.0
# マリオパーティ スーパースターズ_quarter                               9.0  1399.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                    10.0  1348.0
# Splatoon2_quarter                                     12.0  1331.0
# ルイージマンション3_quarter                                     7.0  1328.0
# Splatoon3_quarter                                      5.0  1196.0
# ルイージマンション３_quarter                                     4.0  1044.0

# %%
# 改善しているように見えるが、elasticnetでは、max_iter=1000000で収束
# lassoのCV_R2_meanとCV_R2_stdの値が改善している -> 販売量でフィルタしたことでノイズを持ったタイトルが取り除かれた。データ数>4でのフィルタでは、販売量の小さなタイトルがノイズ的に係数を持っていた可能性が高い

# 販売量>1000でフィルタしたケースでもデータ数が少ないタイトルがも混ざっており、compare_allの結果を鵜呑みにはできない。ローンチ直後のスパイク的な売り上げが、ハード販売の波と一致して回帰モデルに影響してるに過ぎないものもあるはず。
# データ数が少なくて、変動係数が大きいものは明らかにスパイク的に売り上げたタイトル。これらは、短期的なハードへ販売への貢献度は高く、安定的には効いてくるタイトルではないと判断できそう。
# ノイズではないが、ハード販売の牽引役としての役割は一時的なものとして考える。
# 販売量でのフィルタは、影響度の高いタイトルの選別に一定の効果がありそうに見える。

# %%
# 季節性調整後の相関でフィルタ
def seasonal_corr_filter_from_selected(
    selected_df,
    y_col= "hard_total_sales",
    corr_thld = 0.25,     # 季節調整後の相関係数の閾値
    q_cols = ["Q_2", "Q_3", "Q_4"]
    ):
    """
    Returns:
        seasonal_corr_df: 各タイトルの季節調整後相関 "seasonal_adj_corr" と有効データ数 "sample_size" を相関の降順で並べた表
        filtered_titles : フィルタを通過したタイトル名のリスト
        residuals_df    : 残差のデータ
    """
    titles_with_quarter = [col for col in selected_df.columns if "_quarter" in col]
    q_dummies_df = selected_df[q_cols]
    # 残差化    
    def residualize_series(target, q_dummies_df):
        """
        target: タイトル、ハードの販売量（欠損処理済み）
        q_dummies_df: 四半期ダミーdf
        return: 残差（季節成分除去値）のSeries
                targetを[定数, Q_2, Q_3, Q_4] に回帰する
        """
        y = target.astype(float)
        intercept_col = pd.Series(1.0, index=target.index, name="Intercept")  # 定数項
        quarter_cols = q_dummies_df.astype(int)
        X = pd.concat([intercept_col, quarter_cols], axis=1)

        lr = LinearRegression(fit_intercept=False)
        lr.fit(X.values, y.values)

        fitted = pd.Series(lr.predict(X.values), index=target.index, name="fitted")
        resid = (y - fitted).rename(target.name)  # 残差
        return resid

    sample_size = len(selected_df)
    rows = []
    y_res = residualize_series(selected_df[y_col], q_dummies_df) # ハードの残差
    residuals_dict = {"hard_total_sales_resid": y_res}
    for title in titles_with_quarter:
        x_res = residualize_series(selected_df[title], q_dummies_df) # 各タイトルの残差
        residuals_dict[title + "_resid"] = x_res
        # 標準偏差ゼロは相関が定義できないので0.0にsする
        if y_res.std(ddof=0) < 1e-12 or x_res.std(ddof=0) < 1e-12:
            r = 0.0
        else:
            r = float(y_res.corr(x_res))  # ピアソン相関係数
        rows.append({"title": title, "seasonal_adj_corr": r})

    seasonal_corr_df = (pd.DataFrame(rows).sort_values("seasonal_adj_corr", ascending=False).reset_index(drop=True))
    filtered_titles = seasonal_corr_df.loc[seasonal_corr_df["seasonal_adj_corr"] >= corr_thld, "title"].tolist()
    residuals_df = pd.DataFrame(residuals_dict)
    print(f"sample_size: {sample_size}")
    print(f"各タイトルとハード残差の相関表 残すものは >={corr_thld} でフィルタ")
    # display(seasonal_corr_df)
    # display(residuals_df)
    return seasonal_corr_df, filtered_titles, residuals_df

# %%
print("== 季節性調整後のタイトルでフィルタ ==")
seasonal_corr_df, filtered_cols, residuals_df = seasonal_corr_filter_from_selected(selected_df, corr_thld=0.35)

# 季節調整後の相関でフィルタしたタイトルでcompare_allを実行
display(residuals_df.head())
display(compare_all(selected_df, y_col, filtered_cols, max_iter=500000, nonzero_threshold=1e-12))
print("== こここまで 季節調整後の相関でフィルタしてcompare_all ==")
display(seasonal_corr_df[seasonal_corr_df["seasonal_adj_corr"] >= 0.35])
display(filtered_cols)
# Out:
# == 季節性調整後のタイトルでフィルタ ==
# sample_size: 33
# 各タイトルとハード残差の相関表 残すものは >=0.35 でフィルタ
ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter_resid  Pikmin 4_quarter_resid  \
# 2017-03-31                             -16.111111           -1.666667e+00
# 2017-06-30                            -231.375000            1.236896e-15
# 2017-09-30                             -12.375000           -3.262500e+01
# 2017-12-31                              -9.750000           -9.000000e+00
# 2018-03-31                             -16.111111           -1.666667e+00
#
#             ゼルダの伝説 夢をみる島_quarter_resid  ファイアーエムブレム 風花雪月_quarter_resid  \
# 2017-03-31                  -14.444444                  -3.222222e+00
# 2017-06-30                    0.000000                  -3.710688e-15
# 2017-09-30                  -39.125000                  -2.862500e+01
# 2017-12-31                  -13.250000                  -3.625000e+00
# 2018-03-31                  -14.444444                  -3.222222e+00
#
#             ASTRAL CHAIN_quarter_resid  \
# 2017-03-31               -5.555556e-01
# 2017-06-30                1.236896e-15
# 2017-09-30               -2.626753e-15
# 2017-12-31               -1.287500e+01
# 2018-03-31               -5.555556e-01
#
#             MARVEL ULTIMATE ALLIANCE 3: The Black Order_quarter_resid  \
# 2017-03-31                                      -6.666667e-01
# 2017-06-30                                       2.473792e-15
# 2017-09-30                                      -5.016780e-16
# 2017-12-31                                      -1.275000e+01
# 2018-03-31                                      -6.666667e-01
#
#             ゼルダの伝説 知恵のかりもの_quarter_resid  ペーパーマリオRPG_quarter_resid  \
# 2017-03-31                 -2.000000e+00                 -0.444444
# 2017-06-30                 -4.947585e-15                -22.000000
# 2017-09-30                 -3.225000e+01                 -2.250000
# 2017-12-31                 -1.662500e+01                 -1.500000
# 2018-03-31                 -2.000000e+00                 -0.444444
#
#             ルイージマンション2 HD_quarter_resid  スーパー マリオパーティ ジャンボリー_quarter_resid  \
# 2017-03-31                    -0.888889                      -1.455556e+01
# 2017-06-30                   -14.875000                       0.000000e+00
# 2017-09-30                    -4.750000                      -1.913904e-14
# 2017-12-31                    -2.875000                      -7.712500e+01
# 2018-03-31                    -0.888889                      -1.455556e+01
#
#             Super Mario Bros. Wonder_quarter_resid  \
# 2017-03-31                           -2.233333e+01
# 2017-06-30                            6.926618e-14
# 2017-09-30                            1.863184e-14
# 2017-12-31                           -1.753750e+02
# 2018-03-31                           -2.233333e+01
#
#             マリオ&ルイージRPG ブラザーシップ!_quarter_resid  マリオテニス エース_quarter_resid  \
# 2017-03-31                       -1.444444e+00                 -1.222222
# 2017-06-30                        0.000000e+00                -17.250000
# 2017-09-30                        1.346785e-15                 -9.750000
# 2017-12-31                       -2.300000e+01                 -4.625000
# 2018-03-31                       -1.444444e+00                 -1.222222
#
#             ドンキーコング トロピカルフリーズ_quarter_resid  スーパーマリオRPG_quarter_resid  \
# 2017-03-31                        -1.888889             -1.888889e+00
# 2017-06-30                       -17.500000              7.421377e-15
# 2017-09-30                        -3.375000             -5.061366e-15
# 2017-12-31                        -5.125000             -3.925000e+01
# 2018-03-31                        -1.888889             -1.888889e+00
#
#             プリンセスピーチ Showtime!_quarter_resid  マリオvs.ドンキーコング_quarter_resid  \
# 2017-03-31                     -1.355556e+01                -1.244444e+01
# 2017-06-30                      3.092240e-15                 6.184481e-16
# 2017-09-30                     -1.149956e-16                 3.172848e-17
# 2017-12-31                     -1.732297e-15                 5.854352e-16
# 2018-03-31                     -1.355556e+01                -1.244444e+01
#
#             ドンキーコング リターンズ HD_quarter_resid  進め! キノピオ隊長_quarter_resid  \
# 2017-03-31                   -1.411111e+01             -1.444444e+00
# 2017-06-30                    2.473792e-15             -2.473792e-15
# 2017-09-30                    2.427136e-15             -3.853417e-15
# 2017-12-31                    3.904643e-16             -1.312500e+01
# 2018-03-31                   -1.411111e+01             -1.444444e+00
#
#             OCTOPATH TRAVELER_quarter_resid  ヨッシークラフトワールド_quarter_resid  \
# 2017-03-31                    -1.000000e+00               -1.233333e+01
# 2017-06-30                    -1.236896e-15                3.092240e-15
# 2017-09-30                    -1.375143e-16                1.940764e-15
# 2017-12-31                    -1.350000e+01               -1.063187e-15
# 2018-03-31                    -1.000000e+00               -1.233333e+01
#
#             Nintendo Labo Toy-Con 01: Variety Kit_quarter_resid  \
# 2017-03-31                                      -3.333333e-01
# 2017-06-30                                       2.473792e-15
# 2017-09-30                                      -1.204327e-15
# 2017-12-31                                      -1.325000e+01
# 2018-03-31                                      -3.333333e-01
#
#             ルイージマンション３_quarter_resid  おすそわける　メイド イン ワリオ_quarter_resid  \
# 2017-03-31             -7.033333e+01                    -7.383661e-15
# 2017-06-30              1.979034e-14                    -3.092240e-15
# 2017-09-30             -1.887500e+01                    -2.996920e-15
# 2017-12-31             -3.250000e+01                    -1.550000e+01
# 2018-03-31             -7.033333e+01                    -7.383661e-15
#
#             ポケモン不思議のダンジョン 救助隊DX_quarter_resid
# 2017-03-31                      -1.400000e+01
# 2017-06-30                       4.329136e-15
# 2017-09-30                       7.020236e-17
# 2017-12-31                       2.490332e-16
# 2018-03-31                      -1.400000e+01
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.868e+03, tolerance: 1.817e+02
#   model = cd_fast.enet_coordinate_descent(
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.035e+04, tolerance: 2.060e+02
#   model = cd_fast.enet_coordinate_descent(
# [LASSO-TS] n_samples=33, n_features=13, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.8273, Adjusted R2=0.7953, Intercept=453.8182
# [RIDGE-TS] n_samples=33, n_features=13, nonzero=13/13  alpha=1.37382
# R2=0.8498, Adjusted R2=0.7471, Intercept=453.8182
# [ELASTICNET-TS] n_samples=33, n_features=13, nonzero=11/11  alpha=0.529832, l1_ratio=0.800
# R2=0.8444, Adjusted R2=0.7629, Intercept=453.8182
# /// Lasso_nonzero_titles ///
# ['リングフィット アドベンチャー_quarter',
#  'スーパーマリオパーティ_quarter',
#  'マリオカート8 デラックス_quarter',
#  'ピクミン3 デラックス_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter']
# /// Ridge_nonzero_titles ///
# ['リングフィット アドベンチャー_quarter',
#  '世界のアソビ大全51_quarter',
#  'スーパーマリオ 3Dコレクション_quarter',
#  'スーパーマリオパーティ_quarter',
#  'ペーパーマリオ オリガミキング_quarter',
#  'あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'マリオカート ライブ ホームサーキット_quarter',
#  'ゼルダ無双 厄災の黙示録_quarter',
#  'ピクミン3 デラックス_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'Xenoblade Definitive Edition_quarter']
# /// ElasticNet_nonzero_titles ///
# ['リングフィット アドベンチャー_quarter',
#  '世界のアソビ大全51_quarter',
#  'スーパーマリオパーティ_quarter',
#  'ペーパーマリオ オリガミキング_quarter',
#  'あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'ゼルダ無双 厄災の黙示録_quarter',
#  'ピクミン3 デラックス_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'Xenoblade Definitive Edition_quarter']
# == compare_all内で実行した結果  R2 AdjR2 は in sample ==
#         model        R2     AdjR2  CV_R2_mean  CV_R2_std  nonzero
# 0       Lasso  0.827263  0.795274    0.629501   0.206006        5
# 1       Ridge  0.849823  0.747071    0.616495   0.192599       13
# 2  ElasticNet  0.844376  0.762859    0.619321   0.190961       11
# == こここまで 季節調整後の相関でフィルタしてcompare_all ==
#                                    title  seasonal_adj_corr
# 0                リングフィット アドベンチャー_quarter           0.795789
# 1                     世界のアソビ大全51_quarter           0.650761
# 2               スーパーマリオ 3Dコレクション_quarter           0.564521
# 3                    スーパーマリオパーティ_quarter           0.456294
# 4                ペーパーマリオ オリガミキング_quarter           0.435471
# 5                    あつまれ どうぶつの森_quarter           0.434779
# 6                  マリオカート8 デラックス_quarter           0.430966
# 7            マリオカート ライブ ホームサーキット_quarter           0.421838
# 8                   ゼルダ無双 厄災の黙示録_quarter           0.405186
# 9                    ピクミン3 デラックス_quarter           0.399209
# 10          ゼルダの伝説 ブレス オブ ザ ワイルド_quarter           0.397607
# 11       New スーパーマリオブラザーズU デラックス_quarter           0.378437
# 12  Xenoblade Definitive Edition_quarter           0.375003
# ['リングフィット アドベンチャー_quarter',
#  '世界のアソビ大全51_quarter',
#  'スーパーマリオ 3Dコレクション_quarter',
#  'スーパーマリオパーティ_quarter',
#  'ペーパーマリオ オリガミキング_quarter',
#  'あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'マリオカート ライブ ホームサーキット_quarter',
#  'ゼルダ無双 厄災の黙示録_quarter',
#  'ピクミン3 デラックス_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'Xenoblade Definitive Edition_quarter']

# %%
summary_df.loc[filtered_cols]
# （注）ここでのsummary_dfの相関係数は、季節調整前の元データの係数
# Out:
#                                       データ数       平均    中央値     標準偏差   最小値  \
# リングフィット アドベンチャー_quarter               12.0  128.167  116.0   74.693  16.0
# 世界のアソビ大全51_quarter                     5.0   84.400   81.0   22.390  52.0
# スーパーマリオ 3Dコレクション_quarter               3.0  300.333  311.0  226.189  69.0
# スーパーマリオパーティ_quarter                   15.0  137.733  110.0  119.373  32.0
# ペーパーマリオ オリガミキング_quarter                3.0  104.000   23.0  154.360   7.0
# あつまれ どうぶつの森_quarter                   18.0  265.722  133.5  332.687  39.0
# マリオカート8 デラックス_quarter                 31.0  219.968  181.0  105.269  85.0
# マリオカート ライブ ホームサーキット_quarter            2.0   63.500   63.5   62.933  19.0
# ゼルダ無双 厄災の黙示録_quarter                   2.0  153.500  153.5  184.555  23.0
# ピクミン3 デラックス_quarter                    2.0  102.000  102.0  130.108  10.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter          24.0  132.667  121.5   56.030  24.0
# New スーパーマリオブラザーズU デラックス_quarter       15.0  116.267  125.0   73.238  25.0
# Xenoblade Definitive Edition_quarter   4.0   38.000    8.0   62.695   4.0
#
#                                          最大値  変動係数(CV)  \
# リングフィット アドベンチャー_quarter                284.0     0.583
# 世界のアソビ大全51_quarter                     108.0     0.265
# スーパーマリオ 3Dコレクション_quarter               521.0     0.753
# スーパーマリオパーティ_quarter                    530.0     0.867
# ペーパーマリオ オリガミキング_quarter                282.0     1.484
# あつまれ どうぶつの森_quarter                   1177.0     1.252
# マリオカート8 デラックス_quarter                  462.0     0.479
# マリオカート ライブ ホームサーキット_quarter            108.0     0.991
# ゼルダ無双 厄災の黙示録_quarter                   284.0     1.202
# ピクミン3 デラックス_quarter                    194.0     1.276
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter           276.0     0.422
# New スーパーマリオブラザーズU デラックス_quarter        331.0     0.630
# Xenoblade Definitive Edition_quarter   132.0     1.650
#
#                                       相関係数(hard_total_sales)  \
# リングフィット アドベンチャー_quarter                                0.799
# 世界のアソビ大全51_quarter                                    -0.127
# スーパーマリオ 3Dコレクション_quarter                               0.345
# スーパーマリオパーティ_quarter                                    0.464
# ペーパーマリオ オリガミキング_quarter                               -0.160
# あつまれ どうぶつの森_quarter                                    0.203
# マリオカート8 デラックス_quarter                                  0.831
# マリオカート ライブ ホームサーキット_quarter                              NaN
# ゼルダ無双 厄災の黙示録_quarter                                     NaN
# ピクミン3 デラックス_quarter                                      NaN
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                           0.210
# New スーパーマリオブラザーズU デラックス_quarter                        0.108
# Xenoblade Definitive Edition_quarter                  -0.317
#
#                                       p値(hard_total_sales)  データ数(再掲)    総販売量
# リングフィット アドベンチャー_quarter                             0.0018      12.0  1538.0
# 世界のアソビ大全51_quarter                                  0.8383       5.0   422.0
# スーパーマリオ 3Dコレクション_quarter                            0.7758       3.0   901.0
# スーパーマリオパーティ_quarter                                 0.0812      15.0  2066.0
# ペーパーマリオ オリガミキング_quarter                             0.8979       3.0   312.0
# あつまれ どうぶつの森_quarter                                 0.4201      18.0  4783.0
# マリオカート8 デラックス_quarter                               0.0000      31.0  6819.0
# マリオカート ライブ ホームサーキット_quarter                            NaN       2.0   127.0
# ゼルダ無双 厄災の黙示録_quarter                                   NaN       2.0   307.0
# ピクミン3 デラックス_quarter                                    NaN       2.0   204.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                        0.3248      24.0  3184.0
# New スーパーマリオブラザーズU デラックス_quarter                     0.7022      15.0  1744.0
# Xenoblade Definitive Edition_quarter                0.6830       4.0   152.0

# %%
# 残差相関係数>0.35でのフィルタの結果は。販売量でのフィルタよりもCV_R2_meanとCV_R2_stdは改善した
# ただ、データ数が少ないタイトルも多く、分析結果の数値の信頼性は低い
# データ数が少ないタイトルは、販売量の最大値が総販売量に占める割合が大きく、ローンチ直後の初期スパイクとハード販売量が同じ動きをしているものが高相関に見える可能性が高い。
# 　ペーパーマリオ オリガミキング、マリオカート ライブ ホームサーキット、ゼルダ無双 厄災の黙示録、ピクミン3 デラックス、Xenoblade Definitive Edition

# 販売量のフィルタで回帰したものと、季節調整の相関係数でフィルタして回帰したケースでは、モデルの当てはまりは改善したが、そこて抽出したタイトルをそのまま影響度が高いものと判断はできない。
# データ数の少なさからくる見かけの高相関を示すタイトルや、多重共線性の影響でモデルから落とされたタイトルがあるはず。
# 以降の分析で、ハード売り上げを牽引するタイトルの影響の説明性を高めていく。

# 　->　次に 安定性選択　
#       回帰モデルの信頼性を向上させるために、データ数>=8でフィルタしたタイトルに数を絞る（フィルタで落としてしまう重要タイトルもあるかもしれないが、それは記述統計を参考にあとから拾う）
#　　　　安定性選択：時系列CVを繰り返し、各タイトルがどれだけの確率で非ゼロ係数として残るかを評価（elasticnetとlassoを利用）

# %%
# データ数>=8でフィルタしたタイトルでcompare_all
filtered_titles_by_count8 = get_titles_filtered_by_count(summary_df, min_count=8)
# display(filtered_titles_by_count8)

# 比較のためデータ数>=４でのフィルタを再掲
compare_filtered_by_count = compare_all(selected_df, y_col, filtered_titles_by_count, max_iter=100000, nonzero_threshold=1e-12)
display(compare_filtered_by_count)
print("== ここまで データ数4 でフィルタしてcompare_all ==")
display(filtered_titles_by_count)

compare_filtered_by_count8 = compare_all(selected_df, y_col, filtered_titles_by_count8, max_iter=100000, nonzero_threshold=1e-12)
display(compare_filtered_by_count8)
print("== ここまで データ数8 でフィルタしてcompare_all ==")
display(filtered_titles_by_count8)
# Out:
#                                                   データ数       平均    中央値  \
# マリオカート8 デラックス_quarter                             31.0  219.968  181.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                      24.0  132.667  121.5
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                     20.0  181.250  128.5
# スーパーマリオ オデッセイ_quarter                             20.0  146.450  110.5
# あつまれ どうぶつの森_quarter                               18.0  265.722  133.5
# スーパーマリオパーティ_quarter                               15.0  137.733  110.0
# New スーパーマリオブラザーズU デラックス_quarter                   15.0  116.267  125.0
# リングフィット アドベンチャー_quarter                           12.0  128.167  116.0
# Splatoon2_quarter                                 12.0  110.917  109.5
# Nintendo Switch Sports_quarter                    10.0  162.700  128.5
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                10.0  134.800   93.0
# マリオパーティ スーパースターズ_quarter                           9.0  155.444  119.0
# ポケットモンスター ソード・シールド_quarter                         8.0  303.500  132.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter   8.0  181.625   83.0
#
#                                                      標準偏差   最小値     最大値  \
# マリオカート8 デラックス_quarter                             105.269  85.0   462.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                       56.030  24.0   276.0
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                     246.249  36.0  1208.0
# スーパーマリオ オデッセイ_quarter                             186.181  24.0   907.0
# あつまれ どうぶつの森_quarter                               332.687  39.0  1177.0
# スーパーマリオパーティ_quarter                               119.373  32.0   530.0
# New スーパーマリオブラザーズU デラックス_quarter                    73.238  25.0   331.0
# リングフィット アドベンチャー_quarter                            74.693  16.0   284.0
# Splatoon2_quarter                                  87.474  31.0   361.0
# Nintendo Switch Sports_quarter                    125.332  53.0   484.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                153.783  31.0   559.0
# マリオパーティ スーパースターズ_quarter                          147.958  58.0   543.0
# ポケットモンスター ソード・シールド_quarter                        527.944  38.0  1606.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter  332.973  20.0  1000.0
#
#                                                   変動係数(CV)  \
# マリオカート8 デラックス_quarter                                0.479
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                         0.422
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                        1.359
# スーパーマリオ オデッセイ_quarter                                1.271
# あつまれ どうぶつの森_quarter                                  1.252
# スーパーマリオパーティ_quarter                                  0.867
# New スーパーマリオブラザーズU デラックス_quarter                      0.630
# リングフィット アドベンチャー_quarter                              0.583
# Splatoon2_quarter                                    0.789
# Nintendo Switch Sports_quarter                       0.770
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                   1.141
# マリオパーティ スーパースターズ_quarter                             0.952
# ポケットモンスター ソード・シールド_quarter                           1.740
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter     1.833
#
#                                                   相関係数(hard_total_sales)  \
# マリオカート8 デラックス_quarter                                              0.831
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                                       0.210
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                                      0.387
# スーパーマリオ オデッセイ_quarter                                              0.280
# あつまれ どうぶつの森_quarter                                                0.203
# スーパーマリオパーティ_quarter                                                0.464
# New スーパーマリオブラザーズU デラックス_quarter                                    0.108
# リングフィット アドベンチャー_quarter                                            0.799
# Splatoon2_quarter                                                 -0.213
# Nintendo Switch Sports_quarter                                     0.348
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                                 0.116
# マリオパーティ スーパースターズ_quarter                                           0.728
# ポケットモンスター ソード・シールド_quarter                                         0.335
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter                   0.368
#
#                                                   p値(hard_total_sales)  \
# マリオカート8 デラックス_quarter                                           0.0000
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                                    0.3248
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                                   0.0916
# スーパーマリオ オデッセイ_quarter                                           0.2319
# あつまれ どうぶつの森_quarter                                             0.4201
# スーパーマリオパーティ_quarter                                             0.0812
# New スーパーマリオブラザーズU デラックス_quarter                                 0.7022
# リングフィット アドベンチャー_quarter                                         0.0018
# Splatoon2_quarter                                               0.5068
# Nintendo Switch Sports_quarter                                  0.3247
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                              0.7499
# マリオパーティ スーパースターズ_quarter                                        0.0263
# ポケットモンスター ソード・シールド_quarter                                      0.4179
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter                0.3702
#
#                                                   データ数(再掲)    総販売量
# マリオカート8 デラックス_quarter                                 31.0  6819.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                          24.0  3184.0
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                         20.0  3625.0
# スーパーマリオ オデッセイ_quarter                                 20.0  2929.0
# あつまれ どうぶつの森_quarter                                   18.0  4783.0
# スーパーマリオパーティ_quarter                                   15.0  2066.0
# New スーパーマリオブラザーズU デラックス_quarter                       15.0  1744.0
# リングフィット アドベンチャー_quarter                               12.0  1538.0
# Splatoon2_quarter                                     12.0  1331.0
# Nintendo Switch Sports_quarter                        10.0  1627.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                    10.0  1348.0
# マリオパーティ スーパースターズ_quarter                               9.0  1399.0
# ポケットモンスター ソード・シールド_quarter                             8.0  2428.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter       8.0  1453.0
# [LASSO-TS] n_samples=33, n_features=35, nonzero=7/7  alpha=23.9503, l1_ratio=1.000
# R2=0.8790, Adjusted R2=0.8451, Intercept=453.8182
# [RIDGE-TS] n_samples=33, n_features=35, nonzero=35/35  alpha=14.8735
# R2=0.9313, Adjusted R2=nan, Intercept=453.8182
# [ELASTICNET-TS] n_samples=33, n_features=35, nonzero=33/33  alpha=3.56225, l1_ratio=0.800
# R2=0.8826, Adjusted R2=nan, Intercept=453.8182
# /// Lasso_nonzero_titles ///
# ['マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'スーパーマリオパーティ_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ARMS_quarter']
# /// Ridge_nonzero_titles ///
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ルイージマンション3_quarter',
#  '世界のアソビ大全51_quarter',
#  'Splatoon2_quarter',
#  'Xenoblade Definitive Edition_quarter',
#  'スーパーマリオメーカー2_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'Splatoon3_quarter',
#  'Nintendo Switch Sports_quarter',
#  '星のカービィ ディスカバリー_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'マリオストライカーズ バトルリーグ_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'New ポケモンスナップ_quarter',
#  'マリオゴルフ スーパーラッシュ_quarter',
#  'ミートピア_quarter',
#  'ARMS_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'ゼルダの伝説 夢をみる島_quarter',
#  'ペーパーマリオRPG_quarter',
#  'ルイージマンション2 HD_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'マリオテニス エース_quarter',
#  'ドンキーコング トロピカルフリーズ_quarter',
#  'ルイージマンション３_quarter']
# /// ElasticNet_nonzero_titles ///
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ルイージマンション3_quarter',
#  '世界のアソビ大全51_quarter',
#  'Splatoon2_quarter',
#  'Xenoblade Definitive Edition_quarter',
#  'スーパーマリオメーカー2_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'Nintendo Switch Sports_quarter',
#  '星のカービィ ディスカバリー_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'マリオストライカーズ バトルリーグ_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'New ポケモンスナップ_quarter',
#  'マリオゴルフ スーパーラッシュ_quarter',
#  'ミートピア_quarter',
#  'ARMS_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'ゼルダの伝説 夢をみる島_quarter',
#  'ペーパーマリオRPG_quarter',
#  'ルイージマンション2 HD_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'マリオテニス エース_quarter',
#  'ドンキーコング トロピカルフリーズ_quarter',
#  'ルイージマンション３_quarter']
# == compare_all内で実行した結果  R2 AdjR2 は in sample ==
#         model        R2     AdjR2  CV_R2_mean  CV_R2_std  nonzero
# 0       Lasso  0.878968  0.845079    0.373799   0.526196        7
# 1       Ridge  0.931267       NaN    0.368516   0.239189       35
# 2  ElasticNet  0.882563       NaN    0.381214   0.236403       33
# == ここまで データ数4 でフィルタしてcompare_all ==
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'ルイージマンション3_quarter',
#  '世界のアソビ大全51_quarter',
#  'Splatoon2_quarter',
#  'Xenoblade Definitive Edition_quarter',
#  'スーパーマリオメーカー2_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'ポケットモンスター スカーレット・バイオレット_quarter',
#  'Splatoon3_quarter',
#  'Nintendo Switch Sports_quarter',
#  '星のカービィ ディスカバリー_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'マリオストライカーズ バトルリーグ_quarter',
#  'Pokmon LEGENDS アルセウス_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter',
#  'New ポケモンスナップ_quarter',
#  'マリオゴルフ スーパーラッシュ_quarter',
#  'ミートピア_quarter',
#  'ARMS_quarter',
#  'ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter',
#  'ゼルダの伝説 夢をみる島_quarter',
#  'ペーパーマリオRPG_quarter',
#  'ルイージマンション2 HD_quarter',
#  'Super Mario Bros. Wonder_quarter',
#  'マリオテニス エース_quarter',
#  'ドンキーコング トロピカルフリーズ_quarter',
#  'ルイージマンション３_quarter']
# [LASSO-TS] n_samples=33, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8035, Adjusted R2=0.7671, Intercept=453.8182
# [RIDGE-TS] n_samples=33, n_features=14, nonzero=14/14  alpha=9.23671
# R2=0.8783, Adjusted R2=0.7837, Intercept=453.8182
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.473e+02, tolerance: 5.519e+01
#   model = cd_fast.enet_coordinate_descent(
# [ELASTICNET-TS] n_samples=33, n_features=14, nonzero=13/13  alpha=1.37382, l1_ratio=0.600
# R2=0.8478, Adjusted R2=0.7437, Intercept=453.8182
# /// Lasso_nonzero_titles ///
# ['マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  'スーパーマリオパーティ_quarter',
#  'スーパーマリオ オデッセイ_quarter']
# /// Ridge_nonzero_titles ///
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'Splatoon2_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'Nintendo Switch Sports_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter']
# /// ElasticNet_nonzero_titles ///
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'Splatoon2_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'Nintendo Switch Sports_quarter',
#  'マリオパーティ スーパースターズ_quarter']
# == compare_all内で実行した結果  R2 AdjR2 は in sample ==
#         model        R2     AdjR2  CV_R2_mean  CV_R2_std  nonzero
# 0       Lasso  0.803509  0.767122    0.340678   0.491296        5
# 1       Ridge  0.878343  0.783721    0.395217   0.307773       14
# 2  ElasticNet  0.847840  0.743730    0.387549   0.323737       13
# == ここまで データ数8 でフィルタしてcompare_all ==
# ['あつまれ どうぶつの森_quarter',
#  'マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter',
#  'スーパーマリオパーティ_quarter',
#  'New スーパーマリオブラザーズU デラックス_quarter',
#  'ポケットモンスター ソード・シールド_quarter',
#  'スーパーマリオ オデッセイ_quarter',
#  'Splatoon2_quarter',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter",
#  'Nintendo Switch Sports_quarter',
#  'マリオパーティ スーパースターズ_quarter',
#  'スーパーマリオ 3Dワールド + フューリーワールド_quarter']

# %%
# 最善のモデルではridgeとelasticnetのR2は改善したように見えるが、多重共線性の影響が強く残り、クロスバリデーションにおけるR2の平均値は低い
# データ数>=8でフィルタして説明変数を減らしたが、まだ回帰モデルは信頼性に欠ける

# 以下、安定性選択

# %%
def _block_indices(n, block_len, rng):
    """
    長さnの系列から、長さblock_lenの連続ブロックの開始位置をランダムに選び、その区間の整数インデックスを返す
    """
    if block_len >= n:
        return np.arange(n)
    start = rng.integers(0, n - block_len + 1)
    return np.arange(start, start + block_len)

def stability_selection(
    df, y_col, X_cols,
    kind="elasticnet",                 
    alphas=None, l1_ratios=None,
    n_repeats=200,                     # 反復回数
    sample_frac=0.7,                   # 1反復あたりに使う連続ブロックの割合
    n_splits=4,                        # CV（TimeSeriesSplit）
    max_iter=10000,
    nonzero_threshold=1e-12,
    scoring="r2",
    random_state=0
):
    """
    TimeSeriesSplitCVで fit_regularized を実行
    これを n_repeats 回繰り返し、各特徴量が非ゼロで残る割合（選択確率）と符号の傾向を集計する。
    """
    X = df[X_cols].to_numpy()
    y = df[y_col].to_numpy()
    n_samples = len(df)

    # 探索グリッドのデフォルト設定
    if alphas is None:
        alphas = np.logspace(-4, 2, 30)
    if kind == "elasticnet" and l1_ratios is None:
        l1_ratios = [0.2, 0.4, 0.5, 0.6, 0.8]

    block_len = max(4, int(np.floor(n_samples * sample_frac)))  # 最低でも4四半期は確保
    rng = np.random.default_rng(random_state)

    # 集計用
    hit_count = np.zeros(len(X_cols), dtype=int)       # 非ゼロになった回数
    pos_count = np.zeros(len(X_cols), dtype=int)       # 係数が正だった回数
    neg_count = np.zeros(len(X_cols), dtype=int)       # 係数が負だった回数

    # 反復
    for r in range(n_repeats):
        idx = _block_indices(n_samples, block_len, rng)
        sub_df = df.iloc[idx]

        # 時系列CV
        res = fit_regularized(
            sub_df, y_col, X_cols,
            kind=kind,
            alphas=alphas,
            l1_ratios=l1_ratios,
            random_state=random_state + r,  # 反復で乱数シードをずらす
            n_splits=min(n_splits, max(2, len(idx) // 4)),  # ブロックが短いときは分割を最低２分割
            max_iter=max_iter,
            nonzero_threshold=nonzero_threshold,
            scoring=scoring
        )

        coef = res["model"].coef_
        # 非ゼロ判定
        is_nz = np.abs(coef) > nonzero_threshold
        hit_count += is_nz.astype(int)

        # 符号カウント（非ゼロのみ）
        pos_count += (coef > nonzero_threshold).astype(int)
        neg_count += (coef < -nonzero_threshold).astype(int)
        print(f'ループ回数:{r+1}/{n_repeats}回')

    # 選択確率・符号一貫性
    sel_rate = hit_count / n_repeats
    pos_share = np.divide(pos_count, hit_count, out=np.zeros_like(pos_count, dtype=float), where=hit_count > 0)
    neg_share = np.divide(neg_count, hit_count, out=np.zeros_like(neg_count, dtype=float), where=hit_count > 0)
    sign_stability = np.maximum(pos_share, neg_share)  # 正・負どちらか優勢なほう

    stability_df = (
        pd.DataFrame({
            "feature": X_cols,
            "selection_rate": sel_rate,        # どれだけの頻度で選ばれたか（0〜1）
            "sign_positive_share": pos_share,  # 選ばれた回のうち正の割合
            "sign_negative_share": neg_share,  # 選ばれた回のうち負の割合
            "sign_stability": sign_stability,  # 符号の安定度（0.5〜1.0）
            "hit_count": hit_count,
            "repeats": n_repeats
        })
        .sort_values(["selection_rate", "sign_stability"], ascending=False)
        .reset_index(drop=True)
    )

    return {
        "stability_table": stability_df, # dfそのもの
        "n_repeats": n_repeats,
        "block_len": block_len,
        "kind": kind,
        "alphas": alphas,
        "l1_ratios": l1_ratios
    }

def summarize_stability(stab_result, k=15, min_sel_rate=0.3, min_sign_stability=0.6):
    """
    安定性選択の結果から、影響度ランキング（選択確率の高い順）を作成。
    しきい値でフィルタもしやすくする。
    """
    kind = stab_result["kind"] # 回帰の種類
    df = stab_result["stability_table"].copy() # 結果のdf
    # ranked = df[(df["selection_rate"] >= min_sel_rate) & (df["sign_stability"] >= min_sign_stability)] # 条件で抽出されたdf
    ranked = df[(df["selection_rate"] >= min_sel_rate)] # 条件で抽出されたdf
    return kind, df, ranked, df.head(k)

def plot_stability_summary(df, title, kind):
    plt.figure(figsize=(12, 6))
    df = df.sort_values("selection_rate")
    k = len(df)
    plt.barh(df["feature"], df["selection_rate"], alpha=0.7, label="Selection Rate")
    plt.xlim(0, 1.05)
    plt.xlabel("Rate")
    plt.title(f"Stability_selection {title}, k={k}, kind={kind}")
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# elasticnetで安定性選択（データ数>8でフィルタしたタイトル）
valid_titles = summary_df.loc[summary_df["データ数"] >= 8].index.tolist()
print(f"len(valid_titles):{len(valid_titles)}")
stab = stability_selection(
    df=selected_df[valid_titles+["hard_total_sales"]],
    y_col="hard_total_sales",
    X_cols=valid_titles,
    kind="elasticnet",
    # kind='lasso',
    n_repeats=200,
    sample_frac=0.7,            # 1回あたり連続ブロックの長さ（70%）
    n_splits=4,                 # 連続ブロック内のTimeSeriesSplit分割
    max_iter=500000,
    scoring="r2",
    random_state=0
)

# 全てのデータで安定性選択
# X_cols= [c for c in selected_cols if c != "hard_total_sales"]
# stab = stability_selection(
#     df=selected_df,
#     y_col="hard_total_sales",
#     X_cols=X_cols,
#     kind="elasticnet",
#     # kind='lasso',
#     n_repeats=200,
#     sample_frac=0.7,            # 1回あたり連続ブロックの長さ（70%）
#     n_splits=4,                 # 連続ブロック内のTimeSeriesSplit分割
#     max_iter=500000,
#     scoring="r2",
#     random_state=0
# )
# Out:
# len(valid_titles):14
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:1/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:2/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:3/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:4/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:5/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:6/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:7/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:8/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:9/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:10/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:11/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:12/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:13/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:14/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:15/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:16/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:17/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:18/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:19/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:20/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:21/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:22/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:23/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:24/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:25/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:26/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:27/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:28/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:29/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:30/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:31/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:32/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:33/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:34/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:35/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:36/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:37/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:38/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:39/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:40/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:41/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:42/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:43/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:44/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:45/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:46/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:47/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:48/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:49/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:50/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:51/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:52/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:53/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:54/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:55/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:56/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:57/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:58/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:59/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:60/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:61/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:62/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:63/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:64/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:65/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:66/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:67/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:68/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:69/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:70/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:71/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:72/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:73/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:74/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:75/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:76/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:77/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:78/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:79/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:80/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:81/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:82/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:83/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:84/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:85/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:86/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:87/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:88/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:89/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:90/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:91/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:92/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:93/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:94/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:95/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:96/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:97/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:98/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:99/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:100/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:101/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:102/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:103/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:104/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:105/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:106/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:107/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:108/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:109/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:110/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:111/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:112/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:113/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:114/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:115/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:116/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:117/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:118/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:119/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:120/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:121/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:122/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:123/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:124/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:125/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:126/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:127/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:128/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:129/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:130/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:131/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:132/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:133/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:134/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:135/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:136/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:137/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:138/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:139/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:140/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:141/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:142/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:143/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:144/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:145/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:146/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:147/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:148/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:149/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:150/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:151/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:152/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:153/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:154/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:155/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:156/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.800
# R2=0.9565, Adjusted R2=0.8805, Intercept=518.6957
# ループ回数:157/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:158/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:159/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:160/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:161/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:162/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:163/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:164/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:165/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:166/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:167/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:168/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:169/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:170/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:171/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:172/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:173/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:174/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:175/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:176/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.800
# R2=0.9338, Adjusted R2=0.8179, Intercept=515.5217
# ループ回数:177/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:178/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:179/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=0.853168, l1_ratio=0.800
# R2=0.9190, Adjusted R2=0.8020, Intercept=484.3478
# ループ回数:180/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:181/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:182/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.329034, l1_ratio=0.800
# R2=0.9500, Adjusted R2=0.8625, Intercept=513.9130
# ループ回数:183/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:184/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:185/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:186/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:187/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:188/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.00108264, l1_ratio=0.200
# R2=0.9603, Adjusted R2=0.8907, Intercept=486.8696
# ループ回数:189/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:190/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:191/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:192/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9425, Adjusted R2=0.8420, Intercept=519.7391
# ループ回数:193/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8880, Adjusted R2=0.7261, Intercept=510.7391
# ループ回数:194/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.853168, l1_ratio=0.800
# R2=0.9487, Adjusted R2=0.8589, Intercept=518.3478
# ループ回数:195/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=1.37382, l1_ratio=0.800
# R2=0.9045, Adjusted R2=0.7899, Intercept=492.0000
# ループ回数:196/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:197/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:198/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=0.529832, l1_ratio=0.200
# R2=0.9171, Adjusted R2=0.7719, Intercept=501.0870
# ループ回数:199/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=2.21222, l1_ratio=0.800
# R2=0.8859, Adjusted R2=0.7211, Intercept=494.6087
# ループ回数:200/200回

# %%
# 可視化
min_sel_rate=0.50,
kind, all_titles, ranked, top_view = summarize_stability(
    stab, # 
    k=15,
    min_sel_rate=min_sel_rate,
    # min_sign_stability=0.60
)
# print(all_titles)   # 閾値を満たすタイトル
# print(top_view)     # 上位k件のプレビュー

res = {}
res[f'res_{kind}'] = all_titles

plot_stability_summary(all_titles, title="All Features", kind=kind)
# plot_stability_summary(ranked, title="Ranked Features (selection_rate)", kind=kind)
# plot_stability_summary(top_view, title="Top-k Features (selection_rate)", kind=kind)

original_stab_sel_all_titles_elasticnet = all_titles
original_stab_sel_ranked_titles_elasticnet = ranked

# %%
# lassoで安定性選択

valid_titles = summary_df.loc[summary_df["データ数"] >= 8].index.tolist()
print(f"len(valid_titles):{len(valid_titles)}")
stab = stability_selection(
    df=selected_df[valid_titles+["hard_total_sales"]],
    y_col="hard_total_sales",
    X_cols=valid_titles,
    # kind="elasticnet",
    kind='lasso',
    n_repeats=200,
    sample_frac=0.7,            # 1回あたり連続ブロックの長さ（70%）
    n_splits=4,                 # 連続ブロック内のTimeSeriesSplit分割
    max_iter=500000,
    scoring="r2",
    random_state=0
)

# 全てのデータで安定性選択
# X_cols= [c for c in selected_cols if c != "hard_total_sales"]
# stab = stability_selection(
#     df=selected_df,
#     y_col="hard_total_sales",
#     X_cols=X_cols,
#     # kind="elasticnet",
#     kind='lasso',
#     n_repeats=200,
#     sample_frac=0.7,            # 1回あたり連続ブロックの長さ（70%）
#     n_splits=4,                 # 連続ブロック内のTimeSeriesSplit分割
#     max_iter=500000,
#     scoring="r2",
#     random_state=0
# )
# Out:
# len(valid_titles):14
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:1/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:2/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:3/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:4/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:5/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:6/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:7/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:8/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:9/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:10/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:11/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:12/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:13/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:14/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:15/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:16/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:17/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:18/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:19/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:20/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:21/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:22/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:23/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:24/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:25/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:26/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:27/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:28/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:29/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:30/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:31/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:32/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:33/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:34/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:35/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:36/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:37/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:38/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:39/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:40/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:41/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:42/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:43/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:44/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:45/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:46/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:47/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:48/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:49/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:50/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:51/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:52/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:53/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:54/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:55/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:56/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:57/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:58/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:59/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:60/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:61/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:62/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:63/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:64/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:65/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:66/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:67/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:68/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:69/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:70/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:71/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:72/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:73/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:74/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:75/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:76/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:77/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:78/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:79/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:80/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:81/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:82/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:83/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:84/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:85/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:86/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:87/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:88/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:89/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:90/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:91/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:92/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:93/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:94/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:95/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:96/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:97/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:98/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:99/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:100/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:101/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:102/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:103/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:104/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:105/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:106/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:107/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:108/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:109/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:110/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:111/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:112/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:113/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:114/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:115/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:116/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:117/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:118/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:119/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:120/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:121/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:122/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:123/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:124/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:125/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:126/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:127/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:128/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:129/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:130/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:131/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:132/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:133/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:134/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:135/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:136/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:137/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:138/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:139/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:140/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:141/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:142/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:143/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:144/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:145/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:146/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:147/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:148/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:149/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:150/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:151/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:152/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:153/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:154/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:155/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:156/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.9041, Adjusted R2=0.8889, Intercept=518.6957
# ループ回数:157/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:158/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:159/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:160/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:161/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:162/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:163/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:164/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:165/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:166/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:167/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:168/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:169/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:170/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:171/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:172/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:173/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:174/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:175/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:176/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8940, Adjusted R2=0.8772, Intercept=515.5217
# ループ回数:177/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:178/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:179/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.9003, Adjusted R2=0.8782, Intercept=484.3478
# ループ回数:180/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:181/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:182/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8885, Adjusted R2=0.8709, Intercept=513.9130
# ループ回数:183/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:184/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:185/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:186/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:187/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:188/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=9.23671, l1_ratio=1.000
# R2=0.9380, Adjusted R2=0.8951, Intercept=486.8696
# ループ回数:189/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:190/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:191/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:192/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=38.5662, l1_ratio=1.000
# R2=0.8987, Adjusted R2=0.8827, Intercept=519.7391
# ループ回数:193/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=38.5662, l1_ratio=1.000
# R2=0.8337, Adjusted R2=0.7713, Intercept=510.7391
# ループ回数:194/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=14.8735, l1_ratio=1.000
# R2=0.9407, Adjusted R2=0.9233, Intercept=518.3478
# ループ回数:195/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=5/5  alpha=38.5662, l1_ratio=1.000
# R2=0.8859, Adjusted R2=0.8523, Intercept=492.0000
# ループ回数:196/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:197/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:198/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.9527, Adjusted R2=0.9054, Intercept=501.0870
# ループ回数:199/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=5.73615, l1_ratio=1.000
# R2=0.9316, Adjusted R2=0.8494, Intercept=494.6087
# ループ回数:200/200回

# %%
# 可視化
min_sel_rate=0.50,
kind, all_titles, ranked, top_view = summarize_stability(
    stab, # 
    k=15,
    min_sel_rate=min_sel_rate,
)
# print(all_titles)  # 閾値を満たす“安定して効く”タイトル
# print(top_view)　　 # 上位k件のプレビュー

res = {}
res[f'res_{kind}'] = all_titles

plot_stability_summary(all_titles, title="All Features (データ数>=8)", kind=kind)
# plot_stability_summary(ranked, title=f"Ranked Features (selection_rate >= {min_sel_rate})", kind=kind)
# plot_stability_summary(top_view, title="Top-k Features (selection_rate)", kind=kind)

original_stab_sel_all_titles_lasso = all_titles
original_stab_sel_ranked_titles_lasso = ranked

# %%
# elasticnetの安定性選択（季節調整はせず）ではほとんどのタイトルが80%以上の確率で残る。
# lassoの安定性選択（季節調整はせず）では、選択率の上位、中位、下位が見えた。このデータをベースにして、影響力のあるタイトルの傾向を考えていく。

# elasticnet、lassoの安定性選択の50％以上で残ったタイトルについて、ハード販売量との関係性を可視化

# stability_dfとして、以降の分析では次の２つのdfを使う。（どちらも、データ数>=8でフィルタしたdfを対象にした分析の戻り値）
display(original_stab_sel_all_titles_elasticnet)
display(original_stab_sel_all_titles_lasso)
# Out:
#                                              feature  selection_rate  \
# 0                              マリオカート8 デラックス_quarter           1.000
# 1                            リングフィット アドベンチャー_quarter           1.000
# 2                       ゼルダの伝説 ブレス オブ ザ ワイルド_quarter           1.000
# 3                      大乱闘スマッシュブラザーズ SPECIAL_quarter           1.000
# 4   ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter           1.000
# 5                     Nintendo Switch Sports_quarter           1.000
# 6                           マリオパーティ スーパースターズ_quarter           1.000
# 7                                スーパーマリオパーティ_quarter           1.000
# 8                         ポケットモンスター ソード・シールド_quarter           1.000
# 9                    New スーパーマリオブラザーズU デラックス_quarter           1.000
# 10                スーパーマリオ 3Dワールド + フューリーワールド_quarter           0.950
# 11                                 Splatoon2_quarter           0.890
# 12                               あつまれ どうぶつの森_quarter           0.885
# 13                             スーパーマリオ オデッセイ_quarter           0.790
#
#     sign_positive_share  sign_negative_share  sign_stability  hit_count  \
# 0              1.000000             0.000000        1.000000        200
# 1              1.000000             0.000000        1.000000        200
# 2              1.000000             0.000000        1.000000        200
# 3              1.000000             0.000000        1.000000        200
# 4              1.000000             0.000000        1.000000        200
# 5              1.000000             0.000000        1.000000        200
# 6              1.000000             0.000000        1.000000        200
# 7              0.880000             0.120000        0.880000        200
# 8              0.220000             0.780000        0.780000        200
# 9              0.395000             0.605000        0.605000        200
# 10             0.000000             1.000000        1.000000        190
# 11             0.348315             0.651685        0.651685        178
# 12             0.372881             0.627119        0.627119        177
# 13             0.658228             0.341772        0.658228        158
#
#     repeats
# 0       200
# 1       200
# 2       200
# 3       200
# 4       200
# 5       200
# 6       200
# 7       200
# 8       200
# 9       200
# 10      200
# 11      200
# 12      200
# 13      200
#                                              feature  selection_rate  \
# 0                              マリオカート8 デラックス_quarter           1.000
# 1                            リングフィット アドベンチャー_quarter           1.000
# 2                                スーパーマリオパーティ_quarter           0.670
# 3                       ゼルダの伝説 ブレス オブ ザ ワイルド_quarter           0.530
# 4                              スーパーマリオ オデッセイ_quarter           0.390
# 5                           マリオパーティ スーパースターズ_quarter           0.375
# 6                      大乱闘スマッシュブラザーズ SPECIAL_quarter           0.360
# 7   ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter           0.345
# 8                     Nintendo Switch Sports_quarter           0.340
# 9                 スーパーマリオ 3Dワールド + フューリーワールド_quarter           0.340
# 10                   New スーパーマリオブラザーズU デラックス_quarter           0.335
# 11                                 Splatoon2_quarter           0.230
# 12                               あつまれ どうぶつの森_quarter           0.220
# 13                        ポケットモンスター ソード・シールド_quarter           0.110
#
#     sign_positive_share  sign_negative_share  sign_stability  hit_count  \
# 0              1.000000             0.000000        1.000000        200
# 1              1.000000             0.000000        1.000000        200
# 2              1.000000             0.000000        1.000000        134
# 3              1.000000             0.000000        1.000000        106
# 4              0.435897             0.564103        0.564103         78
# 5              1.000000             0.000000        1.000000         75
# 6              1.000000             0.000000        1.000000         72
# 7              1.000000             0.000000        1.000000         69
# 8              1.000000             0.000000        1.000000         68
# 9              0.000000             1.000000        1.000000         68
# 10             0.671642             0.328358        0.671642         67
# 11             0.521739             0.478261        0.521739         46
# 12             0.000000             1.000000        1.000000         44
# 13             0.000000             1.000000        1.000000         22
#
#     repeats
# 0       200
# 1       200
# 2       200
# 3       200
# 4       200
# 5       200
# 6       200
# 7       200
# 8       200
# 9       200
# 10      200
# 11      200
# 12      200
# 13      200

# %%
def select_lasso_titles(stability_df, min_prob=0.5, exclude_q=("Q_2","Q_3","Q_4"), k=None):
    """
    安定性選択の結果から、Lassoで選択確率>=min_probのタイトルを抽出。
    k:上位k件
    """
    df = stability_df.copy()
    # if "selection_rate" not in df.columns or "feature" not in df.columns:
    #     raise ValueError("stability_dfには feature と selection_rate 列が必要です。")
    mask = (~df["feature"].isin(exclude_q)) & (df["selection_rate"] >= min_prob)
    out = df.loc[mask].sort_values("selection_rate", ascending=False)
    if k is not None:
        out = out.head(k)
    return out["feature"].tolist()

def plot_titles_vs_hardware(
    df,
    stability_df=None,
    pickup_titles=[], #リスト
    y_col="hard_total_sales",
    min_prob=0.5,
    k=None,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,
    title="安定性選択タイトル × ハード販売量",
    left_ylabel = "タイトル販売量",
    right_ylabel = "ハード販売量",
    # figsize=(12, 6)
):
    """
    Lasso安定性選択の選択確率>=min_probのタイトル(必要なら上位k)を可視化
    右軸: ハード, 左軸: タイトル
    横軸: df.index（全期間）
    return: 描画したタイトルの一覧
    """
    # フォント
    if font_name is not None:
        plt.rcParams["font.family"] = font_name
    # タイトル選択
    if stability_df is not None:
        sel_titles = select_lasso_titles(stability_df, min_prob=min_prob, exclude_q=exclude_q, k=k)
    else:
        if not pickup_titles:
            raise ValueError("タイトルを指定してください。")
        sel_titles = pickup_titles
    # 存在チェック
    missing = [c for c in sel_titles + [y_col] if c not in df.columns]
    if missing:
        raise ValueError(f"dfに存在しない列があります: {missing}")
    x = df.index
    fig, ax_left = plt.subplots(figsize=(12, 6))
    # 左軸: タイトル
    for col in sel_titles:
        ax_left.plot(x, df[col], marker="o", linewidth=1.8, label=col)
    ax_left.set_ylabel(left_ylabel)
    # 右軸: ハード
    ax_right = ax_left.twinx()
    ax_right.bar(x, df[y_col], alpha=0.35, width=0.8, label=y_col)
    ax_right.set_ylabel(right_ylabel)

    if left_ylabel == "タイトル販売量残差":
        # 左右の 0 の位置をそろえる
        left_min = np.min(df[sel_titles].min().values)
        left_max = np.max(df[sel_titles].max().values)
        left_amp = max(abs(left_min), abs(left_max))
        if left_amp == 0:  # 全て0の保険
            left_amp = 1.0
        ax_left.set_ylim(-left_amp*1.05, left_amp*1.05)

        right_min = float(np.min(df[y_col]))
        right_max = float(np.max(df[y_col]))
        right_amp = max(abs(right_min), abs(right_max))
        if right_amp == 0:
            right_amp = 1.0
        ax_right.set_ylim(-right_amp*1.05, right_amp*1.05)

    # 軸・凡例・レイアウト
    ax_left.set_title(f"{title}（Lasso選択確率>={min_prob}"
                    + (f", 上位{k}件" if k is not None else "") + "）")
    # 2軸の凡例をまとめる
    h1, l1 = ax_left.get_legend_handles_labels()
    h2, l2 = ax_right.get_legend_handles_labels()
    ax_left.legend(h1 + h2, l1 + l2, loc="upper left", ncol=1, frameon=True)
    # 目盛り調整
    fig.autofmt_xdate(rotation=45)
    plt.tight_layout()
    plt.show()

    return sel_titles

# %%
# all_titles: 安定性選択の上位結果タイトルDataFrame
# 選択確率>=0.5で描画。
plot_titles_vs_hardware(
    df=selected_df,
    stability_df=all_titles,
    y_col="hard_total_sales",
    min_prob=0.5,
    k=10,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,
    title="Switch: タイトル×ハード販売"
)
# Out:
# ['マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'スーパーマリオパーティ_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter']

# %%
# 選択確率0.5以上、上位5本で描画。
# plot_titles_vs_hardware(
#     df=selected_df,
#     stability_df=all_titles,
#     y_col="hard_total_sales",
#     min_prob=0.5,
#     k=5,
#     exclude_q=("Q_2","Q_3","Q_4"),
#     font_name=None,
#     title="Switch: タイトル×ハード販売"
# )

# %%
# 第一四半期は、販売量100万本に到達せず、決算資料にタイトルが出ないため０になっているが、各期０に落ち込んでいるわけで歯ないことに注意する。
# "マリオカート8デラックス"の影響がローンチ日から長期にわたって継続、"リングフィットアドベンチャー"もハードの販売量と同じ動きをしている。
# ゼルダもロングテールなタイトルだが、ハード販売量の動きと連動していない。Sマリオパーティは、初期のスパイクは大きく販売期間も長く続いているが、初期スパイク後は季節イベントの影響が大きように見える。
# 季節性が排除されていないため、季節調整後の確認が必要。

# %%
# ここから、残差（季節性排除）で安定性選択　(データ数>=8でフィルタ)
valid_titles = summary_df.loc[summary_df["データ数"] >= 8].index.tolist()
valid_titles_with_resid =[t + "_resid" for t in valid_titles]
valid_titles_with_resid

# elasticnetと、lassoで安定性選択
# 季節性を取り除いた残差データは、seasonal_corr_filter_from_selected の戻り値 residuals_df を使う
# print(residuals_df.columns)
filtered_residuals_titles_by_count = residuals_df.columns.intersection(valid_titles_with_resid).to_list() + ["hard_total_sales_resid"]
filtered_residuals_titles_by_count # 残差化データからデータ数でフィルタしたタイトル
X_cols_resid = [c for c in filtered_residuals_titles_by_count if c != "hard_total_sales_resid"]
filtered_residuals_df_by_count = residuals_df[filtered_residuals_titles_by_count] # df
filtered_residuals_df_by_count.head()
# Out:
#             あつまれ どうぶつの森_quarter_resid  マリオカート8 デラックス_quarter_resid  \
# 2017-03-31                -175.777778                  -148.444444
# 2017-06-30                -148.625000                   195.500000
# 2017-09-30                -104.875000                   -70.750000
# 2017-12-31                -146.625000                   -77.125000
# 2018-03-31                -175.777778                    40.555556
#
#             リングフィット アドベンチャー_quarter_resid  ゼルダの伝説 ブレス オブ ザ ワイルド_quarter_resid  \
# 2017-03-31                     -30.111111                          172.222222
# 2017-06-30                     -29.000000                           86.625000
# 2017-09-30                     -36.125000                          -46.375000
# 2017-12-31                     -93.250000                           72.500000
# 2018-03-31                     -30.111111                           74.222222
#
#             大乱闘スマッシュブラザーズ SPECIAL_quarter_resid  スーパーマリオパーティ_quarter_resid  \
# 2017-03-31                           -69.222222              -4.577778e+01
# 2017-06-30                           -14.375000               4.947585e-14
# 2017-09-30                           -94.625000              -6.100000e+01
# 2017-12-31                          -266.250000              -1.457500e+02
# 2018-03-31                           -69.222222              -4.577778e+01
#
#             New スーパーマリオブラザーズU デラックス_quarter_resid  \
# 2017-03-31                             -68.555556
# 2017-06-30                               0.000000
# 2017-09-30                             -66.375000
# 2017-12-31                             -74.500000
# 2018-03-31                             -68.555556
#
#             ポケットモンスター ソード・シールド_quarter_resid  スーパーマリオ オデッセイ_quarter_resid  \
# 2017-03-31                     -2.711111e+01                -5.677778e+01
# 2017-06-30                     -2.968551e-14                 4.947585e-14
# 2017-09-30                     -3.987500e+01                -7.075000e+01
# 2017-12-31                     -2.331250e+02                 6.755000e+02
# 2018-03-31                     -2.711111e+01                 7.722222e+01
#
#             Splatoon2_quarter_resid  \
# 2017-03-31            -3.644444e+01
# 2017-06-30            -3.463309e-14
# 2017-09-30             2.836250e+02
# 2017-12-31             8.200000e+01
# 2018-03-31             7.455556e+01
#
#             ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter_resid  \
# 2017-03-31                                      -1.466667e+01
# 2017-06-30                                       9.895169e-15
# 2017-09-30                                      -4.233350e-14
# 2017-12-31                                      -1.651250e+02
# 2018-03-31                                      -1.466667e+01
#
#             Nintendo Switch Sports_quarter_resid  \
# 2017-03-31                            -23.888889
# 2017-06-30                            -60.500000
# 2017-09-30                            -46.750000
# 2017-12-31                            -69.250000
# 2018-03-31                            -23.888889
#
#             マリオパーティ スーパースターズ_quarter_resid  \
# 2017-03-31                   -4.355556e+01
# 2017-06-30                    9.895169e-15
# 2017-09-30                   -3.075000e+01
# 2017-12-31                   -9.512500e+01
# 2018-03-31                   -4.355556e+01
#
#             スーパーマリオ 3Dワールド + フューリーワールド_quarter_resid  hard_total_sales_resid
# 2017-03-31                                -78.222222              -18.777778
# 2017-06-30                                -13.625000             -119.375000
# 2017-09-30                                -24.625000              -81.500000
# 2017-12-31                                -42.250000             -129.750000
# 2018-03-31                                -78.222222                0.222222

# %%
# 残差化したデータ（データ数>8）でのelasticnetの安定性選択
min_sel_rate = 0.5
stab = stability_selection(
    df=filtered_residuals_df_by_count,
    y_col="hard_total_sales_resid",
    X_cols=X_cols_resid,
    kind="elasticnet",
    # kind='lasso',
    n_repeats=200,
    sample_frac=0.7,            # 1回あたり連続ブロックの長さ（全体の70%）
    n_splits=4,                 # 連続ブロック内のTimeSeriesSplit分割
    max_iter=500000,
    scoring="r2",
    random_state=0
)

kind, all_titles, ranked, top_view = summarize_stability(
    stab,
    k=15,
    min_sel_rate=min_sel_rate,
    # min_sign_stability=0.60
)
print(all_titles)   # 実用閾値を満たすタイトル
# print(top_view)   # 上位k件のプレビュー

res = {}
res[f'res_{kind}'] = all_titles

resid_stab_sel_all_titles_elasticnet = all_titles
resid_stab_sel_ranked_titles_elasticnet = ranked

# 残差化したデータでのelasticnetの安定性選択の結果を可視化
plot_stability_summary(resid_stab_sel_all_titles_elasticnet, title=f"All Features_resid", kind=kind)
# Out:
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:1/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:2/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:3/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:4/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:5/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:6/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:7/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:8/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:9/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:10/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:11/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:12/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:13/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:14/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:15/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:16/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:17/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:18/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:19/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:20/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:21/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:22/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:23/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:24/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:25/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:26/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:27/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:28/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:29/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:30/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:31/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:32/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:33/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:34/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:35/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:36/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:37/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:38/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:39/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:40/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:41/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:42/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:43/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:44/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:45/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:46/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:47/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:48/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:49/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:50/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:51/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:52/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:53/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:54/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:55/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:56/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:57/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:58/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:59/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:60/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:61/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:62/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:63/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:64/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:65/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:66/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:67/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:68/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:69/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:70/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:71/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:72/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:73/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:74/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:75/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:76/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:77/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:78/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:79/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:80/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:81/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:82/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:83/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:84/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:85/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:86/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:87/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:88/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:89/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:90/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:91/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:92/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:93/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:94/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:95/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:96/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:97/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:98/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:99/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:100/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:101/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:102/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:103/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:104/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:105/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:106/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:107/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:108/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:109/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:110/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:111/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:112/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:113/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:114/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:115/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:116/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:117/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:118/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:119/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:120/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:121/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:122/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:123/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:124/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:125/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:126/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:127/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:128/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:129/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:130/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:131/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:132/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:133/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:134/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:135/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:136/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:137/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:138/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:139/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:140/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:141/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:142/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:143/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:144/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:145/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:146/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:147/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:148/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:149/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:150/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:151/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:152/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:153/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:154/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:155/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:156/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=14.8735, l1_ratio=0.800
# R2=0.4569, Adjusted R2=0.0043, Intercept=53.6069
# ループ回数:157/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:158/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:159/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:160/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:161/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:162/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:163/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:164/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:165/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:166/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:167/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:168/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:169/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:170/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:171/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:172/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:173/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:174/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:175/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:176/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=14.8735, l1_ratio=0.800
# R2=0.4617, Adjusted R2=-0.1843, Intercept=50.4330
# ループ回数:177/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:178/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:179/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7429, Adjusted R2=0.2930, Intercept=42.6232
# ループ回数:180/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:181/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:182/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=1.37382, l1_ratio=0.200
# R2=0.7204, Adjusted R2=0.2311, Intercept=51.3949
# ループ回数:183/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:184/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:185/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:186/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:187/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:188/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=0.800
# R2=0.5911, Adjusted R2=0.1821, Intercept=45.1449
# ループ回数:189/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:190/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:191/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:192/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.5586, Adjusted R2=-0.0790, Intercept=57.2210
# ループ回数:193/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.3520, Adjusted R2=-0.7819, Intercept=44.6679
# ループ回数:194/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=14/14  alpha=5.73615, l1_ratio=0.200
# R2=0.4252, Adjusted R2=-0.5806, Intercept=52.2766
# ループ回数:195/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=9.23671, l1_ratio=0.800
# R2=0.7491, Adjusted R2=0.3867, Intercept=26.9112
# ループ回数:196/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:197/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:198/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=13/13  alpha=5.73615, l1_ratio=0.400
# R2=0.4564, Adjusted R2=-0.3287, Intercept=59.3623
# ループ回数:199/200回
# [ELASTICNET-TS] n_samples=23, n_features=14, nonzero=12/12  alpha=9.23671, l1_ratio=0.800
# R2=0.7268, Adjusted R2=0.3989, Intercept=28.5374
# ループ回数:200/200回
#                                               feature  selection_rate  \
# 0                           あつまれ どうぶつの森_quarter_resid           1.000
# 1                         マリオカート8 デラックス_quarter_resid           1.000
# 2                       リングフィット アドベンチャー_quarter_resid           1.000
# 3                  ゼルダの伝説 ブレス オブ ザ ワイルド_quarter_resid           1.000
# 4                 大乱闘スマッシュブラザーズ SPECIAL_quarter_resid           1.000
# 5                           スーパーマリオパーティ_quarter_resid           1.000
# 6   ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quart...           1.000
# 7            スーパーマリオ 3Dワールド + フューリーワールド_quarter_resid           1.000
# 8               New スーパーマリオブラザーズU デラックス_quarter_resid           0.920
# 9                      マリオパーティ スーパースターズ_quarter_resid           0.920
# 10               Nintendo Switch Sports_quarter_resid           0.880
# 11                            Splatoon2_quarter_resid           0.820
# 12                        スーパーマリオ オデッセイ_quarter_resid           0.810
# 13                   ポケットモンスター ソード・シールド_quarter_resid           0.335
#
#     sign_positive_share  sign_negative_share  sign_stability  hit_count  \
# 0              1.000000             0.000000        1.000000        200
# 1              1.000000             0.000000        1.000000        200
# 2              1.000000             0.000000        1.000000        200
# 3              1.000000             0.000000        1.000000        200
# 4              1.000000             0.000000        1.000000        200
# 5              1.000000             0.000000        1.000000        200
# 6              1.000000             0.000000        1.000000        200
# 7              1.000000             0.000000        1.000000        200
# 8              1.000000             0.000000        1.000000        184
# 9              1.000000             0.000000        1.000000        184
# 10             0.000000             1.000000        1.000000        176
# 11             0.939024             0.060976        0.939024        164
# 12             0.141975             0.858025        0.858025        162
# 13             0.417910             0.582090        0.582090         67
#
#     repeats
# 0       200
# 1       200
# 2       200
# 3       200
# 4       200
# 5       200
# 6       200
# 7       200
# 8       200
# 9       200
# 10      200
# 11      200
# 12      200
# 13      200

# %%
# 残差化したデータ（データ数>8）でのlassoの安定性選択
min_sel_rate = 0.5
stab = stability_selection(
    df=filtered_residuals_df_by_count,
    y_col="hard_total_sales_resid",
    X_cols=X_cols_resid,
    # kind="elasticnet",
    kind='lasso',
    n_repeats=200,
    sample_frac=0.7,            # 1回あたり連続ブロックの長さ（全体の70%）
    n_splits=4,                 # 連続ブロック内のTimeSeriesSplit分割
    max_iter=500000,
    scoring="r2",
    random_state=0
)

kind, all_titles, ranked, top_view = summarize_stability(
    stab,
    k=15,
    min_sel_rate=min_sel_rate,
    # min_sign_stability=0.60
)
print(all_titles)   # 実用閾値を満たす“安定して効く”タイトル
# print(top_view)   # 上位k件のプレビュー

res = {}
res[f'res_{kind}'] = all_titles

resid_stab_sel_all_titles_lasso = all_titles
resid_stab_sel_ranked_titles_lasso = ranked

plot_stability_summary(resid_stab_sel_all_titles_lasso, title="All Features_resid ", kind=kind)
# Out:
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:1/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:2/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:3/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:4/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:5/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:6/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:7/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:8/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:9/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:10/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:11/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:12/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:13/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:14/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:15/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:16/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:17/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:18/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:19/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:20/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:21/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:22/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:23/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:24/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:25/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:26/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:27/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:28/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:29/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:30/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:31/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:32/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:33/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:34/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:35/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:36/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:37/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:38/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:39/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:40/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:41/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:42/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:43/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:44/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:45/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:46/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:47/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:48/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:49/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:50/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:51/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:52/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:53/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:54/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:55/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:56/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:57/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:58/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:59/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:60/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:61/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:62/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:63/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:64/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:65/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:66/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:67/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:68/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:69/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:70/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:71/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:72/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:73/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:74/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:75/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:76/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:77/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:78/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:79/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:80/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:81/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:82/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:83/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:84/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:85/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:86/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:87/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:88/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:89/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:90/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:91/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:92/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:93/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:94/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:95/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:96/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:97/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:98/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:99/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:100/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:101/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:102/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:103/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:104/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:105/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:106/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:107/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:108/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:109/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:110/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:111/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:112/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:113/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:114/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:115/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:116/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:117/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:118/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:119/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:120/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:121/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:122/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:123/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:124/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:125/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:126/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:127/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:128/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:129/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:130/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:131/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:132/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:133/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:134/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:135/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:136/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:137/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:138/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:139/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:140/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:141/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:142/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:143/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:144/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:145/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:146/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:147/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:148/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:149/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:150/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:151/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:152/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:153/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:154/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:155/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:156/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=11/11  alpha=5.73615, l1_ratio=1.000
# R2=0.8407, Adjusted R2=0.6815, Intercept=53.6069
# ループ回数:157/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:158/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:159/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:160/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:161/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:162/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:163/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:164/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:165/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:166/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:167/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:168/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:169/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:170/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:171/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:172/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:173/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:174/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:175/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:176/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=2.21222, l1_ratio=1.000
# R2=0.8990, Adjusted R2=0.8291, Intercept=50.4330
# ループ回数:177/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:178/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:179/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=10/10  alpha=3.56225, l1_ratio=1.000
# R2=0.8804, Adjusted R2=0.7807, Intercept=42.6232
# ループ回数:180/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:181/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:182/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=9/9  alpha=5.73615, l1_ratio=1.000
# R2=0.8591, Adjusted R2=0.7616, Intercept=51.3949
# ループ回数:183/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:184/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:185/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:186/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:187/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:188/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=1/1  alpha=38.5662, l1_ratio=1.000
# R2=0.5536, Adjusted R2=0.5324, Intercept=45.1449
# ループ回数:189/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:190/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:191/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:192/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=6/6  alpha=9.23671, l1_ratio=1.000
# R2=0.7874, Adjusted R2=0.7077, Intercept=57.2210
# ループ回数:193/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.6633, Adjusted R2=0.5885, Intercept=44.6679
# ループ回数:194/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=23.9503, l1_ratio=1.000
# R2=0.7072, Adjusted R2=0.6421, Intercept=52.2766
# ループ回数:195/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=8/8  alpha=23.9503, l1_ratio=1.000
# R2=0.8210, Adjusted R2=0.7188, Intercept=26.9112
# ループ回数:196/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:197/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:198/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=3/3  alpha=23.9503, l1_ratio=1.000
# R2=0.6746, Adjusted R2=0.6233, Intercept=59.3623
# ループ回数:199/200回
# [LASSO-TS] n_samples=23, n_features=14, nonzero=4/4  alpha=38.5662, l1_ratio=1.000
# R2=0.7223, Adjusted R2=0.6605, Intercept=28.5374
# ループ回数:200/200回
#                                               feature  selection_rate  \
# 0                       リングフィット アドベンチャー_quarter_resid           1.000
# 1                         マリオカート8 デラックス_quarter_resid           0.830
# 2                  ゼルダの伝説 ブレス オブ ザ ワイルド_quarter_resid           0.720
# 3                           スーパーマリオパーティ_quarter_resid           0.700
# 4                      マリオパーティ スーパースターズ_quarter_resid           0.500
# 5   ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quart...           0.460
# 6                             Splatoon2_quarter_resid           0.450
# 7                    ポケットモンスター ソード・シールド_quarter_resid           0.405
# 8               New スーパーマリオブラザーズU デラックス_quarter_resid           0.390
# 9                 大乱闘スマッシュブラザーズ SPECIAL_quarter_resid           0.260
# 10                        スーパーマリオ オデッセイ_quarter_resid           0.235
# 11               Nintendo Switch Sports_quarter_resid           0.060
# 12                          あつまれ どうぶつの森_quarter_resid           0.050
# 13           スーパーマリオ 3Dワールド + フューリーワールド_quarter_resid           0.000
#
#     sign_positive_share  sign_negative_share  sign_stability  hit_count  \
# 0              1.000000             0.000000        1.000000        200
# 1              1.000000             0.000000        1.000000        166
# 2              1.000000             0.000000        1.000000        144
# 3              1.000000             0.000000        1.000000        140
# 4              1.000000             0.000000        1.000000        100
# 5              1.000000             0.000000        1.000000         92
# 6              1.000000             0.000000        1.000000         90
# 7              0.000000             1.000000        1.000000         81
# 8              0.294872             0.705128        0.705128         78
# 9              1.000000             0.000000        1.000000         52
# 10             0.255319             0.744681        0.744681         47
# 11             1.000000             0.000000        1.000000         12
# 12             1.000000             0.000000        1.000000         10
# 13             0.000000             0.000000        0.000000          0
#
#     repeats
# 0       200
# 1       200
# 2       200
# 3       200
# 4       200
# 5       200
# 6       200
# 7       200
# 8       200
# 9       200
# 10      200
# 11      200
# 12      200
# 13      200

# %%
# 残差化後 選択率>0.5
resid_stab_sel_all_titles_lasso[resid_stab_sel_all_titles_lasso["selection_rate"] > 0.5]["feature"].to_list()
# Out:
# ['リングフィット アドベンチャー_quarter_resid',
#  'マリオカート8 デラックス_quarter_resid',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter_resid',
#  'スーパーマリオパーティ_quarter_resid']

# %%
# 残差化前 選択率>0.5
original_stab_sel_ranked_titles_lasso["feature"].to_list()
# Out:
# ['マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'スーパーマリオパーティ_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter']

# %%
# 販売データ（季節調整前）と、残差データ（季節調整後）の安定化選択で選択率0.5のタイトルが同じ。
# データ数が一定以上のタイトルでは、一定程度の分析精度を期待しても良さそう。

# %%
# 可視化のために、各タイトル、ローンチ日以前のデータをnanに戻す
def zero_to_nan_prelaunch(original_df, resid_df):
    """
    各タイトルについて、最初に販売データが現れる時点より前（発売前）を NaN に戻す。
    対象: *_quarter → *_quarter_resid
    """
    fixed_resid_df = resid_df.copy()
    for col in original_df.columns:
        if not col.endswith("_quarter"):
            continue
        resid_col = col + "_resid"
        if resid_col in fixed_resid_df.columns:
            first_valid_idx = original_df[col].first_valid_index()
            if first_valid_idx is not None:
                mask = original_df.index < first_valid_idx
                fixed_resid_df.loc[mask, resid_col] = np.nan
    return fixed_resid_df

zero_to_nan_prelaunch(df, residuals_df).head(30)
# Out:
#             hard_total_sales_resid  あつまれ どうぶつの森_quarter_resid  \
# 2017-03-31              -18.777778                        NaN
# 2017-06-30             -119.375000                        NaN
# 2017-09-30              -81.500000                        NaN
# 2017-12-31             -129.750000                        NaN
# 2018-03-31                0.222222                        NaN
# 2018-06-30             -128.375000                        NaN
# 2018-09-30              -54.500000                        NaN
# 2018-12-31               89.250000                        NaN
# 2019-03-31              -45.777778                        NaN
# 2019-06-30             -130.375000                        NaN
# 2019-09-30               57.500000                        NaN
# 2019-12-31               86.250000                        NaN
# 2020-03-31               17.222222                1001.222222
# 2020-06-30              251.625000                 914.375000
# 2020-09-30              312.500000                 259.125000
# 2020-12-31              303.250000                 367.375000
# 2021-03-31              180.222222                 -31.777778
# 2021-06-30              129.625000                 -22.625000
# 2021-09-30                8.500000                  -8.875000
# 2021-12-31              213.250000                 130.375000
# 2022-03-31              119.222222                 -73.777778
# 2022-06-30               27.625000                -148.625000
# 2022-09-30              -49.500000                  48.125000
# 2022-12-31              -29.750000                  -4.625000
# 2023-03-31               13.222222                -112.777778
# 2023-06-30               74.625000                -148.625000
# 2023-09-30              -80.500000                  12.125000
# 2023-12-31             -162.750000                  -5.625000
# 2024-03-31              -97.777778                -118.777778
# 2024-06-30             -105.375000                -148.625000
#
#             マリオカート8 デラックス_quarter_resid  スーパーマリオ 3Dコレクション_quarter_resid  \
# 2017-03-31                          NaN                             NaN
# 2017-06-30                   195.500000                             NaN
# 2017-09-30                   -70.750000                             NaN
# 2017-12-31                   -77.125000                             NaN
# 2018-03-31                    40.555556                             NaN
# 2018-06-30                   -45.500000                             NaN
# 2018-09-30                   -22.750000                             NaN
# 2018-12-31                   -37.125000                             NaN
# 2019-03-31                    18.555556                             NaN
# 2019-06-30                   -38.500000                             NaN
# 2019-09-30                   -46.750000                             NaN
# 2019-12-31                    26.875000                             NaN
# 2020-03-31                    32.555556                             NaN
# 2020-06-30                    38.500000                             NaN
# 2020-09-30                    65.250000                    4.558750e+02
# 2023-03-31                           1.216667e+02             4.522222e+01
# 2023-06-30                           4.947585e-14             2.473792e-14
# 2023-09-30                           9.887500e+01            -9.875000e+01
# 2023-12-31                          -1.770000e+02             6.312500e+01
# 2024-03-31                           2.866667e+01             1.622222e+01
# 2024-06-30                           4.947585e-14             2.473792e-14
#
#             Nintendo Switch Sports_quarter_resid  \
# 2017-03-31                                   NaN
# 2017-06-30                                   NaN
# 2017-09-30                                   NaN
# 2017-12-31                                   NaN
# 2018-03-31                                   NaN
# 2018-06-30                                   NaN
# 2018-09-30                                   NaN
# 2018-12-31                                   NaN
# 2019-03-31                                   NaN
# 2019-06-30                                   NaN
# 2019-09-30                                   NaN
# 2019-12-31                                   NaN
# 2020-03-31                                   NaN
# 2020-06-30                                   NaN
# 2020-09-30                                   NaN
# 2020-12-31                                   NaN
# 2021-03-31                                   NaN
# 2021-06-30                                   NaN
# 2021-09-30                                   NaN
# 2021-12-31                                   NaN
# 2022-03-31                                   NaN
# 2022-06-30                            423.500000
# 2022-09-30                             84.250000
# 2022-12-31                            176.750000
# 2023-03-31                             75.111111
# 2023-06-30                            -60.500000
# 2023-09-30                             70.250000
# 2023-12-31                            101.750000
# 2024-03-31                             39.111111
# 2024-06-30                            -60.500000
#
#             星のカービィ ディスカバリー_quarter_resid  マリオパーティ スーパースターズ_quarter_resid  \
# 2017-03-31                           NaN                             NaN
# 2017-06-30                           NaN                             NaN
# 2017-09-30                           NaN                             NaN
# 2017-12-31                           NaN                             NaN
# 2018-03-31                           NaN                             NaN
# 2018-06-30                           NaN                             NaN
# 2018-09-30                           NaN                             NaN
# 2018-12-31                           NaN                             NaN
# 2019-03-31                           NaN                             NaN
# 2019-06-30                           NaN                             NaN
# 2019-09-30                           NaN                             NaN
# 2019-12-31                           NaN                             NaN
# 2020-03-31                           NaN                             NaN
# 2020-06-30                           NaN                             NaN
# 2020-09-30                           NaN                             NaN
# 2020-12-31                           NaN                             NaN
# 2021-03-31                           NaN                             NaN
# 2021-06-30                           NaN                             NaN
# 2021-09-30                           NaN                             NaN
# 2021-12-31                           NaN                    4.478750e+02
# 2022-03-31                       220.000                    1.014444e+02
# 2022-06-30                       164.500                    9.895169e-15
# 2022-09-30                        63.875                    8.825000e+01
# 2022-12-31                        75.250                    3.587500e+01
# 2023-03-31                       -11.000                    3.544444e+01
# 2023-06-30                       -23.500                    9.895169e-15
# 2023-09-30                        -9.125                    9.625000e+01
# 2023-12-31                       -10.750                   -8.125000e+00
# 2024-03-31                        61.000                    1.444444e+01
# 2024-06-30                       -23.500                    9.895169e-15
#
#             マリオストライカーズ バトルリーグ_quarter_resid  \
# 2017-03-31                              NaN
# 2017-06-30                              NaN
# 2017-09-30                              NaN
# 2017-12-31                              NaN
# 2018-03-31                              NaN
# 2018-06-30                              NaN
# 2018-09-30                              NaN
# 2018-12-31                              NaN
# 2019-03-31                              NaN
# 2019-06-30                              NaN
# 2019-09-30                              NaN
# 2019-12-31                              NaN
# 2020-03-31                              NaN
# 2020-06-30                              NaN
# 2020-09-30                              NaN
# 2020-12-31                              NaN
# 2021-03-31                              NaN
# 2021-06-30                              NaN
# 2021-09-30                              NaN
# 2021-12-31                              NaN
# 2022-03-31                              NaN
# 2022-06-30                       167.125000
# 2022-09-30                        22.750000
# 2022-12-31                        26.250000
# 2023-03-31                         6.222222
# 2023-06-30                       -23.875000
# 2023-09-30                        -3.250000
# 2023-12-31                        -3.750000
# 2024-03-31                        -0.777778
# 2024-06-30                       -23.875000
#
#             Pokmon LEGENDS アルセウス_quarter_resid  \
# 2017-03-31                                 NaN
# 2017-06-30                                 NaN
# 2017-09-30                                 NaN
# 2017-12-31                                 NaN
# 2018-03-31                                 NaN
# 2018-06-30                                 NaN
# 2018-09-30                                 NaN
# 2018-12-31                                 NaN
# 2019-03-31                                 NaN
# 2019-06-30                                 NaN
# 2019-09-30                                 NaN
# 2019-12-31                                 NaN
# 2020-03-31                                 NaN
# 2020-06-30                                 NaN
# 2020-09-30                                 NaN
# 2020-12-31                                 NaN
# 2021-03-31                                 NaN
# 2021-06-30                                 NaN
# 2021-09-30                                 NaN
# 2021-12-31                                 NaN
# 2022-03-31                        1.121333e+03
# 2022-06-30                        2.473792e-14
# 2022-09-30                        1.120000e+02
# 2022-12-31                        6.212500e+01
# 2023-03-31                       -1.226667e+02
# 2023-06-30                        2.473792e-14
# 2023-09-30                       -1.600000e+01
# 2023-12-31                       -8.875000e+00
# 2024-03-31                       -1.426667e+02
# 2024-06-30                        2.473792e-14
#
#             スーパーマリオ 3Dワールド + フューリーワールド_quarter_resid  ゼノブレイド3_quarter_resid  \
# 2017-03-31                                       NaN                    NaN
# 2017-06-30                                       NaN                    NaN
# 2017-09-30                                       NaN                    NaN
# 2017-12-31                                       NaN                    NaN
# 2018-03-31                                       NaN                    NaN
# 2018-06-30                                       NaN                    NaN
# 2018-09-30                                       NaN                    NaN
# 2018-12-31                                       NaN                    NaN
# 2019-03-31                                       NaN                    NaN
# 2019-06-30                                       NaN                    NaN
# 2019-09-30                                       NaN                    NaN
# 2019-12-31                                       NaN                    NaN
# 2020-03-31                                       NaN                    NaN
# 2020-06-30                                       NaN                    NaN
# 2020-09-30                                       NaN                    NaN
# 2020-12-31                                       NaN                    NaN
# 2021-03-31                                480.777778                    NaN
# 2021-06-30                                 95.375000                    NaN
# 2021-09-30                                 52.375000                    NaN
# 2021-12-31                                 97.750000                    NaN
# 2022-03-31                                -20.222222                    NaN
# 2022-06-30                                -13.625000                    NaN
# 2022-09-30                                -24.625000           1.505000e+02
# 2022-12-31                                 96.750000           7.875000e+00
# 2023-03-31                                -22.222222           4.444444e+00
# 2023-06-30                                -13.625000          -3.092240e-15
# 2023-09-30                                 95.375000          -2.150000e+01
# 2023-12-31                                 16.750000          -1.125000e+00
# 2024-03-31                                -47.222222          -5.555556e-01
# 2024-06-30                                -13.625000          -3.092240e-15
#
#             ファイアーエムブレム エンゲージ_quarter_resid  星のカービィ Wii デラックス_quarter_resid  \
# 2017-03-31                             NaN                             NaN
# 2017-06-30                             NaN                             NaN
# 2023-12-31                                 NaN                 -4.625000
# 2024-03-31                                 NaN                 -1.222222
# 2024-06-30                                 NaN                -17.250000
#
#             ドンキーコング トロピカルフリーズ_quarter_resid  スーパーマリオRPG_quarter_resid  \
# 2017-03-31                              NaN                       NaN
# 2017-06-30                              NaN                       NaN
# 2017-09-30                              NaN                       NaN
# 2017-12-31                              NaN                       NaN
# 2018-03-31                              NaN                       NaN
# 2018-06-30                       122.500000                       NaN
# 2018-09-30                        23.625000                       NaN
# 2018-12-31                        35.875000                       NaN
# 2019-03-31                        15.111111                       NaN
# 2019-06-30                       -17.500000                       NaN
# 2019-09-30                        -3.375000                       NaN
# 2019-12-31                        -5.125000                       NaN
# 2020-03-31                        -1.888889                       NaN
# 2020-06-30                       -17.500000                       NaN
# 2020-09-30                        -3.375000                       NaN
# 2020-12-31                        -5.125000                       NaN
# 2021-03-31                        -1.888889                       NaN
# 2021-06-30                       -17.500000                       NaN
# 2021-09-30                        -3.375000                       NaN
# 2021-12-31                        -5.125000                       NaN
# 2022-03-31                        -1.888889                       NaN
# 2022-06-30                       -17.500000                       NaN
# 2022-09-30                        -3.375000                       NaN
# 2022-12-31                        -5.125000                       NaN
# 2023-03-31                        -1.888889                       NaN
# 2023-06-30                       -17.500000                       NaN
# 2023-09-30                        -3.375000                       NaN
# 2023-12-31                        -5.125000              2.747500e+02
# 2024-03-31                        -1.888889              1.511111e+01
# 2024-06-30                       -17.500000              7.421377e-15
#
#             プリンセスピーチ Showtime!_quarter_resid  マリオvs.ドンキーコング_quarter_resid  \
# 2017-03-31                               NaN                          NaN
# 2017-06-30                               NaN                          NaN
# 2017-09-30                               NaN                          NaN
# 2017-12-31                               NaN                          NaN
# 2018-03-31                               NaN                          NaN
# 2018-06-30                               NaN                          NaN
# 2018-09-30                               NaN                          NaN
# 2018-12-31                               NaN                          NaN
# 2019-03-31                               NaN                          NaN
# 2019-06-30                               NaN                          NaN
# 2019-09-30                               NaN                          NaN
# 2019-12-31                               NaN                          NaN
# 2020-03-31                               NaN                          NaN
# 2020-06-30                               NaN                          NaN
# 2020-09-30                               NaN                          NaN
# 2020-12-31                               NaN                          NaN
# 2021-03-31                               NaN                          NaN
# 2021-06-30                               NaN                          NaN
# 2021-09-30                               NaN                          NaN
# 2021-12-31                               NaN                          NaN
# 2022-03-31                               NaN                          NaN
# 2022-06-30                               NaN                          NaN
# 2022-09-30                               NaN                          NaN
# 2022-12-31                               NaN                          NaN
# 2023-03-31                               NaN                          NaN
# 2023-06-30                               NaN                          NaN
# 2023-09-30                               NaN                          NaN
# 2023-12-31                               NaN                          NaN
# 2024-03-31                      1.084444e+02                 9.955556e+01
# 2024-06-30                      3.092240e-15                 6.184481e-16
#
#             ドンキーコング リターンズ HD_quarter_resid  進め! キノピオ隊長_quarter_resid  \
# 2017-03-31                             NaN                       NaN
# 2017-06-30                             NaN                       NaN
# 2017-09-30                             NaN                       NaN
# 2017-12-31                             NaN                       NaN
# 2018-03-31                             NaN                       NaN
# 2018-06-30                             NaN                       NaN
# 2022-12-31                       2.490332e-16
# 2023-03-31                      -1.400000e+01
# 2023-06-30                       4.329136e-15
# 2023-09-30                       7.020236e-17
# 2023-12-31                       2.490332e-16
# 2024-03-31                      -1.400000e+01
# 2024-06-30                       4.329136e-15

# %%
# 安定性選択で影響が強く出たタイトル（データ数>=8, 選択率>=50%）の販売量を可視化
plot_titles_vs_hardware(
    df=selected_df,
    stability_df=original_stab_sel_all_titles_lasso, 
    y_col="hard_total_sales",
    min_prob=0.5,
    # k=5,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,           
    title="Switch: タイトル販売×ハード販売（再掲示）",
    left_ylabel = "タイトル販売量",
    right_ylabel = "ハード販売量",
)

plot_titles_vs_hardware(
    df=zero_to_nan_prelaunch(df, residuals_df), # ローンチ前のデータはnanにしてプロットは非表示にする
    # df = residuals_df,
    stability_df=resid_stab_sel_all_titles_lasso,
    y_col="hard_total_sales_resid",
    min_prob=0.5,
    # k=5,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,
    title="Switch: タイトル販売残差×ハード販売残差",
    left_ylabel = "タイトル販売量残差",
    right_ylabel = "ハード販売量残差",
)
# Out:
# ['リングフィット アドベンチャー_quarter_resid',
#  'マリオカート8 デラックス_quarter_resid',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter_resid',
#  'スーパーマリオパーティ_quarter_resid',
#  'マリオパーティ スーパースターズ_quarter_resid']

# %%
# 残差化後データの2020第１四半期〜2021１四半期のプラスのスパイクは、新型コロナの影響で上振れしている可能性があるが、回帰モデル全体を大きく上振れさせるというほどでもない。
# ハードローンチ初期のマイナス残差は、発売後1年ほどの供給不足によるもの。当初販売見込みは年間1000万台（2018 年 3 ⽉期第２四半期決算説明会）。
# 一方で、供給体制が整い出したと考えらる2018後半からは、年末商戦販売量も伸び、2019年末のからのコロナのための需要増でピークを迎えている。
# 分析に有望な各タイトルは、どれもハードの販売状況に連動しているように見える。-> どのタイトルもハード売上を牽引した可能性がある
# リングフィット　新型コロナのパンデミックのタイミングを考えると、このタイトルがハード販売を大きく牽引。その後は減衰しているが、ハードへの影響はスラディングウィンドウで検証。
# マリオカート８　時期による振れはあるが、ハードの販売量に合わせて動いており、残差の動きの幅も一定。安定して、効いているタイトルと言える。
# ゼルダBOW　　　販売量はトップタイトルに比べ少ないが、残差はマリオカート同じく安定した動きをしており、ハードに対して一定の効果があったと言える。
# 　　　　　　　　各年度第１四半期は、販売１００万本に届かなかったため、決算資料のデータは欠損してる。そのため販売量０となり、谷が深く見えるが、実際は一定量の販売あったことを考慮する。
# スーパーマリオP　ローンチ2年ほどはハードと同様の動きをしているが、後半にかけて販売が減速している。

# %%
# 次に、lasso回帰elasticnet回帰を使った安定性選択でX％以上選択率になったタイトルだけを抽出して、スライディングウィンドウ回帰を試す
# ・販売データそのもの             original_stab_sel_all_titles_lasso  selected_df
# ・季節性を取り除いたデータ（残差） resid_stab_sel_all_titles_lasso     residuals_df

# 変数の影響度が時間の経過とともに安定しているのか、それとも変動しているのか。ただし、第1四半期はデータが欠損しているケースが多いので可視化結果を見る時には注意。

# %%
def sliding_window_betas(
    df,
    stab_df,            # 安定性選択テーブル
    y_col,              # 目的変数（"hard_total_sales", 残差なら "hard_total_sales_resid"）
    data_type = "",     # "sales" or "resid"
    min_prob=0.5,       # 安定性選択の閾値
    k = 6,              # プロットする件数(上位 k タイトル)
    exclude_q=(),       # 除外列("Q_2","Q_3","Q_4")
    window=8,           # ウィンドウ長
    step=1,             # シフト幅
    kind="elasticnet",  # "lasso" | "ridge" | "elasticnet"
    alphas=None,        
    l1_ratios=None,     # ElasticNet のときのみ
    n_splits=3,         # TimeSeriesSplit の分割
    max_iter=100000,
    scoring="r2",
    random_state=0,
):
    """
    stab_df を使って上位の特徴量を抽出 -> スライディングウィンドウで係数（β）の時系列推移を算出
    returns: 行=ウィンドウ末尾のtimestamp, 列=推定係数（β）のDataFrame
    """
    df = df.fillna(0)
    # stab_dfから上位の特徴量を抽出
    filtered = stab_df.loc[stab_df["selection_rate"] >= min_prob, "feature"]
    feats = filtered[~filtered.isin(exclude_q)].tolist()

    if alphas is None:
        alphas = np.logspace(-4, 2, 30)

    if kind == "lasso":
        base = Lasso(max_iter=max_iter, random_state=random_state)
        param_grid = {"reg__alpha": alphas}
    elif kind == "ridge":
        base = Ridge(max_iter=max_iter, random_state=random_state)
        param_grid = {"reg__alpha": alphas}
    elif kind == "elasticnet":
        if l1_ratios is None:
            l1_ratios = [0.2, 0.5, 0.8]
        base = ElasticNet(max_iter=max_iter, random_state=random_state)
        param_grid = {"reg__alpha": alphas, "reg__l1_ratio": l1_ratios}
    else:
        raise ValueError("kind は 'lasso' / 'ridge' / 'elasticnet' のいずれか")

    steps = [("scaler", StandardScaler()), ("reg", base)]   
    pipe = Pipeline(steps)
    # ウィンドウを動かして係数推移を作る
    rows = []
    idx = []
    best_l1_ratios = []
    n = len(df)
    for end in range(window, n + 1, step):
        start = end - window
        sub = df.iloc[start:end, :]
        sub_xy = sub[[y_col] + feats].dropna()
        if len(sub_xy) < max(6, n_splits + 2):
            continue

        X = sub_xy[feats].to_numpy()
        y = sub_xy[y_col].to_numpy()
        splits = min(n_splits, max(2, len(sub_xy) // 4))
        tscv = TimeSeriesSplit(n_splits=splits)
        gscv = GridSearchCV(pipe, param_grid=param_grid, cv=tscv, scoring=scoring, refit=True)
        gscv.fit(X, y)

        reg = gscv.best_estimator_.named_steps["reg"]
        coef = reg.coef_
        rows.append(dict(zip(feats, coef)))
        idx.append(sub.index[-1])

        best_params = gscv.best_params_
        best_l1_ratio = best_params.get("reg__l1_ratio", None)
        best_l1_ratios.append(best_l1_ratio)

    betas = pd.DataFrame(rows, index=pd.Index(idx, name="window_end")).sort_index()
    plot_sliding_window_betas(betas, k=k, title=f"Sliding Window Betas {kind} / {data_type} / window={window} / step={step}")
    l1_ratio_series = pd.Series(best_l1_ratios, index=betas.index, name="l1_ratio")
    display(l1_ratio_series)
    return


def plot_sliding_window_betas(
    betas,
    k = None,
    title = "Sliding Window Betas",    
):
    """
    係数推移の可視化。k を指定すると直近ウィンドウの |coef| 上位のみ描画。
    """
    plt.figure(figsize=(12, 6))
    if k is not None and k < betas.shape[1]:
        cols = betas.iloc[-1].abs().sort_values(ascending=False).head(k).index.tolist()
        data = betas[cols]
    else:
        data = betas

    for c in data.columns:
        plt.plot(data.index, data[c], marker="o", linewidth=1.8, label=c)

    plt.axhline(0, color="gray", lw=1)
    plt.title(title)
    plt.ylabel("係数")
    plt.legend(loc="best", ncol=2, fontsize=9)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# elasticnet
min_prob = 0.5
exclude_q = ("Q_2", "Q_3", "Q_4")  # 四半期ダミーは除外
k = 10
sliding_window_betas(
    df=selected_df,
    stab_df=original_stab_sel_all_titles_lasso,
    y_col="hard_total_sales",
    data_type = "sales",
    min_prob=min_prob,
    k=k,
    exclude_q=exclude_q,
    window=8,              # ウィンドウ長（例: 8四半期）
    step=1,                # 1期ずつずらす
    kind="elasticnet",
    # kind="lasso",
    n_splits=3,            # 短い系列なので小さめに
    alphas=None,           # 既定の探索レンジでOK（標準化前提）
    l1_ratios=[0.2, 0.5, 0.8],  # ElasticNetの時だけ指定
)

# lasso
min_prob = 0.5
exclude_q = ("Q_2", "Q_3", "Q_4")  # 四半期ダミーは除外
k = 10
sliding_window_betas(
    df=selected_df,
    stab_df=original_stab_sel_all_titles_lasso,
    y_col="hard_total_sales",
    data_type = "sales",
    min_prob=min_prob,
    k=k,
    exclude_q=exclude_q,
    window=8,              # ウィンドウ長（例: 8四半期）
    step=1,                # 1期ずつずらす
    # kind="elasticnet",
    kind="lasso",
    n_splits=3,            # 短い系列なので小さめに
    alphas=None,           # 既定の探索レンジでOK（標準化前提）
    # l1_ratios=[0.2, 0.5, 0.8],  # ElasticNetの時だけ指定
)
# Out:
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.813e+02, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# window_end
# 2018-12-31    0.8
# 2019-03-31    0.2
# 2019-06-30    0.8
# 2019-09-30    0.2
# 2019-12-31    0.2
# 2020-03-31    0.2
# 2020-06-30    0.8
# 2020-09-30    0.2
# 2020-12-31    0.8
# 2021-03-31    0.2
# 2021-06-30    0.8
# 2021-09-30    0.2
# 2021-12-31    0.8
# 2022-03-31    0.8
# 2022-06-30    0.8
# 2022-09-30    0.8
# 2022-12-31    0.8
# 2023-03-31    0.8
# 2023-06-30    0.2
# 2023-09-30    0.2
# 2023-12-31    0.8
# 2024-03-31    0.8
# 2024-06-30    0.8
# 2024-09-30    0.2
# 2024-12-31    0.2
# 2025-03-31    0.8
# Name: l1_ratio, dtype: float64
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.322e+01, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.597e+01, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.815e+01, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.790e+01, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.367e+01, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.432e+01, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.889e+01, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.637e+01, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/fumi/Desktop/ProjectN/analysis_N/project_N_env/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.615e+01, tolerance: 3.666e+01
#   model = cd_fast.enet_coordinate_descent(
# window_end
# 2018-12-31    None
# 2019-03-31    None
# 2019-06-30    None
# 2019-09-30    None
# 2019-12-31    None
# 2020-03-31    None
# 2020-06-30    None
# 2020-09-30    None
# 2020-12-31    None
# 2021-03-31    None
# 2021-06-30    None
# 2021-09-30    None
# 2021-12-31    None
# 2022-03-31    None
# 2022-06-30    None
# 2022-09-30    None
# 2022-12-31    None
# 2023-03-31    None
# 2023-06-30    None
# 2023-09-30    None
# 2023-12-31    None
# 2024-03-31    None
# 2024-06-30    None
# 2024-09-30    None
# 2024-12-31    None
# 2025-03-31    None
# Name: l1_ratio, dtype: object

# %%
# ここまでで一区切り
# 正則化の影響が強いLassoでは、ハード販売に対してどのタイトルが特に大きな影響を与えているかを見れそう。
# 一方、ElasticNetでは L1とL2の中間的な正則化のため、グラフも滑らかになっている

# マリオカートが主要タイトルとして長期間にわたってハード販売を牽引した。これらのタイトルの中では、圧倒的に効いているタイトルとして表現されている。
# 販売量のチャートでは、リングフィット、ゼルダは全期間を通して中位を保っていたが、回帰モデルの係数で評価すると、期間後半のハードへの寄与度は低く見える。
# リングフィットのハード販売への効き方で、2019年〜2021年が強いのは、新型コロナのパンデミックによる巣ごもり需要と一致している。
# マリオカート以外の３タイトルは、ローンチからしばらくは牽引タイトルとして機能したが、終盤の影響は限定的。一方、マリオカートの強さは変わらない。マリオカートは、ハード購入時の初期タイトルとなっている安納性が高い。

# %%
# ここで、その他のデータの分析
# 記述統計から、データの性質を読み解く　上位に残ったが安定化選択で0.5未満になったものや、販売後にスパイク的に売れるが、データ数が少ないもの。短期間でもハードへの影響が否定できなさそうなデータ。

# %%
# 記述統計の再掲
display(summary_df.sort_values("総販売量", ascending=False))
# Out:
#                                                     データ数       平均    中央値  \
# マリオカート8 デラックス_quarter                               31.0  219.968  181.0
# あつまれ どうぶつの森_quarter                                 18.0  265.722  133.5
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                       20.0  181.250  128.5
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                        24.0  132.667  121.5
# スーパーマリオ オデッセイ_quarter                               20.0  146.450  110.5
# ポケットモンスター スカーレット・バイオレット_quarter                      7.0  382.714  113.0
# ポケットモンスター ソード・シールド_quarter                           8.0  303.500  132.0
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                      5.0  434.600   99.0
# スーパーマリオパーティ_quarter                                 15.0  137.733  110.0
# New スーパーマリオブラザーズU デラックス_quarter                     15.0  116.267  125.0
# Nintendo Switch Sports_quarter                      10.0  162.700  128.5
# Super Mario Bros. Wonder_quarter                     4.0  401.000  177.5
# リングフィット アドベンチャー_quarter                             12.0  128.167  116.0
# Pokmon LEGENDS アルセウス_quarter                         4.0  370.750   99.5
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter             2.0  732.500  732.5
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter     8.0  181.625   83.0
# マリオパーティ スーパースターズ_quarter                             9.0  155.444  119.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                  10.0  134.800   93.0
# Splatoon2_quarter                                   12.0  110.917  109.5
# ルイージマンション3_quarter                                   7.0  189.714  142.0
# Splatoon3_quarter                                    5.0  239.200  104.0
# ルイージマンション３_quarter                                   4.0  261.000  148.0
# スーパーマリオ 3Dコレクション_quarter                             3.0  300.333  311.0
# 星のカービィ ディスカバリー_quarter                               6.0  125.333   96.0
# スーパー マリオパーティ ジャンボリー_quarter                          2.0  374.000  374.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                                   0.116
# Splatoon2_quarter                                                   -0.213
# ルイージマンション3_quarter                                                   0.618
# Splatoon3_quarter                                                   -0.075
# ルイージマンション３_quarter                                                  -0.802
# スーパーマリオ 3Dコレクション_quarter                                             0.345
# 星のカービィ ディスカバリー_quarter                                              -0.022
# スーパー マリオパーティ ジャンボリー_quarter                                            NaN
# スーパーマリオメーカー2_quarter                                                -0.079
# ゼルダの伝説 夢をみる島_quarter                                                -0.024
# 世界のアソビ大全51_quarter                                                  -0.127
# ゼルダの伝説 知恵のかりもの_quarter                                               0.357
# ゼルダの伝説 スカイウォードソード HD_quarter                                        -0.491
# Pikmin 4_quarter                                                    -0.110
# スーパーマリオRPG_quarter                                                     NaN
# ペーパーマリオ オリガミキング_quarter                                             -0.160
# ゼルダ無双 厄災の黙示録_quarter                                                   NaN
# メトロイド ドレッド_quarter                                                     NaN
# ファイアーエムブレム 風花雪月_quarter                                             -0.333
# マリオテニス エース_quarter                                                  -0.406
# 星のカービィ スターアライズ_quarter                                               0.481
# マリオストライカーズ バトルリーグ_quarter                                           -0.208
# New ポケモンスナップ_quarter                                                -0.227
# マリオゴルフ スーパーラッシュ_quarter                                             -0.282
# ドンキーコング トロピカルフリーズ_quarter                                           -0.299
# ペーパーマリオRPG_quarter                                                  -0.231
# ピクミン3 デラックス_quarter                                                    NaN
# マリオ&ルイージRPG ブラザーシップ!_quarter                                           NaN
# ルイージマンション2 HD_quarter                                               -0.163
# ゼノブレイド3_quarter                                                     -0.453
# ARMS_quarter                                                        -0.462
# ミートピア_quarter                                                       -0.193
# ファイアーエムブレム エンゲージ_quarter                                               NaN
# やわらかあたま塾 いっしょにあたまのストレッチ_quarter                                        NaN
# Xenoblade Definitive Edition_quarter                                -0.317
# 星のカービィ Wii デラックス_quarter                                               NaN
# 1-2-Switch_quarter                                                     NaN
# ゼノブレイド2_quarter                                                        NaN
# ドンキーコング リターンズ HD_quarter                                               NaN
# マリオカート ライブ ホームサーキット_quarter                                            NaN
# おすそわける メイド イン ワリオ_quarter                                              NaN
# ポケモン不思議のダンジョン 救助隊DX_quarter                                            NaN
# おすそわける　メイド イン ワリオ_quarter                                              NaN
# プリンセスピーチ Showtime!_quarter                                             NaN
# 進め! キノピオ隊長_quarter                                                     NaN
# OCTOPATH TRAVELER_quarter                                              NaN
# ポッ拳 ポッケン トーナメント DX_quarter                                             NaN
# マリオvs.ドンキーコング_quarter                                                  NaN
# ヨッシークラフトワールド_quarter                                                   NaN
# メトロイドプライム リマスタード_quarter                                               NaN
# Nintendo Labo Toy-Con 01: Variety Kit_quarter                          NaN
# MARVEL ULTIMATE ALLIANCE 3: The Black Order_qua...                     NaN
# ASTRAL CHAIN_quarter                                                   NaN
# ベヨネッタ3_quarter                                                         NaN
# ナビつき！ つくってわかる はじめてゲームプログラミング_quarter                                   NaN
#
#                                                     p値(hard_total_sales)  \
# マリオカート8 デラックス_quarter                                             0.0000
# あつまれ どうぶつの森_quarter                                               0.4201
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                                     0.0916
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                                      0.3248
# スーパーマリオ オデッセイ_quarter                                             0.2319
# ポケットモンスター スカーレット・バイオレット_quarter                                   0.0726
# ポケットモンスター ソード・シールド_quarter                                        0.4179
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                                   0.8382
# スーパーマリオパーティ_quarter                                               0.0812
# New スーパーマリオブラザーズU デラックス_quarter                                   0.7022
# Nintendo Switch Sports_quarter                                    0.3247
# Super Mario Bros. Wonder_quarter                                  0.1368
# リングフィット アドベンチャー_quarter                                           0.0018
# Pokmon LEGENDS アルセウス_quarter                                      0.8504
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter                             NaN
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter                  0.3702
# マリオパーティ スーパースターズ_quarter                                          0.0263
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                                0.7499
# Splatoon2_quarter                                                 0.5068
# ルイージマンション3_quarter                                                0.1393
# Splatoon3_quarter                                                 0.9040
# ルイージマンション３_quarter                                                0.1975
# スーパーマリオ 3Dコレクション_quarter                                          0.7758
# 星のカービィ ディスカバリー_quarter                                            0.9669
# スーパー マリオパーティ ジャンボリー_quarter                                          NaN
# スーパーマリオメーカー2_quarter                                              0.8813
# ゼルダの伝説 夢をみる島_quarter                                              0.9758
# 世界のアソビ大全51_quarter                                                0.8383
# ゼルダの伝説 知恵のかりもの_quarter                                            0.7677
# ゼルダの伝説 スカイウォードソード HD_quarter                                      0.6731
# Pikmin 4_quarter                                                  0.9298
# スーパーマリオRPG_quarter                                                   NaN
# ペーパーマリオ オリガミキング_quarter                                           0.8979
# ゼルダ無双 厄災の黙示録_quarter                                                 NaN
# メトロイド ドレッド_quarter                                                   NaN
# ファイアーエムブレム 風花雪月_quarter                                           0.7837
# マリオテニス エース_quarter                                                0.5935
# 星のカービィ スターアライズ_quarter                                            0.6804
# マリオストライカーズ バトルリーグ_quarter                                         0.7923
# New ポケモンスナップ_quarter                                              0.7730
# マリオゴルフ スーパーラッシュ_quarter                                           0.7179
# ドンキーコング トロピカルフリーズ_quarter                                         0.7013
# ペーパーマリオRPG_quarter                                                0.7693
# ピクミン3 デラックス_quarter                                                  NaN
# マリオ&ルイージRPG ブラザーシップ!_quarter                                         NaN
# ルイージマンション2 HD_quarter                                             0.8369
# ゼノブレイド3_quarter                                                   0.7007
# ARMS_quarter                                                      0.5382
# ミートピア_quarter                                                     0.8069
# ファイアーエムブレム エンゲージ_quarter                                             NaN
# やわらかあたま塾 いっしょにあたまのストレッチ_quarter                                      NaN
# Xenoblade Definitive Edition_quarter                              0.6830
# 星のカービィ Wii デラックス_quarter                                             NaN
# 1-2-Switch_quarter                                                   NaN
# ゼノブレイド2_quarter                                                      NaN
# ドンキーコング リターンズ HD_quarter                                             NaN
# マリオカート ライブ ホームサーキット_quarter                                          NaN
# おすそわける メイド イン ワリオ_quarter                                            NaN
# ポケモン不思議のダンジョン 救助隊DX_quarter                                          NaN
# おすそわける　メイド イン ワリオ_quarter                                            NaN
# プリンセスピーチ Showtime!_quarter                                           NaN
# 進め! キノピオ隊長_quarter                                                   NaN
# OCTOPATH TRAVELER_quarter                                            NaN
# ポッ拳 ポッケン トーナメント DX_quarter                                           NaN
# マリオvs.ドンキーコング_quarter                                                NaN
# ヨッシークラフトワールド_quarter                                                 NaN
# メトロイドプライム リマスタード_quarter                                             NaN
# Nintendo Labo Toy-Con 01: Variety Kit_quarter                        NaN
# MARVEL ULTIMATE ALLIANCE 3: The Black Order_qua...                   NaN
# ASTRAL CHAIN_quarter                                                 NaN
# ベヨネッタ3_quarter                                                       NaN
# ナビつき！ つくってわかる はじめてゲームプログラミング_quarter                                 NaN
#
#                                                     データ数(再掲)    総販売量
# マリオカート8 デラックス_quarter                                   31.0  6819.0
# あつまれ どうぶつの森_quarter                                     18.0  4783.0
# 大乱闘スマッシュブラザーズ SPECIAL_quarter                           20.0  3625.0
# ゼルダの伝説 ブレス オブ ザ ワイルド_quarter                            24.0  3184.0
# スーパーマリオ オデッセイ_quarter                                   20.0  2929.0
# ポケットモンスター スカーレット・バイオレット_quarter                          7.0  2679.0
# ポケットモンスター ソード・シールド_quarter                               8.0  2428.0
# ゼルダの伝説 ティアーズ オブ ザ キングダム_quarter                          5.0  2173.0
# スーパーマリオパーティ_quarter                                     15.0  2066.0
# New スーパーマリオブラザーズU デラックス_quarter                         15.0  1744.0
# Nintendo Switch Sports_quarter                          10.0  1627.0
# Super Mario Bros. Wonder_quarter                         4.0  1604.0
# リングフィット アドベンチャー_quarter                                 12.0  1538.0
# Pokmon LEGENDS アルセウス_quarter                             4.0  1483.0
# ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter                 2.0  1465.0
# ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter         8.0  1453.0
# マリオパーティ スーパースターズ_quarter                                 9.0  1399.0
# スーパーマリオ 3Dワールド + フューリーワールド_quarter                      10.0  1348.0
# Splatoon2_quarter                                       12.0  1331.0
# ルイージマンション3_quarter                                       7.0  1328.0
# Splatoon3_quarter                                        5.0  1196.0
# ルイージマンション３_quarter                                       4.0  1044.0
# スーパーマリオ 3Dコレクション_quarter                                 3.0   901.0
# 星のカービィ ディスカバリー_quarter                                   6.0   752.0
# スーパー マリオパーティ ジャンボリー_quarter                              2.0   748.0
# スーパーマリオメーカー2_quarter                                     6.0   715.0
# ゼルダの伝説 夢をみる島_quarter                                     4.0   549.0
# 世界のアソビ大全51_quarter                                       5.0   422.0
# ゼルダの伝説 知恵のかりもの_quarter                                   3.0   409.0
# ゼルダの伝説 スカイウォードソード HD_quarter                             3.0   391.0
# Pikmin 4_quarter                                         3.0   348.0
# スーパーマリオRPG_quarter                                       2.0   331.0
# ペーパーマリオ オリガミキング_quarter                                  3.0   312.0
# ゼルダ無双 厄災の黙示録_quarter                                     2.0   307.0
# メトロイド ドレッド_quarter                                       2.0   290.0
# ファイアーエムブレム 風花雪月_quarter                                  3.0   287.0
# マリオテニス エース_quarter                                       4.0   264.0
# 星のカービィ スターアライズ_quarter                                   3.0   256.0
# マリオストライカーズ バトルリーグ_quarter                                4.0   254.0
# New ポケモンスナップ_quarter                                     4.0   240.0
# マリオゴルフ スーパーラッシュ_quarter                                  4.0   235.0
# ドンキーコング トロピカルフリーズ_quarter                                4.0   225.0
# ペーパーマリオRPG_quarter                                       4.0   210.0
# ピクミン3 デラックス_quarter                                      2.0   204.0
# マリオ&ルイージRPG ブラザーシップ!_quarter                             2.0   197.0
# ルイージマンション2 HD_quarter                                    4.0   188.0
# ゼノブレイド3_quarter                                          3.0   186.0
# ARMS_quarter                                             4.0   185.0
# ミートピア_quarter                                            4.0   168.0
# ファイアーエムブレム エンゲージ_quarter                                 1.0   161.0
# やわらかあたま塾 いっしょにあたまのストレッチ_quarter                          2.0   159.0
# Xenoblade Definitive Edition_quarter                     4.0   152.0
# 星のカービィ Wii デラックス_quarter                                 1.0   146.0
# 1-2-Switch_quarter                                       1.0   134.0
# ゼノブレイド2_quarter                                          2.0   131.0
# ドンキーコング リターンズ HD_quarter                                 1.0   127.0
# マリオカート ライブ ホームサーキット_quarter                              2.0   127.0
# おすそわける メイド イン ワリオ_quarter                                1.0   127.0
# ポケモン不思議のダンジョン 救助隊DX_quarter                              1.0   126.0
# おすそわける　メイド イン ワリオ_quarter                                1.0   124.0
# プリンセスピーチ Showtime!_quarter                               1.0   122.0
# 進め! キノピオ隊長_quarter                                       2.0   118.0
# OCTOPATH TRAVELER_quarter                                2.0   117.0
# ポッ拳 ポッケン トーナメント DX_quarter                               1.0   116.0
# マリオvs.ドンキーコング_quarter                                    1.0   112.0
# ヨッシークラフトワールド_quarter                                     1.0   111.0
# メトロイドプライム リマスタード_quarter                                 1.0   109.0
# Nintendo Labo Toy-Con 01: Variety Kit_quarter            2.0   109.0
# MARVEL ULTIMATE ALLIANCE 3: The Black Order_qua...       2.0   108.0
# ASTRAL CHAIN_quarter                                     2.0   108.0
# ベヨネッタ3_quarter                                           2.0   107.0
# ナビつき！ つくってわかる はじめてゲームプログラミング_quarter                     2.0   106.0

# %%
# 記述統計から、個別に見てみたいタイトルを抽出
# Splatoon2
# スマブラ
# あつ森
pickup_titles = ["あつまれ どうぶつの森_quarter", "大乱闘スマッシュブラザーズ SPECIAL_quarter", "Splatoon2_quarter"]
pickup_titles_resid = ["あつまれ どうぶつの森_quarter_resid", "大乱闘スマッシュブラザーズ SPECIAL_quarter_resid", "Splatoon2_quarter_resid"]

# ポケモンはデータ数が少ないにも関わらず、CV、最大値、総販売量が大きい。ローンチ直後のスパイクが極端に大きいタイトルで、一時のハード販売量には貢献するが、継続的に効くタイトルではない。
pokemon = [t for t in summary_df.index if "ポケ" in t or "Pok" in t] 
pokemon_resid = [t + "_resid" for t in pokemon]

# %%
plot_titles_vs_hardware(
    df=selected_df,
    # stability_df=original_stab_sel_all_titles_lasso, 
    pickup_titles=pickup_titles,
    y_col="hard_total_sales",
    min_prob=0.5,
    # k=5,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,           
    title="Switch: タイトル販売×ハード販売",
    left_ylabel = "タイトル販売量",
    right_ylabel = "ハード販売量",
)

plot_titles_vs_hardware(
    df=zero_to_nan_prelaunch(df, residuals_df), # ローンチ前のデータはnanにしてプロットは非表示にする
    # df = residuals_df,
    # stability_df=resid_stab_sel_all_titles_lasso,
    pickup_titles=pickup_titles_resid,
    y_col="hard_total_sales_resid",
    min_prob=0.5,
    # k=5,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,
    title="Switch: タイトル販売残差×ハード販売残差",
    left_ylabel = "タイトル販売量残差",
    right_ylabel = "ハード販売量残差",
)
# Out:
# ['あつまれ どうぶつの森_quarter_resid',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter_resid',
#  'Splatoon2_quarter_resid']

# %%
plot_titles_vs_hardware(
    df=selected_df,
    # stability_df=original_stab_sel_all_titles_lasso, 
    pickup_titles=pokemon,
    y_col="hard_total_sales",
    min_prob=0.5,
    # k=5,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,           
    title="Switch: タイトル販売×ハード販売",
    left_ylabel = "タイトル販売量",
    right_ylabel = "ハード販売量",
)

plot_titles_vs_hardware(
    df=zero_to_nan_prelaunch(df, residuals_df), # ローンチ前のデータはnanにしてプロットは非表示にする
    # df = residuals_df,
    # stability_df=resid_stab_sel_all_titles_lasso,
    pickup_titles=pokemon_resid,
    y_col="hard_total_sales_resid",
    min_prob=0.5,
    # k=5,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,
    title="Switch: タイトル販売残差×ハード販売残差",
    left_ylabel = "タイトル販売量残差",
    right_ylabel = "ハード販売量残差",
)
# Out:
# ['ポケットモンスター ソード・シールド_quarter_resid',
#  "ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter_resid",
#  'ポケットモンスター スカーレット・バイオレット_quarter_resid',
#  'Pokmon LEGENDS アルセウス_quarter_resid',
#  'ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter_resid',
#  'New ポケモンスナップ_quarter_resid',
#  'ポケモン不思議のダンジョン 救助隊DX_quarter_resid']

# %%
selected_df[pokemon]
# Out:
#             ポケットモンスター ソード・シールド_quarter  \
# 2017-03-31                         0.0
# 2017-06-30                         0.0
# 2017-09-30                         0.0
# 2017-12-31                         0.0
# 2018-03-31                         0.0
# 2018-06-30                         0.0
# 2018-09-30                         0.0
# 2018-12-31                         0.0
# 2019-03-31                         0.0
# 2019-06-30                         0.0
# 2019-09-30                         0.0
# 2019-12-31                      1606.0
# 2020-03-31                       131.0
# 2020-06-30                         0.0
# 2020-09-30                       165.0
# 2020-12-31                       133.0
# 2021-03-31                        75.0
# 2021-06-30                         0.0
# 2021-09-30                       154.0
# 2021-12-31                       126.0
# 2022-03-31                        38.0
# 2022-06-30                         0.0
# 2022-09-30                         0.0
# 2022-12-31                         0.0
# 2023-03-31                         0.0
# 2023-06-30                         0.0
# 2023-09-30                         0.0
# 2023-12-31                         0.0
# 2024-03-31                         0.0
# 2024-06-30                         0.0
# 2024-09-30                         0.0
# 2024-12-31                         0.0
# 2025-03-31                         0.0
#
#             ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter  \
# 2017-03-31                                               0.0
# 2017-06-30                                               0.0
# 2017-09-30                                               0.0
# 2017-12-31                                               0.0
# 2018-03-31                                               0.0
# 2018-06-30                                               0.0
# 2018-09-30                                               0.0
# 2018-12-31                                            1000.0
# 2019-03-31                                              63.0
# 2019-06-30                                               0.0
# 2019-09-30                                               0.0
# 2019-12-31                                             113.0
# 2020-03-31                                              21.0
# 2020-06-30                                               0.0
# 2020-09-30                                               0.0
# 2020-12-31                                             103.0
# 2021-03-31                                              28.0
# 2021-06-30                                               0.0
# 2021-09-30                                               0.0
# 2021-12-31                                             105.0
# 2022-03-31                                              20.0
# 2022-06-30                                               0.0
# 2022-09-30                                               0.0
# 2022-12-31                                               0.0
# 2023-03-31                                               0.0
# 2023-06-30                                               0.0
# 2023-09-30                                               0.0
# 2023-12-31                                               0.0
# 2024-03-31                                               0.0
# 2024-06-30                                               0.0
# 2018-12-31                          0.0
# 2019-03-31                          0.0
# 2019-06-30                          0.0
# 2019-09-30                          0.0
# 2019-12-31                          0.0
# 2020-03-31                        126.0
# 2020-06-30                          0.0
# 2020-09-30                          0.0
# 2020-12-31                          0.0
# 2021-03-31                          0.0
# 2021-06-30                          0.0
# 2021-09-30                          0.0
# 2021-12-31                          0.0
# 2022-03-31                          0.0
# 2022-06-30                          0.0
# 2022-09-30                          0.0
# 2022-12-31                          0.0
# 2023-03-31                          0.0
# 2023-06-30                          0.0
# 2023-09-30                          0.0
# 2023-12-31                          0.0
# 2024-03-31                          0.0
# 2024-06-30                          0.0
# 2024-09-30                          0.0
# 2024-12-31                          0.0
# 2025-03-31                          0.0

# %%
# あつ森、スマブラ、スプラはどれも売れ行きはどれも長期間続くが、あつ森、スマブラはローンチ直後にスパイク的な販売量を示していることから、発売初期はハード売上を牽引した可能性は高い。
# 残差分析では、あつ森の初期のピークが際立っている。ハード販売の残差も伸びており、かつ2020/6,9,12月期には、他に同様な伸びを示すタイトルはないので、このタイトルがハード販売を牽引した可能性がある。
# スプラの残差は低位で安定。ハード新規購入層の初期タイトルとして毎期の一定量の売上に貢献

# ポケモンはどれも初期スパイクが大きく1000万本以上売るが、その後の安定性ない。ハードの潜在的購入者の意欲がピークになりそうな年末などの季節性を考慮して、購入の決断を後押しするためのタイトルとして効く
# 競争相手のハードウェアがローンチされるタイミングに自社ハードを優先してもらうための、差別化要因のタイトルになる

# これらのタイトルの販売量のスライディング回帰

# %%
original_stab_sel_all_titles_lasso
# Out:
#                                              feature  selection_rate  \
# 0                              マリオカート8 デラックス_quarter           1.000
# 1                            リングフィット アドベンチャー_quarter           1.000
# 2                                スーパーマリオパーティ_quarter           0.670
# 3                       ゼルダの伝説 ブレス オブ ザ ワイルド_quarter           0.530
# 4                              スーパーマリオ オデッセイ_quarter           0.390
# 5                           マリオパーティ スーパースターズ_quarter           0.375
# 6                      大乱闘スマッシュブラザーズ SPECIAL_quarter           0.360
# 7   ポケットモンスター Let's Go! ピカチュウ・Let's Go! イーブイ_quarter           0.345
# 8                     Nintendo Switch Sports_quarter           0.340
# 9                 スーパーマリオ 3Dワールド + フューリーワールド_quarter           0.340
# 10                   New スーパーマリオブラザーズU デラックス_quarter           0.335
# 11                                 Splatoon2_quarter           0.230
# 12                               あつまれ どうぶつの森_quarter           0.220
# 13                        ポケットモンスター ソード・シールド_quarter           0.110
#
#     sign_positive_share  sign_negative_share  sign_stability  hit_count  \
# 0              1.000000             0.000000        1.000000        200
# 1              1.000000             0.000000        1.000000        200
# 2              1.000000             0.000000        1.000000        134
# 3              1.000000             0.000000        1.000000        106
# 4              0.435897             0.564103        0.564103         78
# 5              1.000000             0.000000        1.000000         75
# 6              1.000000             0.000000        1.000000         72
# 7              1.000000             0.000000        1.000000         69
# 8              1.000000             0.000000        1.000000         68
# 9              0.000000             1.000000        1.000000         68
# 10             0.671642             0.328358        0.671642         67
# 11             0.521739             0.478261        0.521739         46
# 12             0.000000             1.000000        1.000000         44
# 13             0.000000             1.000000        1.000000         22
#
#     repeats
# 0       200
# 1       200
# 2       200
# 3       200
# 4       200
# 5       200
# 6       200
# 7       200
# 8       200
# 9       200
# 10      200
# 11      200
# 12      200
# 13      200

# %%
pickup_titles
# Out:
# ['あつまれ どうぶつの森_quarter', '大乱闘スマッシュブラザーズ SPECIAL_quarter', 'Splatoon2_quarter']

# %%
# elasticnet
min_prob = 0.1
exclude_q = ("Q_2", "Q_3", "Q_4")  # 四半期ダミーは除外
k = 10
sliding_window_betas(
    df=selected_df,
    stab_df=original_stab_sel_all_titles_lasso.loc[original_stab_sel_all_titles_lasso["feature"].isin(pickup_titles)],
    y_col="hard_total_sales",
    data_type = "sales",
    min_prob=min_prob,
    k=k,
    exclude_q=exclude_q,
    window=8,              # ウィンドウ長（例: 8四半期）
    step=1,                # 1期ずつずらす
    kind="elasticnet",
    # kind="lasso",
    n_splits=3,            # 短い系列なので小さめに
    alphas=None,           # 既定の探索レンジでOK（標準化前提）
    l1_ratios=[0.2, 0.5, 0.8],  # ElasticNetの時だけ指定
)

# # lasso
# min_prob = 0.1
# exclude_q = ("Q_2", "Q_3", "Q_4")  # 四半期ダミーは除外
# k = 10
# sliding_window_betas(
#     df=selected_df,
#     stab_df=original_stab_sel_all_titles_lasso.loc[original_stab_sel_all_titles_lasso["feature"].isin(pickup_titles)],
#     y_col="hard_total_sales",
#     data_type = "sales",
#     min_prob=min_prob,
#     k=k,
#     exclude_q=exclude_q,
#     window=8,              # ウィンドウ長（例: 8四半期）
#     step=1,                # 1期ずつずらす
#     # kind="elasticnet",
#     kind="lasso",
#     n_splits=3,            # 短い系列なので小さめに
#     alphas=None,           # 既定の探索レンジでOK（標準化前提）
#     # l1_ratios=[0.2, 0.5, 0.8],  # ElasticNetの時だけ指定
# )

# # ridge
# min_prob = 0.1
# exclude_q = ("Q_2", "Q_3", "Q_4")  # 四半期ダミーは除外
# k = 10
# sliding_window_betas(
#     df=selected_df,
#     stab_df=original_stab_sel_all_titles_lasso.loc[original_stab_sel_all_titles_lasso["feature"].isin(pickup_titles)],
#     y_col="hard_total_sales",
#     data_type = "sales",
#     min_prob=min_prob,
#     k=k,
#     exclude_q=exclude_q,
#     window=8,              # ウィンドウ長（例: 8四半期）
#     step=1,                # 1期ずつずらす
#     # kind="elasticnet",
#     kind="ridge",
#     n_splits=3,            # 短い系列なので小さめに
#     alphas=None,           # 既定の探索レンジでOK（標準化前提）
#     # l1_ratios=[0.2, 0.5, 0.8],  # ElasticNetの時だけ指定
# )
# Out:
# window_end
# 2018-12-31    0.8
# 2019-03-31    0.8
# 2019-06-30    0.8
# 2019-09-30    0.2
# 2019-12-31    0.8
# 2020-03-31    0.2
# 2020-06-30    0.2
# 2020-09-30    0.8
# 2020-12-31    0.2
# 2021-03-31    0.8
# 2021-06-30    0.8
# 2021-09-30    0.2
# 2021-12-31    0.5
# 2022-03-31    0.2
# 2022-06-30    0.8
# 2022-09-30    0.8
# 2022-12-31    0.8
# 2023-03-31    0.8
# 2023-06-30    0.8
# 2023-09-30    0.8
# 2023-12-31    0.8
# 2024-03-31    0.8
# 2024-06-30    0.8
# 2024-09-30    0.2
# 2024-12-31    0.8
# 2025-03-31    0.2
# Name: l1_ratio, dtype: float64

# %%
# スマブラとあつ森の多重共線性の影響が強く出て、特に後半は評価が難しい
# 前半は、ローンチ前のデータも算入される。

# %%
# ここで、「あつ森、スマブラ、スプラ」３タイトルに、安定性性選択でlasso選択率>0.5のタイトルを重ねて分析してみる

# %%
original_stab_sel_ranked_titles_lasso["feature"].to_list()
# Out:
# ['マリオカート8 デラックス_quarter',
#  'リングフィット アドベンチャー_quarter',
#  'スーパーマリオパーティ_quarter',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter']

# %%
plot_titles_vs_hardware(
    df=selected_df,
    # stability_df=original_stab_sel_all_titles_lasso, 
    pickup_titles=pickup_titles + original_stab_sel_ranked_titles_lasso["feature"].to_list(),
    y_col="hard_total_sales",
    min_prob=0.5,
    # k=5,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,           
    title="Switch: タイトル販売×ハード販売",
    left_ylabel = "タイトル販売量",
    right_ylabel = "ハード販売量",
)

plot_titles_vs_hardware(
    df=zero_to_nan_prelaunch(df, residuals_df), # ローンチ前のデータはnanにしてプロットは非表示にする
    # df = residuals_df,
    # stability_df=resid_stab_sel_all_titles_lasso,
    pickup_titles=pickup_titles_resid + resid_stab_sel_ranked_titles_lasso["feature"].to_list(),
    y_col="hard_total_sales_resid",
    min_prob=0.5,
    # k=5,
    exclude_q=("Q_2","Q_3","Q_4"),
    font_name=None,
    title="Switch: タイトル販売残差×ハード販売残差",
    left_ylabel = "タイトル販売量残差",
    right_ylabel = "ハード販売量残差",
)
# Out:
# ['あつまれ どうぶつの森_quarter_resid',
#  '大乱闘スマッシュブラザーズ SPECIAL_quarter_resid',
#  'Splatoon2_quarter_resid',
#  'リングフィット アドベンチャー_quarter_resid',
#  'マリオカート8 デラックス_quarter_resid',
#  'ゼルダの伝説 ブレス オブ ザ ワイルド_quarter_resid',
#  'スーパーマリオパーティ_quarter_resid',
#  'マリオパーティ スーパースターズ_quarter_resid']

# %%
# あつ森、スマブラ　どちらも初期のスパイクが大きく、ハード販売量との同期具合を見るとスマブラはハード購入のトリガーとなった可能性があり、短期的とはいえ明確なハード売上げの牽引タイトルと言える。
# 一方で、あつ森は新型コロナのパンデミックの時期と重なり、約1年に渡ってハードの販売を支えたことが伺える。
# マリカは発売初期から通期でハードとセット購入される基盤タイトルとなっている。 変動係数:0.479, 相関係数:0.831, p値（相関係数）:0.0000, データ数:31.0, 総販売量:6819.0
# 残りの、スプラ、リングフィット、ゼルダ、Sマリオパーティは、後半にかけて売上げを落とすが、発売以降長期にわたり安定した販売を継続している。どれも残差が０付近で安定していることからも、季節性やイベントに左右されずにハード販売のベース部分を支えたと考えられる。

# スプラや安定性選択で残ったタイトルは、市場維持とベース需要の安定化を支える存在といえる。
# ハードの残差　2020〜21のプラス残差は、新型コロナ＋あつ森・リングフィットによる需要の超過
#             ハードのローンチ初期のマイナス残差は、データ不足による回帰モデルの不安定さと、供給不足による販売機械の喪失によるもの
#             2023以降のマイナス残差は、ハードのモデル末期の買い控え


# 次の分析
# 残差相関を見る

# %% [markdown]
# #### 以下、初手で試したコードの後半部分
# 初手は データ数>4 で分析を始め、以降のコードを最後まで試して分析した。
# 結果が安定しないので、データ数>8 で再度分析したものが、このセルより上の部分。

# %% [markdown]
# <!-- 以下、初手で試した終盤のコード
# 初手の前半は、ここまでのコードをデータ数>4のフィルタで分析してきた。
# これ以降コードで分析をした結果、データ数>8でフィルタし直して再度分析した方が良さそうだとか考え、初手に戻る -->

# %%
# 販売量でフィルタ -> 安定化選択
display(summary_df[(summary_df["総販売量"] >= 1000)].sort_values("データ数", ascending=False))
print(len(summary_df[(summary_df["総販売量"] >= 1000)]))

# %%
total_sales_df = culc_total_sales(selected_df)
titles_filtered_by_sales = get_titles_filtered_by_sales(total_sales_df, min_sales=1000) # total_sales_dfは初手で作成済
filtered_titles_by_sales_df = selected_df[["Q_2", "Q_3", "Q_4"] + titles_filtered_by_sales + ["hard_total_sales"]]
len(filtered_titles_by_sales_df.columns)

# %%
print("== 季節性調整後のタイトルでフィルタ ==")
seasonal_corr_df_sales_datas, filtered_cols_sales_datas, residuals_df_sales_datas = seasonal_corr_filter_from_selected(filtered_titles_by_sales_df, corr_thld=0.35)

# 季節調整後の相関でフィルタしたタイトルでcompare_allを実行
# display(compare_all(filtered_titles_by_count_df, y_col, filtered_cols_count_datas, max_iter=500000, nonzero_threshold=1e-12))
# print("== こここまで 季節調整後の相関でフィルタしてcompare_all ==")
# display(filtered_titles_by_count_df)

# %%
residuals_df_sales_datas.columns
X_cols_resid = [c for c in residuals_df_sales_datas.columns if c != "hard_total_sales_resid"]

# %%
# elasticnetで安定性選択
stab = stability_selection(
    df=residuals_df_sales_datas,
    y_col="hard_total_sales_resid",
    X_cols=X_cols_resid,
    kind="elasticnet",
    # kind='lasso',
    n_repeats=200,
    sample_frac=0.7,            # 1回あたり連続ブロックの長さ（70%）
    n_splits=4,                 # 連続ブロック内のTimeSeriesSplit分割
    max_iter=500000,
    scoring="r2",
    random_state=0
)

kind, all_titles, ranked, top_view = summarize_stability(
    stab,
    k=15,
    min_sel_rate=0.30,
    min_sign_stability=0.60
)
# print(all_titles)  # 閾値を満たす“安定して効く”タイトル
# print(top_view)　　 # 上位k件のプレビュー

res = {}
res[f'res_{kind}'] = all_titles

plot_stability_summary(all_titles, title="All Features (selection_rate)", kind=kind)
# plot_stability_summary(ranked, title="Ranked Features (selection_rate)", kind=kind)
# plot_stability_summary(top_view, title="Top-k Features (selection_rate)", kind=kind)

sales_datas_stab_sel_all_titles_lasso = all_titles

# %%
# lassoで安定性選択
stab = stability_selection(
    df=residuals_df_sales_datas,
    y_col="hard_total_sales_resid",
    X_cols=X_cols_resid,
    # kind="elasticnet",
    kind='lasso',
    n_repeats=200,
    sample_frac=0.7,            # 1回あたり連続ブロックの長さ（70%）
    n_splits=4,                 # 連続ブロック内のTimeSeriesSplit分割
    max_iter=500000,
    scoring="r2",
    random_state=0
)

kind, all_titles, ranked, top_view = summarize_stability(
    stab, # 
    k=15,
    min_sel_rate=0.30,
    min_sign_stability=0.60
)
# print(all_titles)  # 閾値を満たす“安定して効く”タイトル
# print(top_view)　　 # 上位k件のプレビュー

res = {}
res[f'res_{kind}'] = all_titles

plot_stability_summary(all_titles, title="All Features (selection_rate)", kind=kind)
# plot_stability_summary(ranked, title="Ranked Features (selection_rate)", kind=kind)
# plot_stability_summary(top_view, title="Top-k Features (selection_rate)", kind=kind)

sales_datas_stab_sel_all_titles_lasso = all_titles

# %%
# 同時期に四半期単位で売れているタイトルの影響度の区別は難しい。
# タイトルを決めて、その影響度を測った方が現実的
# 目的はを変更。人気タイトルがどれくらいの期間ハードの販売を牽引するか。。。

# まずは、販売量と販売期間から人気タイトルの選別。
# 再度、以下のフィルタでタイトルを絞って、その中から、人気タイトルのハードへの影響度を測る。
# "四半期データ数" >= 4
# "総販売量" >= 500

# これまでの分析のまとめ
# どの手法も多重共線性の影響とデータ数不足により、不安定な結果になりがち
# 全てのタイトルを投入 -> データ数（四半期数）に対してタイトル数（説明変数）が多いので、回帰モデルが成立しない
# 安定性選択でフィルタ -> 事前に有効データ数（販売があった四半期数）や販売量でフィルタして説明変数を整理しても、
# 　　　　　　　　　　　　　ElasticNetでは、ほとんどが高確率で残る。これはタイトル同士の相関が強く、タイトル群としてハード売上に効いているという評価しかできない。
# 　　　　　　　　　　　　　Lassoでは、より効いているタイトルのみを残す効果が強く出過ぎて、代表的なタイトルしか評価されていない。
#                       -> 典型的な多重共線性の形　R2と調整済R2の差が小さくても、解釈性は低い。

# 販売期間が一定期間あるタイトルと、販売量が多いタイトルの記述統計を見直す
# 残差化したデータの安定化選択の結果とsliding windowの結果を再考する


# 同時期に同じように売れたタイトルは、それぞれのハード販売への影響度を切り分けて考えるのは難しい
# 複数のタイトルが同時期に売れている以上、それらをまとめてモデルに投入して機械的に分析するのには限界がある
# 次にやってみること
# 　タイトルを絞って個別に分析する　-> シリーズものの傾向を分析につながる
# 　多重共線性があるとはいえ、ここまでの分析で見えてきた知見の仮説を深掘りしてみる

# 安定性選択(lasso)で残ったタイトルを影響力の強いタイトルの一角として分析する
#  ① 残差化後の安定化選択で上位(>0.5)に残ったものは、ハード販売に効いているタイトルの代表と考える。
#  ②  -> 実際に効いていながらもアルゴリズムに落とされたものを補完するために、残差化前（販売データ）の安定化選択と統計統計を見直す# 　その中にシリーズものがないか確認　主成分分析につなげる
# 　その中にシリーズものがないか確認 -> 主成分分析がにつなげる
# 記述統計より
# 　ポケモンは一気に売れる傾向　データ数が少ないのに販売量が大きい　CVが大きい　発売直後、もしくは季節連動でスパイク的に売れている可能性
# 　アソビ大全は販売量が小さくても安定性選択で上位に来ている　CVが小さい　安定的に継続して売れている可能性
#   残ったタイトルとハード販売の相関をチェックする
#

# %%
# 元データ（販売データ）による安定性選択の可視化
# plot_stability_summary(original_stab_sel_all_titles_elasticnet, title="All Features", kind="elasticnet")
plot_stability_summary(original_stab_sel_all_titles_lasso, title="All Features ", kind="lasso")
plot_stability_summary(original_stab_sel_ranked_titles_lasso, title=f"Ranked Features (selection_rate >= {min_sel_rate})", kind="lasoo") # min_sel_rateは前回rankedを計算したときの値

# 残差化データによる安定性選択の可視化
plot_stability_summary(resid_stab_sel_all_titles_lasso, title="All Features ", kind="lasso")
plot_stability_summary(resid_stab_sel_ranked_titles_lasso, title=f"Ranked Features (selection_rate >= {min_sel_rate})", kind="lasso")

# %%
# 残差化したデータの安定化選択の結果
display(resid_stab_sel_all_titles_lasso[resid_stab_sel_all_titles_lasso["selection_rate"] > 0])
filtered_titiles_from_resid_stab_sel_all_titles_lasso = resid_stab_sel_all_titles_lasso[resid_stab_sel_all_titles_lasso["selection_rate"] > 0.2]['feature'].to_list()
filtered_titiles_from_resid_stab_sel_all_titles_lasso

# %%
# display(summary_df[(summary_df["データ数"] >= 4) | (summary_df["総販売量"] >= 500)].sort_values("データ数", ascending=False))
filtered_summary_df = summary_df[(summary_df["データ数"] >= 4) | (summary_df["総販売量"] >= 500)].sort_values("データ数", ascending=False)
print(len(filtered_summary_df))
filtered_summary_df

# %%
# 残差化したデータで安定化選択した結果の上位を、CV昇順で表示（サフィックス"_resid"を外す）
replaced_filtered_titiles_from_resid_stab_sel_all_titles_lasso = [i.replace("_resid", "") for i in filtered_titiles_from_resid_stab_sel_all_titles_lasso]
summary_df.loc[replaced_filtered_titiles_from_resid_stab_sel_all_titles_lasso].sort_values("変動係数(CV)", ascending=True)

# %%
# selection_rate > 0.2 のデータを記述統計テーブル上でカラー表示 (filtered_titiles_from_resid_stab_sel_all_titles_lassoでフィルタ)
# 1つ目："総販売量"で降順に並べ替えてからマスク
filtered_summary_df = filtered_summary_df.sort_values("総販売量", ascending=False)
mask1 = filtered_summary_df.index.isin(replaced_filtered_titiles_from_resid_stab_sel_all_titles_lasso)
styled = filtered_summary_df.style.apply(lambda s: ['background-color: red' if v else '' for v in mask1], axis=0)
display(styled)

# 2つ目："CV"で昇順に並べ替えてからマスク
filtered_summary_df_ = filtered_summary_df.sort_values("変動係数(CV)", ascending=True)
mask2 = filtered_summary_df_.index.isin(replaced_filtered_titiles_from_resid_stab_sel_all_titles_lasso)
styled_ = filtered_summary_df_.style.apply(lambda s: ['background-color: blue' if v else '' for v in mask2], axis=0)
display(styled_)

# %%
# 残差データの相関係数で記述統計をソート
# モデルの当てはまり加減を見ようとしたが、タイトル数を絞らないと相関係数がばらついて評価が難しい

def summarize_resid_stats(df, title_cols):
    """
    残差データを対象に記述統計
    """
    stats = {}
    for col in title_cols:
        series = df[col].dropna()
        n = series.count()

        # 相関係数とp値の計算（データ数が3以上のときのみ）
        if n > 2:
            corr_val, p_val = pearsonr(df["hard_total_sales_resid"].loc[series.index], series)
            corr_val = round(corr_val, 3)
            p_val = round(p_val, 4)
        else:
            corr_val = None
            p_val = None
        
        mean_val = series.mean()
        if mean_val != 0:
            cv_val = round(series.std() / mean_val, 3)
        else:
            cv_val = None

        stats[col] = {
            "データ数": n,
            "平均": round(mean_val, 3),
            "中央値": series.median() if n > 0 else None,
            "標準偏差": round(series.std(), 3) if n > 0 else None,
            "最小値": series.min() if n > 0 else None,
            "最大値": series.max() if n > 0 else None,
            "変動係数(CV)": cv_val,
            "相関係数(hard_total_sales_resid)": corr_val,
            "p値(hard_total_sales_resid)": p_val,
            "データ数(再掲)": n,
            "総販売量": series.sum() if n > 0 else None
        }

    summary_df = pd.DataFrame(stats).T
    return summary_df

titles_without_total_sales = [col for col in residuals_df.columns if col not in ["hard_total_sales_resid"]]
resid_summary_df = summarize_resid_stats(residuals_df, titles_without_total_sales)
# resid_summary_df.sort_values("相関係数(hard_total_sales_resid)")

# 3つ目：残差化したデータで"相関係数"で昇順に並べ替えてからマスク
filtered_resid_summary_df = resid_summary_df.sort_values("相関係数(hard_total_sales_resid)", ascending=False)
replaced_filtered_titiles_from_resid_stab_sel_all_titles_lasso_with_resid = [t + "_resid" for t in replaced_filtered_titiles_from_resid_stab_sel_all_titles_lasso]
mask3 = filtered_resid_summary_df.index.isin(replaced_filtered_titiles_from_resid_stab_sel_all_titles_lasso_with_resid)
styled__ = filtered_resid_summary_df.style.apply(lambda s: ['background-color: green' if v else '' for v in mask3], axis=0)
display(styled__)

# %%
# CV昇順上位に selection_rate > 0.4 以上の6タイトル が並んでいる。
# ここまでをまとめると
# 　安定性選択での上位に残ったタイトルは、記述統計上CVも低く、安定的に毎期売れているものが多い。とできる。
# 　ただし、タイトルの総販売量が少ないものはハードへの貢献度も限定的と考えると、"世界のアソビ大全51"は、販売データも5期分しかないため、影響度が大きかったタイトル群からは外すべきかもしれない

# 　ここから考えること
#   まず、総販売量(>700) とデータ数(>8)でフィルタする
#　　①販売量：　単純にハード販売への影響力が大きいと考える
#　　①データ数：一定のデータ(四半期)数がなければ、分析精度が落ちる。回帰分析においては係数が不安定に信頼できる結果が得られない
#　　　ここまでで、残ったタイトルについて記述統計値とグラフを分析してハード販売に影響がありそうなものを主観的に洗い出す
#　　②販売データをlasso回帰の安定化選択で残ったものと、①の結果を比較する。客観的根拠の補強。（選択率>=0.5）
#　　②季節性調整済みデータをlasso回帰で安定化選択して残ったものを①と比較。客観的根拠の補強。（選択率>=0.2）
#　　③販売データのスライディング回帰でタイトルのハードへの影響の継続性をみる
#　　③季節性調整済みデータのスライディング回帰でタイトルのハードへの影響の継続性を確認する
#　　④最後にグループ化して、分析から漏れたタイトルを補う

# まず、

# %%
display(summary_df[summary_df["総販売量"] > 700].sort_values("総販売量", ascending=False))
display(summary_df[summary_df["データ数"] >= 8].sort_values("総販売量", ascending=False))

# %%
print("元の販売データの安定性選択の結果タイトル（選択率>0.5）")
display(pd.DataFrame(original_stab_sel_ranked_titles_lasso["feature"]))
print("残差化したデータの安定性選択の結果タイトル（選択率>0.2）")
display(pd.DataFrame(filtered_titiles_from_resid_stab_sel_all_titles_lasso))
print("元の販売データで、記述統計から抽出したタイトル（データ数>4、総販売量>500、CV、相関係数、P値）")
summary_df[summary_df["データ数"] > 4]
summary_df.sort_values("データ数", ascending=False)
"ポケットモンスター ブリリアントダイヤモンド・シャイニングパール_quarter", "Pokmon LEGENDS アルセウス_quarter", "スーパーマリオ 3Dコレクション_quarter", "スーパー マリオパーティ ジャンボリー_quarter", "", "", ""

print("残差化したデータで、記述統計から抽出したタイトル（データ数、総販売量、CV、相関係数、P値）")


print("")

# %%
original_stab_sel_ranked_titles_lasso

# %%
# sliding windowの
min_prob = 0.0
exclude_q = ()  # 残差にQ_2,Q_3,Q_4列がないければ空
k = 10
sliding_window_betas(
    df=residuals_df,
    stab_df=resid_stab_sel_all_titles_lasso.head(5),
    y_col="hard_total_sales_resid",
    data_type = "resid",
    min_prob=min_prob,
    k=k,
    exclude_q=exclude_q,
    window=8,
    step=1,
    kind="elasticnet",
    # kind="lasso",
    n_splits=3,
    alphas=None,
    l1_ratios=[0.2, 0.5, 0.8],
)

# %%
min_prob = 0.1
exclude_q = ()  # 残差にQ_2,Q_3,Q_4列がないければ空
k = 10
sliding_window_betas(
    df=residuals_df,
    stab_df=resid_stab_sel_all_titles_lasso.head(),
    y_col="hard_total_sales_resid",
    data_type = "resid",
    min_prob=min_prob,
    k=k,
    exclude_q=exclude_q,
    window=8,
    step=1,
    # kind="elasticnet",
    kind="lasso",
    n_splits=3,
    alphas=None,
    # l1_ratios=[0.2, 0.5, 0.8],
)

# %%
def simple_plot_titles_vs_hardware(
    df,
    X_cols=[],
    y_col="hard_total_sales",
    # exclude_q=("Q_2","Q_3","Q_4"),
    title="タイトル × ハード販売量"
    # figsize=(12, 6)
):
    """
    右軸: ハード, 左軸: タイトル
    横軸: df.index（全期間）
    """
    # 存在チェック
    if not X_cols:
        raise ValueError("タイトルを指定してください")
    x = df.index
    fig, ax_left = plt.subplots(figsize=(12, 6))
    # 左軸: タイトル
    for col in X_cols:
        ax_left.plot(x, df[col], marker="o", linewidth=1.8, label=col)
    ax_left.set_ylabel("タイトル販売量")
    # 右軸: ハード
    ax_right = ax_left.twinx()
    ax_right.bar(x, df[y_col], alpha=0.35, width=0.8, label=y_col)
    ax_right.set_ylabel("ハード販売量")
    # 軸・凡例・レイアウト
    ax_left.set_title(f"{title}")
    # 2軸の凡例をまとめる
    h1, l1 = ax_left.get_legend_handles_labels()
    h2, l2 = ax_right.get_legend_handles_labels()
    ax_left.legend(h1 + h2, l1 + l2, loc="upper left", ncol=1, frameon=True)
    # 目盛り調整
    fig.autofmt_xdate(rotation=45)
    plt.tight_layout()
    plt.show()

    return

# %%
simple_plot_titles_vs_hardware(selected_df, ["マリオカート8 デラックス_quarter", "やわらかあたま塾 いっしょにあたまのストレッチ_quarter", "スーパーマリオパーティ_quarter"])

# %%
selected_df.head()

# %%
summary_df.sort_values("総販売量", ascending=False)

# %% [markdown]
# まとめ方
# 一旦、ここまで分析して、データ数>4でのフィルタでも安定しなさそうとわかる。このフィルタ条件での結果はlassoは収束せず、相関係数も安定しない。一定の傾向は見えるが、信頼度に確証が持てない程度に分析結果がばらつく。
# 最初に戻り、スライディング回帰の実行までをデータ数>8のフィルタでやり直す。
